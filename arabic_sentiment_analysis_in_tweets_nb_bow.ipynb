# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-S-Helal/-Finding-Donors-for-Charity-ML-Project/blob/main/arabic_sentiment_analysis_in_tweets_nb_bow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arabic Sentiment Analysis in tweets using Naive Bayes Machine learning Algorithm and unigram features

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import nltk
from nltk import NaiveBayesClassifier
from nltk.metrics.scores import f_measure, precision, recall
import collections
from builtins import chr
from nltk import word_tokenize, ngrams


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # define functions

# %%
import re
from itertools import islice
from nltk.corpus import stopwords
nltk.download('stopwords')



def arabicrange():
        """return a list of arabic characteres .
        Return a list of characteres between \u060c to \u0652
        @return: list of arabic characteres.
        @rtype: unicode;
        """
        mylist = [];
        for i in range(0x0620, 0x00650):
            try :
                mylist.append(chr(i));
            except ValueError:
                pass;
        return mylist[:-5]+[' '];

arb = arabicrange()
stopwords_list = stopwords.words('arabic')

def clean_raw_review(body):
        # return ''.join(c for c in body if c in arb)
        return ''.join(c if c in arb else ' ' for c in body)

         # patterns to remove first
        pat = [\
            (u'http[s]?://[a-zA-Z0-9_\-./~\?=%&]+', u''),  # remove links
            (u'www[a-zA-Z0-9_\-?=%&/.~]+', u''),
#            u'\n+': u' ',                     # remove newlines
            (u'<br />', u' '),  # remove html line breaks
            (u'</?[^>]+>', u' '),  # remove html markup
#            u'http': u'',
            (u'[a-zA-Z]+\.org', u''),
            (u'[a-zA-Z]+\.com', u''),
            (u'://', u''),
            (u'&[^;]+;', u' '),
            (u':D', u':)'),
#            (u'[0-9/]+', u''),
#            u'[a-zA-Z.]+': u'',
#            u'[^0-9' + u''.join(self.arabicrange()) + \
#                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
#                u'\s^><\-_\u201D\u00AB=\u2026]+': u'',          # remove latin characters
            (u'\s+', u' '),  # remove spaces
            (u'\.+', u'.'),  # multiple dots
            (u'[\u201C\u201D]', u'"'),  # “
            (u'[\u2665\u2764]', u''),  # heart symbol
            (u'[\u00BB\u00AB]', u'"'),
            (u'\u2013', u'-'),  # dash
        ]

        # patterns that disqualify a review
        remove_if_there = [\
            (u'[^0-9' + u''.join(arabicrange()) + \
                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
                u'\s\^><\-_\u201D\u00AB=\u2026+|' + \
                u'\u0660-\u066D\u201C\u201D' + \
                u'\ufefb\ufef7\ufef5\ufef9]+', u''),  # non arabic characters
        ]

        # patterns that disqualify if empty after removing
        remove_if_empty_after = [\
            (u'[0-9a-zA-Z\-_]', u' '),  # alpha-numeric
            (u'[0-9' + u".,!;:$%&*%'#(){}~`\[\]/\\\\\"" + \
                u'\s\^><`\-=_+]+', u''),  # remove just punctuation
            (u'\s+', u' '),  # remove spaces
        ]

        # remove again
        # patterns to remove
        pat2 = [\
#            u'[^0-9' + u''.join(self.arabicrange()) + \
#                u"!.,;:$%&*%'#(){}~`\[\]/\\\\\"" + \
#                u'\s^><\-_\u201D\u00AB=\u2026]+': u'',          # remove latin characters
        ]

        skip = False

        # if empty body, skip
        if body == u'': skip = True

        # do some subsitutions
        for k, v in pat:
            body = re.sub(k, v, body)

        # remove if exist
        for k, v in remove_if_there:
            if re.search(k, body):
                skip = True

        # remove if empty after replacing
        for k, v in remove_if_empty_after:
            temp = re.sub(k, v, body)
            if temp == u" " or temp == u"":
                skip = True

        # do some more subsitutions
        if not skip:
            for k, v in pat2:
                body = re.sub(k, v, body)

        # if empty string, skip
        if body == u'' or body == u' ':
            skip = True

        if not skip:
            return body
        else:
            return u""

def load_tsv(data_file, n):
    data_features = list()
    data = list()
    # infile = open(data_file, encoding='utf-8')

    infile = data_file.to_numpy()
    for line in infile:
        # if not line.strip():
        #     continue
        
        # text,label = line.split(',')
        text,label = line
        text = clean_raw_review(text)
        text_features = process_text(text, n)
        if text_features:
            text_features = [s for s in text_features if s and len(s)>1 and s not in stopwords_list]
            if not text_features:
              continue
            # print(text_features)
            text_features = text_features +\
              rec_char_ngram(text_features,3)+\
              rec_char_ngram(text_features,4)

            data_features += text_features
            data.append((text_features, label))
        
    return data, data_features

def process_text(text, n=1,
                 remove_vowel_marks=False,
                 remove_repeated_chars=True,
                 ):
    clean_text = text
    # if remove_vowel_marks:
    #     clean_text = remove_diacritics(clean_text)
    if remove_repeated_chars:
        clean_text = remove_repeating_char(clean_text)

    if n == 1:
        return clean_text.split()
    else:
        tokens = clean_text.split()
        grams = tokens
        for i in range(2, n + 1):
            grams += [' '.join(g) for g in list(window(tokens, i))]

        return grams

def char_ngram(s, n):
  if len(s)>n:
    return [s[i:i+n] for i in range(len(s)-n+1)]
  else:
    return s

def rec_char_ngram(ls,n):
  ls = [i for i in ls if len(i)>n]
  return [j for jj in  [char_ngram(i,n) for i in ls] for j in jj]
    



def window(words_seq, n):
    """Returns a sliding window (of width n) over data from the iterable"""
    "   s -> (s0,s1,...s[n-1]), (s1,s2,...,sn), ...                   "
    it = iter(words_seq)
    result = tuple(islice(it, n))
    if len(result) == n:
        yield result
    for elem in it:
        result = result[1:] + (elem,)
        yield result


def remove_repeating_char(text):
    # return re.sub(r'(.)\1+', r'\1', text)     # keep only 1 repeat
    return re.sub(r'(.)\1+', r'\1\1', text)  # keep 2 repeat

def document_features(document, corpus_features):
    document_words = set(document)
    features = {}
    for word in corpus_features:
        features['has({})'.format(word)] = (word in document_words)
    return features
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Load corpus

# %%
for i in [1,2,4]:
  if True:
    continue
  print(i)

# %%
l = ['assds', 'asasdaads', 'asdaasd','jj']

# %%
rec_char_ngram(l,3)
# Out:
# ['ass',
#  'ssd',
#  'sds',
#  'asa',
#  'sas',
#  'asd',
#  'sda',
#  'daa',
#  'aad',
#  'ads',
#  'asd',
#  'sda',
#  'daa',
#  'aas',
#  'asd']

# %%
char_ngram('as', 4)
# Out:
# 'as'

# %%
''.join(('s','t'))
# Out:
# 'st'

# %%
char_ngram("asaddddfgg",4)
# Out:
# ['asad', 'sadd', 'addd', 'dddd', 'dddf', 'ddfg', 'dfgg']

# %%
char_ngram('student',3)
# Out:
# ['stu', 'tud', 'ude', 'den', 'ent']

# %%
df = pd.read_csv('/content/CY_train.csv')
clean_raw_review(df.iloc[6,0])
# Out:
# '  يا عيون عطشان عطشانة سهر يا قلوب تعبانة تعبانة سفر كتروا من الحب تلاقوا تلاقوا في الضلمة ألف قمر  '

# %%
# pos_train_file = '../input/train_Arabic_tweets_positive_20190413.tsv'
# neg_train_file = '../input/train_Arabic_tweets_negative_20190413.tsv'

# pos_test_file = '../input/test_Arabic_tweets_positive_20190413.tsv'
# neg_test_file = '../input/test_Arabic_tweets_negative_20190413.tsv'
# print('data files')
# print('train file (pos)', pos_train_file)
# print('train file (neg)', neg_train_file)
# print('test file (pos)', pos_test_file)
# print('test file (neg)', neg_test_file)

# %% [markdown]
# # Parameters (ngrams)

# %%
print('parameters')
n = 1
print('n grams:', n)
# Out:
# parameters
# n grams: 1

# %% [markdown]
# # loading train data ....

# %%
# print('loading train data ....')
# pos_train_data, pos_train_feat = load_tsv(pos_train_file, n)
# neg_train_data, neg_train_feat = load_tsv(neg_train_file, n)
# print('loading test data ....')
# pos_test_data, pos_test_feat = load_tsv(pos_test_file, n)
# neg_test_data, neg_test_feat = load_tsv(neg_test_file, n)

# %% [markdown]
# # Training data information

# %%
# print('train data info')
# train_data = pos_train_data + neg_train_data
# print('train data size', len(train_data))
# print('# of positive', len(pos_train_data))
# print('# of negative', len(neg_train_data))

# %%
# train_data,feat = load_tsv('/content/CY_train.csv', n)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df,stratify=df['class'],test_size=0.2)

# %%
train['class'].value_counts()
# Out:
# pos    836
# neg    781
# neu    579
# Name: class, dtype: int64

# %%
test['class'].value_counts()
# Out:
# pos    210
# neg    195
# neu    145
# Name: class, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
m = MultinomialNB()

# %%
train_data, train_feat = load_tsv(train,n)
test_data, test_feat = load_tsv(test,n)

# %%
test_data
# Out:
# [(['سكايب',
#    'كول',
#    'ظاظا',
#    'تلت',
#    'ساعات',
#    'ونص',
#    'عشان',
#    'نخلص',
#    'سكشن',
#    'تمانية',
#    'وهنام',
#    'وش',
#    'الصبح',
#    'قحة',
#    'سكا',
#    'كاي',
#    'ايب',
#    'ظاظ',
#    'اظا',
#    'ساع',
#    'اعا',
#    'عات',
#    'عشا',
#    'شان',
#    'نخل',
#    'خلص',
#    'سكش',
#    'كشن',
#    'تما',
#    'مان',
#    'اني',
#    'نية',
#    'وهن',
#    'هنا',
#    'نام',
#    'الص',
#    'لصب',
#    'صبح',
#    'سكاي',
#    'كايب',
#    'ساعا',
#    'اعات',
#    'تمان',
#    'ماني',
#    'انية',
#    'وهنا',
#    'هنام',
#    'الصب',
#    'لصبح'],
#   'neg'),
#  (['بدات',
#    'الحن',
#    'النشيد',
#    'بدا',
#    'دات',
#    'الح',
#    'لحن',
#    'الن',
#    'لنش',
#    'نشي',
#    'شيد',
#    'النش',
#    'لنشي',
#    'نشيد'],
#   'neu'),
#  (['منا',
#    'خدت',
#    'بالي',
#    'حلوة',
#    'فعلا',
#    'انا',
#    'مش',
#    'ميال',
#    'ليها',
#    'انا',
#    'اصلا',
#    'بحب',
#    'المانفسيتو',
#    'اوي',
#    'اقوي',
#    'ويسترن',
#    'يونيون',
#    'انا',
#    'بحب',
#    'ويسترن',
#    'اكتر',
#    'بال',
#    'الي',
#    'حلو',
#    'لوة',
#    'فعل',
#    'علا',
#    'ميا',
#    'يال',
#    'ليه',
#    'يها',
#    'اصل',
#    'صلا',
#    'الم',
#    'لما',
#    'مان',
#    'انف',
#    'نفس',
#    'فسي',
#    'سيت',
#    'يتو',
#    'اقو',
#    'قوي',
#    'ويس',
#    'يست',
#    'ستر',
#    'ترن',
#    'يون',
#    'وني',
#    'نيو',
#    'يون',
#    'ويس',
#    'يست',
#    'ستر',
#    'ترن',
#    'اكت',
#    'كتر',
#    'الما',
#    'لمان',
#    'مانف',
#    'انفس',
#    'نفسي',
#    'فسيت',
#    'سيتو',
#    'ويست',
#    'يستر',
#    'سترن',
#    'يوني',
#    'ونيو',
#    'نيون',
#    'ويست',
#    'يستر',
#    'سترن'],
#   'pos'),
#  (['صباحك', 'سكرر', 'صبا', 'باح', 'احك', 'سكر', 'كرر', 'صباح', 'باحك'], 'pos'),
#  (['هتمسكوا',
#    'خناق',
#    'المصريين',
#    'كمان',
#    'مش',
#    'كنا',
#    'حبايبكوا',
#    'اول',
#    'البرنامج',
#    'اله',
#    'الا',
#    'الله',
#    'الغدر',
#    'هتم',
#    'تمس',
#    'مسك',
#    'سكو',
#    'كوا',
#    'خنا',
#    'ناق',
#    'الم',
#    'لمص',
#    'مصر',
#    'صري',
#    'ريي',
#    'يين',
#    'كما',
#    'مان',
#    'حبا',
#    'باي',
#    'ايب',
#    'يبك',
#    'بكو',
#    'كوا',
#    'الب',
#    'لبر',
#    'برن',
#    'رنا',
#    'نام',
#    'امج',
#    'الل',
#    'لله',
#    'الغ',
#    'لغد',
#    'غدر',
#    'هتمس',
#    'تمسك',
#    'مسكو',
#    'سكوا',
#    'المص',
#    'لمصر',
#    'مصري',
#    'صريي',
#    'ريين',
#    'حباي',
#    'بايب',
#    'ايبك',
#    'يبكو',
#    'بكوا',
#    'البر',
#    'لبرن',
#    'برنا',
#    'رنام',
#    'نامج',
#    'الغد',
#    'لغدر'],
#   'neg'),
#  (['بردو',
#    'بتجبلي',
#    'سيرة',
#    'المزاكرة',
#    'انت',
#    'حمار',
#    'عبدو',
#    'انت',
#    'حمار',
#    'يسطى',
#    'ايه',
#    'وسك',
#    'حوار',
#    'الطلبة',
#    'دلوقتي',
#    'فتحي',
#    'مش',
#    'معانا',
#    'برد',
#    'ردو',
#    'بتج',
#    'تجب',
#    'جبل',
#    'بلي',
#    'سير',
#    'يرة',
#    'الم',
#    'لمز',
#    'مزا',
#    'زاك',
#    'اكر',
#    'كرة',
#    'حما',
#    'مار',
#    'عبد',
#    'بدو',
#    'حما',
#    'مار',
#    'يسط',
#    'سطى',
#    'حوا',
#    'وار',
#    'الط',
#    'لطل',
#    'طلب',
#    'لبة',
#    'دلو',
#    'لوق',
#    'وقت',
#    'قتي',
#    'فتح',
#    'تحي',
#    'معا',
#    'عان',
#    'انا',
#    'بتجب',
#    'تجبل',
#    'جبلي',
#    'المز',
#    'لمزا',
#    'مزاك',
#    'زاكر',
#    'اكرة',
#    'الطل',
#    'لطلب',
#    'طلبة',
#    'دلوق',
#    'لوقت',
#    'وقتي',
#    'معان',
#    'عانا'],
#   'neg'),
#  (['نرتضى',
#    'منصور',
#    'انسان',
#    'مسئول',
#    'بالمره',
#    'مش',
#    'هتلاقى',
#    'نادى',
#    'فى',
#    'العالم',
#    'رئيسه',
#    'يطلع',
#    'يتكلم',
#    'شوية',
#    'الفرقع',
#    'بتاعته',
#    'حصل',
#    'نرت',
#    'رتض',
#    'تضى',
#    'منص',
#    'نصو',
#    'صور',
#    'انس',
#    'نسا',
#    'سان',
#    'مسئ',
#    'سئو',
#    'ئول',
#    'بال',
#    'الم',
#    'لمر',
#    'مره',
#    'هتل',
#    'تلا',
#    'لاق',
#    'اقى',
#    'ناد',
#    'ادى',
#    'الع',
#    'لعا',
#    'عال',
#    'الم',
#    'رئي',
#    'ئيس',
#    'يسه',
#    'يطل',
#    'طلع',
#    'يتك',
#    'تكل',
#    'كلم',
#    'شوي',
#    'وية',
#    'الف',
#    'لفر',
#    'فرق',
#    'رقع',
#    'بتا',
#    'تاع',
#    'اعت',
#    'عته',
#    'نرتض',
#    'رتضى',
#    'منصو',
#    'نصور',
#    'انسا',
#    'نسان',
#    'مسئو',
#    'سئول',
#    'بالم',
#    'المر',
#    'لمره',
#    'هتلا',
#    'تلاق',
#    'لاقى',
#    'العا',
#    'لعال',
#    'عالم',
#    'رئيس',
#    'ئيسه',
#    'يتكل',
#    'تكلم',
#    'الفر',
#    'لفرق',
#    'فرقع',
#    'بتاع',
#    'تاعت',
#    'اعته'],
#   'neg'),
#  (['نـجم',
#    'أرب',
#    'جوت',
#    'تالنت',
#    'بـجدارة',
#    'نـج',
#    'ـجم',
#    'تال',
#    'الن',
#    'لنت',
#    'بـج',
#    'ـجد',
#    'جدا',
#    'دار',
#    'ارة',
#    'تالن',
#    'النت',
#    'بـجد',
#    'ـجدا',
#    'جدار',
#    'دارة'],
#   'pos'),
#  (['صلاه', 'الفجر', 'صلا', 'لاه', 'الف', 'لفج', 'فجر', 'الفج', 'لفجر'], 'neu'),
#  (['فيلم',
#    'المغسلة',
#    'اشهر',
#    'فيلم',
#    'مصر',
#    'احاا',
#    'فيل',
#    'يلم',
#    'الم',
#    'لمغ',
#    'مغس',
#    'غسل',
#    'سلة',
#    'اشه',
#    'شهر',
#    'فيل',
#    'يلم',
#    'احا',
#    'حاا',
#    'المغ',
#    'لمغس',
#    'مغسل',
#    'غسلة'],
#   'neg'),
#  (['ومسائل',
#    'لمعرفة',
#    'الحوائج',
#    'تقضى',
#    'ومسائل',
#    'لقضاء',
#    'الحوائج',
#    'ومسائل',
#    'عقد',
#    'الألسنة',
#    'ومسائل',
#    'حل',
#    'المشكلات',
#    'مسائل',
#    'تسهيل',
#    'المصاعب',
#    'ومس',
#    'مسا',
#    'سائ',
#    'ائل',
#    'لمع',
#    'معر',
#    'عرف',
#    'رفة',
#    'الح',
#    'لحو',
#    'حوا',
#    'وائ',
#    'ائج',
#    'تقض',
#    'قضى',
#    'ومس',
#    'مسا',
#    'سائ',
#    'ائل',
#    'لقض',
#    'قضا',
#    'ضاء',
#    'الح',
#    'لحو',
#    'حوا',
#    'وائ',
#    'ائج',
#    'ومس',
#    'مسا',
#    'سائ',
#    'ائل',
#    'الأ',
#    'لأل',
#    'ألس',
#    'لسن',
#    'سنة',
#    'ومس',
#    'مسا',
#    'سائ',
#    'ائل',
#    'الم',
#    'لمش',
#    'مشك',
#    'شكل',
#    'كلا',
#    'لات',
#    'مسا',
#    'سائ',
#    'ائل',
#    'تسه',
#    'سهي',
#    'هيل',
#    'الم',
#    'لمص',
#    'مصا',
#    'صاع',
#    'اعب',
#    'ومسا',
#    'مسائ',
#    'سائل',
#    'لمعر',
#    'معرف',
#    'عرفة',
#    'الحو',
#    'لحوا',
#    'حوائ',
#    'وائج',
#    'ومسا',
#    'مسائ',
#    'سائل',
#    'لقضا',
#    'قضاء',
#    'الحو',
#    'لحوا',
#    'حوائ',
#    'وائج',
#    'ومسا',
#    'مسائ',
#    'سائل',
#    'الأل',
#    'لألس',
#    'ألسن',
#    'لسنة',
#    'ومسا',
#    'مسائ',
#    'سائل',
#    'المش',
#    'لمشك',
#    'مشكل',
#    'شكلا',
#    'كلات',
#    'مسائ',
#    'سائل',
#    'تسهي',
#    'سهيل',
#    'المص',
#    'لمصا',
#    'مصاع',
#    'صاعب'],
#   'neu'),
#  (['الوطن',
#    'مشاهير',
#    'العالم',
#    'يختارون',
#    'المغرب',
#    'للاحتفال',
#    'بـ',
#    'رأس',
#    'السنة',
#    'الو',
#    'لوط',
#    'وطن',
#    'مشا',
#    'شاه',
#    'اهي',
#    'هير',
#    'الع',
#    'لعا',
#    'عال',
#    'الم',
#    'يخت',
#    'ختا',
#    'تار',
#    'ارو',
#    'رون',
#    'الم',
#    'لمغ',
#    'مغر',
#    'غرب',
#    'للا',
#    'لاح',
#    'احت',
#    'حتف',
#    'تفا',
#    'فال',
#    'الس',
#    'لسن',
#    'سنة',
#    'الوط',
#    'لوطن',
#    'مشاه',
#    'شاهي',
#    'اهير',
#    'العا',
#    'لعال',
#    'عالم',
#    'يختا',
#    'ختار',
#    'تارو',
#    'ارون',
#    'المغ',
#    'لمغر',
#    'مغرب',
#    'للاح',
#    'لاحت',
#    'احتف',
#    'حتفا',
#    'تفال',
#    'السن',
#    'لسنة'],
#   'neu'),
#  (['اللهم',
#    'اجعلنا',
#    'نتقبل',
#    'الخوازيق',
#    'اعدائنا',
#    'انصرنا',
#    'بعضنا',
#    'الل',
#    'لله',
#    'لهم',
#    'اجع',
#    'جعل',
#    'علن',
#    'لنا',
#    'نتق',
#    'تقب',
#    'قبل',
#    'الخ',
#    'لخو',
#    'خوا',
#    'واز',
#    'ازي',
#    'زيق',
#    'اعد',
#    'عدا',
#    'دائ',
#    'ائن',
#    'ئنا',
#    'انص',
#    'نصر',
#    'صرن',
#    'رنا',
#    'بعض',
#    'عضن',
#    'ضنا',
#    'الله',
#    'للهم',
#    'اجعل',
#    'جعلن',
#    'علنا',
#    'نتقب',
#    'تقبل',
#    'الخو',
#    'لخوا',
#    'خواز',
#    'وازي',
#    'ازيق',
#    'اعدا',
#    'عدائ',
#    'دائن',
#    'ائنا',
#    'انصر',
#    'نصرن',
#    'صرنا',
#    'بعضن',
#    'عضنا'],
#   'neg'),
#  (['ولـو',
#    'وقـع',
#    'لـيـة',
#    'قـومـة',
#    'الاهلى',
#    'ولـ',
#    'لـو',
#    'وقـ',
#    'قـع',
#    'لـي',
#    'ـيـ',
#    'يـة',
#    'قـو',
#    'ـوم',
#    'ومـ',
#    'مـة',
#    'الا',
#    'لاه',
#    'اهل',
#    'هلى',
#    'لـيـ',
#    'ـيـة',
#    'قـوم',
#    'ـومـ',
#    'ومـة',
#    'الاه',
#    'لاهل',
#    'اهلى'],
#   'pos'),
#  (['معناته',
#    'غبي',
#    'خلص',
#    'استسلمت',
#    'معن',
#    'عنا',
#    'نات',
#    'اته',
#    'است',
#    'ستس',
#    'تسل',
#    'سلم',
#    'لمت',
#    'معنا',
#    'عنات',
#    'ناته',
#    'استس',
#    'ستسل',
#    'تسلم',
#    'سلمت'],
#   'neg'),
#  (['هاتوولي',
#    'رقم',
#    'دعاء',
#    'حاالا',
#    'لازم',
#    'تاخدوا',
#    'نصيبكوا',
#    'هات',
#    'اتو',
#    'توو',
#    'وول',
#    'ولي',
#    'دعا',
#    'عاء',
#    'حاا',
#    'اال',
#    'الا',
#    'لاز',
#    'ازم',
#    'تاخ',
#    'اخد',
#    'خدو',
#    'دوا',
#    'نصي',
#    'صيب',
#    'يبك',
#    'بكو',
#    'كوا',
#    'هاتو',
#    'اتوو',
#    'توول',
#    'وولي',
#    'حاال',
#    'االا',
#    'تاخد',
#    'اخدو',
#    'خدوا',
#    'نصيب',
#    'صيبك',
#    'يبكو',
#    'بكوا'],
#   'neu'),
#  (['احلى',
#    'محبوب',
#    'العرب',
#    'محمد',
#    'عساف',
#    'احل',
#    'حلى',
#    'محب',
#    'حبو',
#    'بوب',
#    'الع',
#    'لعر',
#    'عرب',
#    'محم',
#    'حمد',
#    'عسا',
#    'ساف',
#    'محبو',
#    'حبوب',
#    'العر',
#    'لعرب'],
#   'pos'),
#  (['سنه',
#    'وانت',
#    'طيب',
#    'ياصاحبي',
#    'وعقبال',
#    'سنه',
#    'ويارب',
#    'سنه',
#    'سعيده',
#    'وتحقق',
#    'احلامك',
#    'وان',
#    'انت',
#    'ياص',
#    'اصا',
#    'صاح',
#    'احب',
#    'حبي',
#    'وعق',
#    'عقب',
#    'قبا',
#    'بال',
#    'ويا',
#    'يار',
#    'ارب',
#    'سعي',
#    'عيد',
#    'يده',
#    'وتح',
#    'تحق',
#    'حقق',
#    'احل',
#    'حلا',
#    'لام',
#    'امك',
#    'ياصا',
#    'اصاح',
#    'صاحب',
#    'احبي',
#    'وعقب',
#    'عقبا',
#    'قبال',
#    'ويار',
#    'يارب',
#    'سعيد',
#    'عيده',
#    'وتحق',
#    'تحقق',
#    'احلا',
#    'حلام',
#    'لامك'],
#   'pos'),
#  (['السنة',
#    'ملهاش',
#    'دعوة',
#    'بنجاحك',
#    'وفشلك',
#    'والحقيقة',
#    'انك',
#    'فاشل',
#    'عشان',
#    'انت',
#    'خول',
#    'وعلق',
#    'مش',
#    'عشان',
#    'انت',
#    'سئ',
#    'الحظ',
#    'او',
#    'قوانين',
#    'الطبيعة',
#    'والزمن',
#    'بيتامروا',
#    'صانع',
#    'الساعات',
#    'الس',
#    'لسن',
#    'سنة',
#    'مله',
#    'لها',
#    'هاش',
#    'دعو',
#    'عوة',
#    'بنج',
#    'نجا',
#    'جاح',
#    'احك',
#    'وفش',
#    'فشل',
#    'شلك',
#    'وال',
#    'الح',
#    'لحق',
#    'حقي',
#    'قيق',
#    'يقة',
#    'فاش',
#    'اشل',
#    'عشا',
#    'شان',
#    'وعل',
#    'علق',
#    'عشا',
#    'شان',
#    'الح',
#    'لحظ',
#    'قوا',
#    'وان',
#    'اني',
#    'نين',
#    'الط',
#    'لطب',
#    'طبي',
#    'بيع',
#    'يعة',
#    'وال',
#    'الز',
#    'لزم',
#    'زمن',
#    'بيت',
#    'يتا',
#    'تام',
#    'امر',
#    'مرو',
#    'روا',
#    'صان',
#    'انع',
#    'الس',
#    'لسا',
#    'ساع',
#    'اعا',
#    'عات',
#    'السن',
#    'لسنة',
#    'ملها',
#    'لهاش',
#    'بنجا',
#    'نجاح',
#    'جاحك',
#    'وفشل',
#    'فشلك',
#    'والح',
#    'الحق',
#    'لحقي',
#    'حقيق',
#    'قيقة',
#    'قوان',
#    'واني',
#    'انين',
#    'الطب',
#    'لطبي',
#    'طبيع',
#    'بيعة',
#    'والز',
#    'الزم',
#    'لزمن',
#    'بيتا',
#    'يتام',
#    'تامر',
#    'امرو',
#    'مروا',
#    'السا',
#    'لساع',
#    'ساعا',
#    'اعات'],
#   'neg'),
#  (['كنت',
#    'بائس',
#    'حياتى',
#    'وحزين',
#    'الساعه',
#    'دلوقتى',
#    'متفأل',
#    'ومبسوط',
#    'فشخ',
#    'مغير',
#    'حوال',
#    'بائ',
#    'ائس',
#    'حيا',
#    'يات',
#    'اتى',
#    'وحز',
#    'حزي',
#    'زين',
#    'الس',
#    'لسا',
#    'ساع',
#    'اعه',
#    'دلو',
#    'لوق',
#    'وقت',
#    'قتى',
#    'متف',
#    'تفأ',
#    'فأل',
#    'ومب',
#    'مبس',
#    'بسو',
#    'سوط',
#    'مغي',
#    'غير',
#    'حوا',
#    'وال',
#    'حيات',
#    'ياتى',
#    'وحزي',
#    'حزين',
#    'السا',
#    'لساع',
#    'ساعه',
#    'دلوق',
#    'لوقت',
#    'وقتى',
#    'متفأ',
#    'تفأل',
#    'ومبس',
#    'مبسو',
#    'بسوط'],
#   'pos'),
#  (['القعدة',
#    'الصحاب',
#    'بالدنيا',
#    'الق',
#    'لقع',
#    'قعد',
#    'عدة',
#    'الص',
#    'لصح',
#    'صحا',
#    'حاب',
#    'بال',
#    'الد',
#    'لدن',
#    'دني',
#    'نيا',
#    'القع',
#    'لقعد',
#    'قعدة',
#    'الصح',
#    'لصحا',
#    'صحاب',
#    'بالد',
#    'الدن',
#    'لدني',
#    'دنيا'],
#   'pos'),
#  (['انا',
#    'حقوق',
#    'اهو',
#    'ميرفت',
#    'حقو',
#    'قوق',
#    'مير',
#    'يرف',
#    'رفت',
#    'ميرف',
#    'يرفت'],
#   'neu'),
#  (['ككلمت',
#    'ايلي',
#    'طمني',
#    'وخلاني',
#    'اككلمه',
#    'امبارح',
#    'ككل',
#    'كلم',
#    'لمت',
#    'ايل',
#    'يلي',
#    'طمن',
#    'مني',
#    'وخل',
#    'خلا',
#    'لان',
#    'اني',
#    'اكك',
#    'ككل',
#    'كلم',
#    'لمه',
#    'امب',
#    'مبا',
#    'بار',
#    'ارح',
#    'ككلم',
#    'كلمت',
#    'وخلا',
#    'خلان',
#    'لاني',
#    'اككل',
#    'ككلم',
#    'كلمه',
#    'امبا',
#    'مبار',
#    'بارح'],
#   'pos'),
#  (['دوله',
#    'المشروع',
#    'الحضاري',
#    'الفساد',
#    'فاق',
#    'حد',
#    'التصور',
#    'والان',
#    'ال',
#    'دول',
#    'وله',
#    'الم',
#    'لمش',
#    'مشر',
#    'شرو',
#    'روع',
#    'الح',
#    'لحض',
#    'حضا',
#    'ضار',
#    'اري',
#    'الف',
#    'لفس',
#    'فسا',
#    'ساد',
#    'الت',
#    'لتص',
#    'تصو',
#    'صور',
#    'وال',
#    'الا',
#    'لان',
#    'المش',
#    'لمشر',
#    'مشرو',
#    'شروع',
#    'الحض',
#    'لحضا',
#    'حضار',
#    'ضاري',
#    'الفس',
#    'لفسا',
#    'فساد',
#    'التص',
#    'لتصو',
#    'تصور',
#    'والا',
#    'الان'],
#   'neg'),
#  (['الأمل',
#    'الغد',
#    'عاش',
#    'المظلوم',
#    'اليوم',
#    'الأ',
#    'لأم',
#    'أمل',
#    'الغ',
#    'لغد',
#    'الم',
#    'لمظ',
#    'مظل',
#    'ظلو',
#    'لوم',
#    'الي',
#    'ليو',
#    'يوم',
#    'الأم',
#    'لأمل',
#    'المظ',
#    'لمظل',
#    'مظلو',
#    'ظلوم',
#    'اليو',
#    'ليوم'],
#   'pos'),
#  (['إله',
#    'سبحانك',
#    'اني',
#    'كنت',
#    'الظالمين',
#    'سبح',
#    'بحا',
#    'حان',
#    'انك',
#    'الظ',
#    'لظا',
#    'ظال',
#    'الم',
#    'لمي',
#    'مين',
#    'سبحا',
#    'بحان',
#    'حانك',
#    'الظا',
#    'لظال',
#    'ظالم',
#    'المي',
#    'لمين'],
#   'pos'),
#  (['لاتبكي',
#    'علي',
#    'شئ',
#    'فكل',
#    'ذاهب',
#    'فالحب',
#    'كالموت',
#    'لايعرف',
#    'مذاهب',
#    'لات',
#    'اتب',
#    'تبك',
#    'بكي',
#    'ذاه',
#    'اهب',
#    'فال',
#    'الح',
#    'لحب',
#    'كال',
#    'الم',
#    'لمو',
#    'موت',
#    'لاي',
#    'ايع',
#    'يعر',
#    'عرف',
#    'مذا',
#    'ذاه',
#    'اهب',
#    'لاتب',
#    'اتبك',
#    'تبكي',
#    'فالح',
#    'الحب',
#    'كالم',
#    'المو',
#    'لموت',
#    'لايع',
#    'ايعر',
#    'يعرف',
#    'مذاه',
#    'ذاهب'],
#   'neu'),
#  (['قرارت',
#    'حاسمه',
#    'شخص',
#    'يعتمد',
#    'مكنتش',
#    'عايز',
#    'تعزمه',
#    'ظالم',
#    'قرا',
#    'رار',
#    'ارت',
#    'حاس',
#    'اسم',
#    'سمه',
#    'يعت',
#    'عتم',
#    'تمد',
#    'مكن',
#    'كنت',
#    'نتش',
#    'عاي',
#    'ايز',
#    'تعز',
#    'عزم',
#    'زمه',
#    'ظال',
#    'الم',
#    'قرار',
#    'رارت',
#    'حاسم',
#    'اسمه',
#    'يعتم',
#    'عتمد',
#    'مكنت',
#    'كنتش',
#    'تعزم',
#    'عزمه'],
#   'neg'),
#  (['دي',
#    'تصحيك',
#    'النوم',
#    'تصح',
#    'صحي',
#    'حيك',
#    'الن',
#    'لنو',
#    'نوم',
#    'تصحي',
#    'صحيك',
#    'النو',
#    'لنوم'],
#   'neu'),
#  (['صح', 'جدآ'], 'pos'),
#  (['سعيد',
#    'دفاع',
#    'هجوم',
#    'اوت',
#    'تكملة',
#    'عدد',
#    'للفريق',
#    'سعي',
#    'عيد',
#    'دفا',
#    'فاع',
#    'هجو',
#    'جوم',
#    'تكم',
#    'كمل',
#    'ملة',
#    'للف',
#    'لفر',
#    'فري',
#    'ريق',
#    'تكمل',
#    'كملة',
#    'للفر',
#    'لفري',
#    'فريق'],
#   'neg'),
#  (['آلل',
#    'إجعلن',
#    'يقآل',
#    'آلجن',
#    'آلتي',
#    'تم',
#    'وعد',
#    'إجع',
#    'جعل',
#    'علن',
#    'يقآ',
#    'قآل',
#    'آلج',
#    'لجن',
#    'آلت',
#    'لتي',
#    'إجعل',
#    'جعلن'],
#   'neu'),
#  (['حبيبتى',
#    'تسلمى',
#    'امين',
#    'يارب',
#    'حبي',
#    'بيب',
#    'يبت',
#    'بتى',
#    'تسل',
#    'سلم',
#    'لمى',
#    'امي',
#    'مين',
#    'يار',
#    'ارب',
#    'حبيب',
#    'بيبت',
#    'يبتى',
#    'تسلم',
#    'سلمى'],
#   'pos'),
#  (['مينا',
#    'فخر',
#    'العرب',
#    'عايزين',
#    'مينا',
#    'تويتر',
#    'يامينا',
#    'وكل',
#    'ليا',
#    'حياة',
#    'قلبى',
#    'ونور',
#    'عينى',
#    'فينك',
#    'يامينو',
#    'وحشتنا',
#    'اووى',
#    'مين',
#    'ينا',
#    'الع',
#    'لعر',
#    'عرب',
#    'عاي',
#    'ايز',
#    'يزي',
#    'زين',
#    'مين',
#    'ينا',
#    'توي',
#    'ويت',
#    'يتر',
#    'يام',
#    'امي',
#    'مين',
#    'ينا',
#    'حيا',
#    'ياة',
#    'قلب',
#    'لبى',
#    'ونو',
#    'نور',
#    'عين',
#    'ينى',
#    'فين',
#    'ينك',
#    'يام',
#    'امي',
#    'مين',
#    'ينو',
#    'وحش',
#    'حشت',
#    'شتن',
#    'تنا',
#    'اوو',
#    'ووى',
#    'العر',
#    'لعرب',
#    'عايز',
#    'ايزي',
#    'يزين',
#    'تويت',
#    'ويتر',
#    'يامي',
#    'امين',
#    'مينا',
#    'يامي',
#    'امين',
#    'مينو',
#    'وحشت',
#    'حشتن',
#    'شتنا'],
#   'pos'),
#  (['حيااتى',
#    'دعااء',
#    'انا',
#    'بحببك',
#    'اووى',
#    'حبيبتى',
#    'مستنياكى',
#    'ناار',
#    'حيا',
#    'ياا',
#    'اات',
#    'اتى',
#    'دعا',
#    'عاا',
#    'ااء',
#    'بحب',
#    'حبب',
#    'ببك',
#    'اوو',
#    'ووى',
#    'حبي',
#    'بيب',
#    'يبت',
#    'بتى',
#    'مست',
#    'ستن',
#    'تني',
#    'نيا',
#    'ياك',
#    'اكى',
#    'ناا',
#    'اار',
#    'حياا',
#    'ياات',
#    'ااتى',
#    'دعاا',
#    'عااء',
#    'بحبب',
#    'حببك',
#    'حبيب',
#    'بيبت',
#    'يبتى',
#    'مستن',
#    'ستني',
#    'تنيا',
#    'نياك',
#    'ياكى'],
#   'pos'),
#  (['النملة',
#    'أصغر',
#    'وللا',
#    'البرغوت',
#    'التمر',
#    'حنة',
#    'القملة',
#    'السمسمة',
#    'الن',
#    'لنم',
#    'نمل',
#    'ملة',
#    'أصغ',
#    'صغر',
#    'ولل',
#    'للا',
#    'الب',
#    'لبر',
#    'برغ',
#    'رغو',
#    'غوت',
#    'الت',
#    'لتم',
#    'تمر',
#    'الق',
#    'لقم',
#    'قمل',
#    'ملة',
#    'الس',
#    'لسم',
#    'سمس',
#    'مسم',
#    'سمة',
#    'النم',
#    'لنمل',
#    'نملة',
#    'البر',
#    'لبرغ',
#    'برغو',
#    'رغوت',
#    'التم',
#    'لتمر',
#    'القم',
#    'لقمل',
#    'قملة',
#    'السم',
#    'لسمس',
#    'سمسم',
#    'مسمة'],
#   'neu'),
#  (['ينضم',
#    'لجماعة',
#    'خوان',
#    'غبي',
#    'أذكر',
#    'أمامة',
#    'السيسي',
#    'محمد',
#    'بن',
#    'زايد',
#    'عبد',
#    'الله',
#    'وسينهار',
#    'وينكشف',
#    'ويظهر',
#    'انتمائه',
#    'للخرفان',
#    'ينض',
#    'نضم',
#    'لجم',
#    'جما',
#    'ماع',
#    'اعة',
#    'خوا',
#    'وان',
#    'أذك',
#    'ذكر',
#    'أما',
#    'مام',
#    'امة',
#    'الس',
#    'لسي',
#    'سيس',
#    'يسي',
#    'محم',
#    'حمد',
#    'زاي',
#    'ايد',
#    'الل',
#    'لله',
#    'وسي',
#    'سين',
#    'ينه',
#    'نها',
#    'هار',
#    'وين',
#    'ينك',
#    'نكش',
#    'كشف',
#    'ويظ',
#    'يظه',
#    'ظهر',
#    'انت',
#    'نتم',
#    'تما',
#    'مائ',
#    'ائه',
#    'للخ',
#    'لخر',
#    'خرف',
#    'رفا',
#    'فان',
#    'لجما',
#    'جماع',
#    'ماعة',
#    'أمام',
#    'مامة',
#    'السي',
#    'لسيس',
#    'سيسي',
#    'وسين',
#    'سينه',
#    'ينها',
#    'نهار',
#    'وينك',
#    'ينكش',
#    'نكشف',
#    'ويظه',
#    'يظهر',
#    'انتم',
#    'نتما',
#    'تمائ',
#    'مائه',
#    'للخر',
#    'لخرف',
#    'خرفا',
#    'رفان'],
#   'neg'),
#  (['يخربيت',
#    'المسا',
#    'يخر',
#    'خرب',
#    'ربي',
#    'بيت',
#    'الم',
#    'لمس',
#    'مسا',
#    'يخرب',
#    'خربي',
#    'ربيت',
#    'المس',
#    'لمسا'],
#   'neg'),
#  (['فأن',
#    'الصبر',
#    'للأحرار',
#    'زادا',
#    'وانا',
#    'ذاد',
#    'البلاء',
#    'لزادوا',
#    'الص',
#    'لصب',
#    'صبر',
#    'للأ',
#    'لأح',
#    'أحر',
#    'حرا',
#    'رار',
#    'زاد',
#    'ادا',
#    'وان',
#    'انا',
#    'الب',
#    'لبل',
#    'بلا',
#    'لاء',
#    'لزا',
#    'زاد',
#    'ادو',
#    'دوا',
#    'الصب',
#    'لصبر',
#    'للأح',
#    'لأحر',
#    'أحرا',
#    'حرار',
#    'البل',
#    'لبلا',
#    'بلاء',
#    'لزاد',
#    'زادو',
#    'ادوا'],
#   'pos'),
#  (['روعة', 'روع', 'وعة'], 'pos'),
#  (['وانا',
#    'ليه',
#    'اصحي',
#    'الساعه',
#    'الصبح',
#    'عشان',
#    'انزل',
#    'درس',
#    'ليه',
#    'هه',
#    'وان',
#    'انا',
#    'اصح',
#    'صحي',
#    'الس',
#    'لسا',
#    'ساع',
#    'اعه',
#    'الص',
#    'لصب',
#    'صبح',
#    'عشا',
#    'شان',
#    'انز',
#    'نزل',
#    'السا',
#    'لساع',
#    'ساعه',
#    'الصب',
#    'لصبح'],
#   'neg'),
#  (['خيانة',
#    'وكدب',
#    'خد',
#    'عندك',
#    'تلاقي',
#    'كتير',
#    'خيا',
#    'يان',
#    'انة',
#    'وكد',
#    'كدب',
#    'عند',
#    'ندك',
#    'تلا',
#    'لاق',
#    'اقي',
#    'كتي',
#    'تير',
#    'خيان',
#    'يانة',
#    'تلاق',
#    'لاقي'],
#   'neg'),
#  (['التريند',
#    'ماله',
#    'اهبل',
#    'كده',
#    'تفاهه',
#    'الت',
#    'لتر',
#    'تري',
#    'رين',
#    'يند',
#    'مال',
#    'اله',
#    'اهب',
#    'هبل',
#    'تفا',
#    'فاه',
#    'اهه',
#    'التر',
#    'لتري',
#    'ترين',
#    'ريند',
#    'تفاه',
#    'فاهه'],
#   'neg'),
#  (['امتحانى',
#    'بكره',
#    'كده',
#    'امت',
#    'متح',
#    'تحا',
#    'حان',
#    'انى',
#    'بكر',
#    'كره',
#    'امتح',
#    'متحا',
#    'تحان',
#    'حانى'],
#   'neu'),
#  (['قاعدة',
#    'الصحاب',
#    'نص',
#    'الاسبوع',
#    'بتقرب',
#    'اكتر',
#    'قاعدة',
#    'اخر',
#    'الأسبوع',
#    'قاع',
#    'اعد',
#    'عدة',
#    'الص',
#    'لصح',
#    'صحا',
#    'حاب',
#    'الا',
#    'لاس',
#    'اسب',
#    'سبو',
#    'بوع',
#    'بتق',
#    'تقر',
#    'قرب',
#    'اكت',
#    'كتر',
#    'قاع',
#    'اعد',
#    'عدة',
#    'الأ',
#    'لأس',
#    'أسب',
#    'سبو',
#    'بوع',
#    'قاعد',
#    'اعدة',
#    'الصح',
#    'لصحا',
#    'صحاب',
#    'الاس',
#    'لاسب',
#    'اسبو',
#    'سبوع',
#    'بتقر',
#    'تقرب',
#    'قاعد',
#    'اعدة',
#    'الأس',
#    'لأسب',
#    'أسبو',
#    'سبوع'],
#   'neu'),
#  (['اخ',
#    'اشي',
#    'برفع',
#    'الضغط',
#    'قال',
#    'انا',
#    'قضيت',
#    'ابوي',
#    'السي',
#    'دي',
#    'اغاني',
#    'وطنيه',
#    'برف',
#    'رفع',
#    'الض',
#    'لضغ',
#    'ضغط',
#    'قضي',
#    'ضيت',
#    'ابو',
#    'بوي',
#    'الس',
#    'لسي',
#    'اغا',
#    'غان',
#    'اني',
#    'وطن',
#    'طني',
#    'نيه',
#    'الضغ',
#    'لضغط',
#    'اغان',
#    'غاني',
#    'وطني',
#    'طنيه'],
#   'neg'),
#  (['حبيبتى',
#    'انتى',
#    'ربنا',
#    'يقومك',
#    'بالسلامه',
#    'ويشفيكى',
#    'يارب',
#    'اول',
#    'تطلعى',
#    'طمنينى',
#    'عليكى',
#    'حبي',
#    'بيب',
#    'يبت',
#    'بتى',
#    'انت',
#    'نتى',
#    'ربن',
#    'بنا',
#    'يقو',
#    'قوم',
#    'ومك',
#    'بال',
#    'الس',
#    'لسل',
#    'سلا',
#    'لام',
#    'امه',
#    'ويش',
#    'يشف',
#    'شفي',
#    'فيك',
#    'يكى',
#    'يار',
#    'ارب',
#    'تطل',
#    'طلع',
#    'لعى',
#    'طمن',
#    'مني',
#    'نين',
#    'ينى',
#    'علي',
#    'ليك',
#    'يكى',
#    'حبيب',
#    'بيبت',
#    'يبتى',
#    'يقوم',
#    'قومك',
#    'بالس',
#    'السل',
#    'لسلا',
#    'سلام',
#    'لامه',
#    'ويشف',
#    'يشفي',
#    'شفيك',
#    'فيكى',
#    'تطلع',
#    'طلعى',
#    'طمني',
#    'منين',
#    'نينى',
#    'عليك',
#    'ليكى'],
#   'pos'),
#  (['الورد',
#    'جميل',
#    'السودان',
#    'سلام',
#    'الو',
#    'لور',
#    'ورد',
#    'جمي',
#    'ميل',
#    'الس',
#    'لسو',
#    'سود',
#    'ودا',
#    'دان',
#    'سلا',
#    'لام',
#    'الور',
#    'لورد',
#    'السو',
#    'لسود',
#    'سودا',
#    'ودان'],
#   'pos'),
#  (['ربنا',
#    'ادنا',
#    'العقل',
#    'عشان',
#    'نفكربي',
#    'عشان',
#    'كده',
#    'ماناخد',
#    'اي',
#    'قرار',
#    'حياتنا',
#    'لازم',
#    'نفكر',
#    'كويس',
#    'منتسرعش',
#    'حتي',
#    'احنا',
#    'شخصيات',
#    'متسرعه',
#    'يوم',
#    'ماناخد',
#    'القرار',
#    'نفكر',
#    'ربن',
#    'بنا',
#    'ادن',
#    'دنا',
#    'الع',
#    'لعق',
#    'عقل',
#    'عشا',
#    'شان',
#    'نفك',
#    'فكر',
#    'كرب',
#    'ربي',
#    'عشا',
#    'شان',
#    'مان',
#    'انا',
#    'ناخ',
#    'اخد',
#    'قرا',
#    'رار',
#    'حيا',
#    'يات',
#    'اتن',
#    'تنا',
#    'لاز',
#    'ازم',
#    'نفك',
#    'فكر',
#    'كوي',
#    'ويس',
#    'منت',
#    'نتس',
#    'تسر',
#    'سرع',
#    'رعش',
#    'احن',
#    'حنا',
#    'شخص',
#    'خصي',
#    'صيا',
#    'يات',
#    'متس',
#    'تسر',
#    'سرع',
#    'رعه',
#    'مان',
#    'انا',
#    'ناخ',
#    'اخد',
#    'الق',
#    'لقر',
#    'قرا',
#    'رار',
#    'نفك',
#    'فكر',
#    'العق',
#    'لعقل',
#    'نفكر',
#    'فكرب',
#    'كربي',
#    'مانا',
#    'اناخ',
#    'ناخد',
#    'حيات',
#    'ياتن',
#    'اتنا',
#    'منتس',
#    'نتسر',
#    'تسرع',
#    'سرعش',
#    'شخصي',
#    'خصيا',
#    'صيات',
#    'متسر',
#    'تسرع',
#    'سرعه',
#    'مانا',
#    'اناخ',
#    'ناخد',
#    'القر',
#    'لقرا',
#    'قرار'],
#   'neu'),
#  (['اهبل',
#    'انتبتلعب',
#    'عداد',
#    'عمرك',
#    'عبهادي',
#    'انا',
#    'برده',
#    'منور',
#    'اهب',
#    'هبل',
#    'انت',
#    'نتب',
#    'تبت',
#    'بتل',
#    'تلع',
#    'لعب',
#    'عدا',
#    'داد',
#    'عمر',
#    'مرك',
#    'عبه',
#    'بها',
#    'هاد',
#    'ادي',
#    'برد',
#    'رده',
#    'منو',
#    'نور',
#    'انتب',
#    'نتبت',
#    'تبتل',
#    'بتلع',
#    'تلعب',
#    'عبها',
#    'بهاد',
#    'هادي'],
#   'neg'),
#  (['الله', 'والله', 'الل', 'لله', 'وال', 'الل', 'لله', 'والل', 'الله'], 'pos'),
#  (['تقريبا',
#    'خلاص',
#    'كدة',
#    'تقر',
#    'قري',
#    'ريب',
#    'يبا',
#    'خلا',
#    'لاص',
#    'تقري',
#    'قريب',
#    'ريبا'],
#   'neu'),
#  (['وانت',
#    'بالف',
#    'خير',
#    'ميرسى',
#    'احمد',
#    'وان',
#    'انت',
#    'بال',
#    'الف',
#    'مير',
#    'يرس',
#    'رسى',
#    'احم',
#    'حمد',
#    'ميرس',
#    'يرسى'],
#   'pos'),
#  (['جولين',
#    'ولاد',
#    'الوثخه',
#    'حكام',
#    'معرصين',
#    'صحيح',
#    'جول',
#    'ولي',
#    'لين',
#    'ولا',
#    'لاد',
#    'الو',
#    'لوث',
#    'وثخ',
#    'ثخه',
#    'حكا',
#    'كام',
#    'معر',
#    'عرص',
#    'رصي',
#    'صين',
#    'صحي',
#    'حيح',
#    'جولي',
#    'ولين',
#    'الوث',
#    'لوثخ',
#    'وثخه',
#    'معرص',
#    'عرصي',
#    'رصين'],
#   'neg'),
#  (['الخير',
#    'شارك',
#    'هشتاج',
#    'ازاي',
#    'نساعدك',
#    'مصر',
#    'الخ',
#    'لخي',
#    'خير',
#    'شار',
#    'ارك',
#    'هشت',
#    'شتا',
#    'تاج',
#    'ازا',
#    'زاي',
#    'نسا',
#    'ساع',
#    'اعد',
#    'عدك',
#    'الخي',
#    'لخير',
#    'هشتا',
#    'شتاج',
#    'نساع',
#    'ساعد',
#    'اعدك'],
#   'neu'),
#  (['ايد', 'تقيله', 'معلش', 'تقي', 'قيل', 'يله', 'معل', 'علش', 'تقيل', 'قيله'],
#   'neg'),
#  (['جاريدو',
#    'مش',
#    'مدرب',
#    'ده',
#    'بتاع',
#    'بطيخ',
#    'فضحتنا',
#    'ليه',
#    'تشمت',
#    'فينا',
#    'الزملكاويه',
#    'اللي',
#    'اصلا',
#    'متعودين',
#    'الخساره',
#    'ليــه',
#    'كــدا',
#    'يااخي',
#    'دي',
#    'عمرها',
#    'ماحصلت',
#    'جار',
#    'اري',
#    'ريد',
#    'يدو',
#    'مدر',
#    'درب',
#    'بتا',
#    'تاع',
#    'بطي',
#    'طيخ',
#    'فضح',
#    'ضحت',
#    'حتن',
#    'تنا',
#    'تشم',
#    'شمت',
#    'فين',
#    'ينا',
#    'الز',
#    'لزم',
#    'زمل',
#    'ملك',
#    'لكا',
#    'كاو',
#    'اوي',
#    'ويه',
#    'الل',
#    'للي',
#    'اصل',
#    'صلا',
#    'متع',
#    'تعو',
#    'عود',
#    'ودي',
#    'دين',
#    'الخ',
#    'لخس',
#    'خسا',
#    'سار',
#    'اره',
#    'ليـ',
#    'يــ',
#    'ــه',
#    'كــ',
#    'ــد',
#    'ـدا',
#    'ياا',
#    'ااخ',
#    'اخي',
#    'عمر',
#    'مره',
#    'رها',
#    'ماح',
#    'احص',
#    'حصل',
#    'صلت',
#    'جاري',
#    'اريد',
#    'ريدو',
#    'فضحت',
#    'ضحتن',
#    'حتنا',
#    'الزم',
#    'لزمل',
#    'زملك',
#    'ملكا',
#    'لكاو',
#    'كاوي',
#    'اويه',
#    'متعو',
#    'تعود',
#    'عودي',
#    'ودين',
#    'الخس',
#    'لخسا',
#    'خسار',
#    'ساره',
#    'ليــ',
#    'يــه',
#    'كــد',
#    'ــدا',
#    'يااخ',
#    'ااخي',
#    'عمره',
#    'مرها',
#    'ماحص',
#    'احصل',
#    'حصلت'],
#   'neg'),
#  (['إنك',
#    'تبلغ',
#    'الدين',
#    'شيئا',
#    'توقر',
#    'الخلائق',
#    'تحتقر',
#    'احدا',
#    'الله',
#    'خلقه',
#    'يحتقره',
#    'محى',
#    'الدين',
#    'بن',
#    'عربى',
#    'تبل',
#    'بلغ',
#    'الد',
#    'لدي',
#    'دين',
#    'شيئ',
#    'يئا',
#    'توق',
#    'وقر',
#    'الخ',
#    'لخل',
#    'خلا',
#    'لائ',
#    'ائق',
#    'تحت',
#    'حتق',
#    'تقر',
#    'احد',
#    'حدا',
#    'الل',
#    'لله',
#    'خلق',
#    'لقه',
#    'يحت',
#    'حتق',
#    'تقر',
#    'قره',
#    'الد',
#    'لدي',
#    'دين',
#    'عرب',
#    'ربى',
#    'الدي',
#    'لدين',
#    'الخل',
#    'لخلا',
#    'خلائ',
#    'لائق',
#    'تحتق',
#    'حتقر',
#    'يحتق',
#    'حتقر',
#    'تقره',
#    'الدي',
#    'لدين'],
#   'neu'),
#  (['أللهم',
#    'إغفر',
#    'ولجميع',
#    'أمة',
#    'المسلمين',
#    'واشفي',
#    'مرضانا',
#    'ومرضى',
#    'المسلمين',
#    'وانصر',
#    'أهلنا',
#    'الشام',
#    'وفلسطين',
#    'والعراق',
#    'واليمن',
#    'وسائر',
#    'المسلمين',
#    'ألل',
#    'لله',
#    'لهم',
#    'إغف',
#    'غفر',
#    'ولج',
#    'لجم',
#    'جمي',
#    'ميع',
#    'الم',
#    'لمس',
#    'مسل',
#    'سلم',
#    'لمي',
#    'مين',
#    'واش',
#    'اشف',
#    'شفي',
#    'مرض',
#    'رضا',
#    'ضان',
#    'انا',
#    'ومر',
#    'مرض',
#    'رضى',
#    'الم',
#    'لمس',
#    'مسل',
#    'سلم',
#    'لمي',
#    'مين',
#    'وان',
#    'انص',
#    'نصر',
#    'أهل',
#    'هلن',
#    'لنا',
#    'الش',
#    'لشا',
#    'شام',
#    'وفل',
#    'فلس',
#    'لسط',
#    'سطي',
#    'طين',
#    'وال',
#    'الع',
#    'لعر',
#    'عرا',
#    'راق',
#    'وال',
#    'الي',
#    'ليم',
#    'يمن',
#    'وسا',
#    'سائ',
#    'ائر',
#    'الم',
#    'لمس',
#    'مسل',
#    'سلم',
#    'لمي',
#    'مين',
#    'ألله',
#    'للهم',
#    'ولجم',
#    'لجمي',
#    'جميع',
#    'المس',
#    'لمسل',
#    'مسلم',
#    'سلمي',
#    'لمين',
#    'واشف',
#    'اشفي',
#    'مرضا',
#    'رضان',
#    'ضانا',
#    'ومرض',
#    'مرضى',
#    'المس',
#    'لمسل',
#    'مسلم',
#    'سلمي',
#    'لمين',
#    'وانص',
#    'انصر',
#    'أهلن',
#    'هلنا',
#    'الشا',
#    'لشام',
#    'وفلس',
#    'فلسط',
#    'لسطي',
#    'سطين',
#    'والع',
#    'العر',
#    'لعرا',
#    'عراق',
#    'والي',
#    'اليم',
#    'ليمن',
#    'وسائ',
#    'سائر',
#    'المس',
#    'لمسل',
#    'مسلم',
#    'سلمي',
#    'لمين'],
#   'pos'),
#  (['سعيد',
#    'الشهراني',
#    'يحتاج',
#    'دعواتكم',
#    'البرنامج',
#    'الرجل',
#    'عاطل',
#    'العمل',
#    'ويبتسم',
#    'رغم',
#    'حزنه',
#    'اسأل',
#    'الله',
#    'ان',
#    'لاينتهي',
#    'البرنامج',
#    'وقد',
#    'بشر',
#    'بوظيفه',
#    'سعي',
#    'عيد',
#    'الش',
#    'لشه',
#    'شهر',
#    'هرا',
#    'ران',
#    'اني',
#    'يحت',
#    'حتا',
#    'تاج',
#    'دعو',
#    'عوا',
#    'وات',
#    'اتك',
#    'تكم',
#    'الب',
#    'لبر',
#    'برن',
#    'رنا',
#    'نام',
#    'امج',
#    'الر',
#    'لرج',
#    'رجل',
#    'عاط',
#    'اطل',
#    'الع',
#    'لعم',
#    'عمل',
#    'ويب',
#    'يبت',
#    'بتس',
#    'تسم',
#    'حزن',
#    'زنه',
#    'اسأ',
#    'سأل',
#    'الل',
#    'لله',
#    'لاي',
#    'اين',
#    'ينت',
#    'نته',
#    'تهي',
#    'الب',
#    'لبر',
#    'برن',
#    'رنا',
#    'نام',
#    'امج',
#    'بوظ',
#    'وظي',
#    'ظيف',
#    'يفه',
#    'الشه',
#    'لشهر',
#    'شهرا',
#    'هران',
#    'راني',
#    'يحتا',
#    'حتاج',
#    'دعوا',
#    'عوات',
#    'واتك',
#    'اتكم',
#    'البر',
#    'لبرن',
#    'برنا',
#    'رنام',
#    'نامج',
#    'الرج',
#    'لرجل',
#    'العم',
#    'لعمل',
#    'ويبت',
#    'يبتس',
#    'بتسم',
#    'لاين',
#    'اينت',
#    'ينته',
#    'نتهي',
#    'البر',
#    'لبرن',
#    'برنا',
#    'رنام',
#    'نامج',
#    'بوظي',
#    'وظيف',
#    'ظيفه'],
#   'pos'),
#  (['درست',
#    'دين',
#    'سنين',
#    'الحمد',
#    'لله',
#    'بعرف',
#    'أتعامل',
#    'معه',
#    'درس',
#    'رست',
#    'سني',
#    'نين',
#    'الح',
#    'لحم',
#    'حمد',
#    'بعر',
#    'عرف',
#    'أتع',
#    'تعا',
#    'عام',
#    'امل',
#    'الحم',
#    'لحمد',
#    'أتعا',
#    'تعام',
#    'عامل'],
#   'pos'),
#  (['تدرى',
#    'كدا',
#    'تبقى',
#    'مخنوق',
#    'دا',
#    'اكيد',
#    'سببه',
#    'ان',
#    'انت',
#    'عبيت',
#    'وشلت',
#    'جواك',
#    'كتير',
#    'لحد',
#    'مبقاش',
#    'فى',
#    'حيز',
#    'يساع',
#    'اكتر',
#    'كدا',
#    'تدر',
#    'درى',
#    'تبق',
#    'بقى',
#    'مخن',
#    'خنو',
#    'نوق',
#    'اكي',
#    'كيد',
#    'سبب',
#    'ببه',
#    'عبي',
#    'بيت',
#    'وشل',
#    'شلت',
#    'جوا',
#    'واك',
#    'كتي',
#    'تير',
#    'مبق',
#    'بقا',
#    'قاش',
#    'يسا',
#    'ساع',
#    'اكت',
#    'كتر',
#    'مخنو',
#    'خنوق',
#    'مبقا',
#    'بقاش'],
#   'neg'),
#  (['مش',
#    'لازم',
#    'القريبين',
#    'منك',
#    'يعرفوا',
#    'كبيرة',
#    'وصغيرة',
#    'عنك',
#    'حاجات',
#    'لازم',
#    'تحتفظ',
#    'بيها',
#    'لنفسك',
#    'لاز',
#    'ازم',
#    'الق',
#    'لقر',
#    'قري',
#    'ريب',
#    'يبي',
#    'بين',
#    'يعر',
#    'عرف',
#    'رفو',
#    'فوا',
#    'كبي',
#    'بير',
#    'يرة',
#    'وصغ',
#    'صغي',
#    'غير',
#    'يرة',
#    'حاج',
#    'اجا',
#    'جات',
#    'لاز',
#    'ازم',
#    'تحت',
#    'حتف',
#    'تفظ',
#    'بيه',
#    'يها',
#    'لنف',
#    'نفس',
#    'فسك',
#    'القر',
#    'لقري',
#    'قريب',
#    'ريبي',
#    'يبين',
#    'يعرف',
#    'عرفو',
#    'رفوا',
#    'كبير',
#    'بيرة',
#    'وصغي',
#    'صغير',
#    'غيرة',
#    'حاجا',
#    'اجات',
#    'تحتف',
#    'حتفظ',
#    'لنفس',
#    'نفسك'],
#   'neu'),
#  (['ممكن',
#    'تتصل',
#    'برقم',
#    'رقمك',
#    'مقابل',
#    'قروش',
#    'للمكالمه',
#    'وتتأكد',
#    'تسجيل',
#    'بيانات',
#    'الخط',
#    'محمد',
#    'ممك',
#    'مكن',
#    'تتص',
#    'تصل',
#    'برق',
#    'رقم',
#    'رقم',
#    'قمك',
#    'مقا',
#    'قاب',
#    'ابل',
#    'قرو',
#    'روش',
#    'للم',
#    'لمك',
#    'مكا',
#    'كال',
#    'الم',
#    'لمه',
#    'وتت',
#    'تتأ',
#    'تأك',
#    'أكد',
#    'تسج',
#    'سجي',
#    'جيل',
#    'بيا',
#    'يان',
#    'انا',
#    'نات',
#    'الخ',
#    'لخط',
#    'محم',
#    'حمد',
#    'مقاب',
#    'قابل',
#    'للمك',
#    'لمكا',
#    'مكال',
#    'كالم',
#    'المه',
#    'وتتأ',
#    'تتأك',
#    'تأكد',
#    'تسجي',
#    'سجيل',
#    'بيان',
#    'يانا',
#    'انات'],
#   'neu'),
#  (['الدجاج',
#    'تشبسي',
#    'الخميس',
#    'القادم',
#    'بالتوفيق',
#    'للحكام',
#    'الد',
#    'لدج',
#    'دجا',
#    'جاج',
#    'تشب',
#    'شبس',
#    'بسي',
#    'الخ',
#    'لخم',
#    'خمي',
#    'ميس',
#    'الق',
#    'لقا',
#    'قاد',
#    'ادم',
#    'بال',
#    'الت',
#    'لتو',
#    'توف',
#    'وفي',
#    'فيق',
#    'للح',
#    'لحك',
#    'حكا',
#    'كام',
#    'الدج',
#    'لدجا',
#    'دجاج',
#    'تشبس',
#    'شبسي',
#    'الخم',
#    'لخمي',
#    'خميس',
#    'القا',
#    'لقاد',
#    'قادم',
#    'بالت',
#    'التو',
#    'لتوف',
#    'توفي',
#    'وفيق',
#    'للحك',
#    'لحكا',
#    'حكام'],
#   'neu'),
#  (['فشلنا',
#    'ادينا',
#    'حاولنا',
#    'دا',
#    'هيدي',
#    'الامل',
#    'لغيرنا',
#    'فشل',
#    'شلن',
#    'لنا',
#    'ادي',
#    'دين',
#    'ينا',
#    'حاو',
#    'اول',
#    'ولن',
#    'لنا',
#    'هيد',
#    'يدي',
#    'الا',
#    'لام',
#    'امل',
#    'لغي',
#    'غير',
#    'يرن',
#    'رنا',
#    'فشلن',
#    'شلنا',
#    'ادين',
#    'دينا',
#    'حاول',
#    'اولن',
#    'ولنا',
#    'الام',
#    'لامل',
#    'لغير',
#    'غيرن',
#    'يرنا'],
#   'pos'),
#  (['حقول',
#    'نفط',
#    'ليبيا',
#    'تحترق',
#    'حقو',
#    'قول',
#    'ليب',
#    'يبي',
#    'بيا',
#    'تحت',
#    'حتر',
#    'ترق',
#    'ليبي',
#    'يبيا',
#    'تحتر',
#    'حترق'],
#   'neu'),
#  (['ويوم',
#    'تحميها',
#    'الناس',
#    'هتبقي',
#    'انت',
#    'حياتها',
#    'ويو',
#    'يوم',
#    'تحم',
#    'حمي',
#    'ميه',
#    'يها',
#    'الن',
#    'لنا',
#    'ناس',
#    'هتب',
#    'تبق',
#    'بقي',
#    'حيا',
#    'يات',
#    'اته',
#    'تها',
#    'تحمي',
#    'حميه',
#    'ميها',
#    'النا',
#    'لناس',
#    'هتبق',
#    'تبقي',
#    'حيات',
#    'ياته',
#    'اتها'],
#   'pos'),
#  (['اتفرج',
#    'بالصور',
#    'اللبنانية',
#    'يارا',
#    'تظهر',
#    'بفستان',
#    'غريب',
#    'حفل',
#    'الكريسماس',
#    'شاهد',
#    'الصور',
#    'عبر',
#    'الرابط',
#    'اتف',
#    'تفر',
#    'فرج',
#    'بال',
#    'الص',
#    'لصو',
#    'صور',
#    'الل',
#    'للب',
#    'لبن',
#    'بنا',
#    'نان',
#    'اني',
#    'نية',
#    'يار',
#    'ارا',
#    'تظه',
#    'ظهر',
#    'بفس',
#    'فست',
#    'ستا',
#    'تان',
#    'غري',
#    'ريب',
#    'الك',
#    'لكر',
#    'كري',
#    'ريس',
#    'يسم',
#    'سما',
#    'ماس',
#    'شاه',
#    'اهد',
#    'الص',
#    'لصو',
#    'صور',
#    'الر',
#    'لرا',
#    'راب',
#    'ابط',
#    'اتفر',
#    'تفرج',
#    'بالص',
#    'الصو',
#    'لصور',
#    'اللب',
#    'للبن',
#    'لبنا',
#    'بنان',
#    'ناني',
#    'انية',
#    'بفست',
#    'فستا',
#    'ستان',
#    'الكر',
#    'لكري',
#    'كريس',
#    'ريسم',
#    'يسما',
#    'سماس',
#    'الصو',
#    'لصور',
#    'الرا',
#    'لراب',
#    'رابط'],
#   'neu'),
#  (['أستاذ',
#    'محماه',
#    'كده',
#    'ياعم',
#    'أست',
#    'ستا',
#    'تاذ',
#    'محم',
#    'حما',
#    'ماه',
#    'ياع',
#    'اعم',
#    'أستا',
#    'ستاذ',
#    'محما',
#    'حماه'],
#   'neu'),
#  (['مبحبش',
#    'سؤال',
#    'كلمة',
#    'كده',
#    'سبب',
#    'قال',
#    'مكانها',
#    'إشرح',
#    'هجاوب',
#    'عادي',
#    'رغم',
#    'ترجمتها',
#    'يعني',
#    'إشرح',
#    'الكلمة',
#    'نفسها',
#    'غبية',
#    'مبح',
#    'بحب',
#    'حبش',
#    'سؤا',
#    'ؤال',
#    'كلم',
#    'لمة',
#    'مكا',
#    'كان',
#    'انه',
#    'نها',
#    'إشر',
#    'شرح',
#    'هجا',
#    'جاو',
#    'اوب',
#    'عاد',
#    'ادي',
#    'ترج',
#    'رجم',
#    'جمت',
#    'مته',
#    'تها',
#    'يعن',
#    'عني',
#    'إشر',
#    'شرح',
#    'الك',
#    'لكل',
#    'كلم',
#    'لمة',
#    'نفس',
#    'فسه',
#    'سها',
#    'غبي',
#    'بية',
#    'مبحب',
#    'بحبش',
#    'مكان',
#    'كانه',
#    'انها',
#    'هجاو',
#    'جاوب',
#    'ترجم',
#    'رجمت',
#    'جمته',
#    'متها',
#    'الكل',
#    'لكلم',
#    'كلمة',
#    'نفسه',
#    'فسها'],
#   'neg'),
#  (['خل',
#    'المشاعر',
#    'تنام',
#    'وبالها',
#    'خالي',
#    'محد',
#    'سواك',
#    'انت',
#    'ضحكها',
#    'بكاها',
#    'لحالي',
#    'ووقتي',
#    'الحالي',
#    'مهو',
#    'حالي',
#    'والذكريات',
#    'الثقيلة',
#    'بنساها',
#    'الم',
#    'لمش',
#    'مشا',
#    'شاع',
#    'اعر',
#    'تنا',
#    'نام',
#    'وبا',
#    'بال',
#    'اله',
#    'لها',
#    'خال',
#    'الي',
#    'سوا',
#    'واك',
#    'ضحك',
#    'حكه',
#    'كها',
#    'بكا',
#    'كاه',
#    'اها',
#    'لحا',
#    'حال',
#    'الي',
#    'ووق',
#    'وقت',
#    'قتي',
#    'الح',
#    'لحا',
#    'حال',
#    'الي',
#    'حال',
#    'الي',
#    'وال',
#    'الذ',
#    'لذك',
#    'ذكر',
#    'كري',
#    'ريا',
#    'يات',
#    'الث',
#    'لثق',
#    'ثقي',
#    'قيل',
#    'يلة',
#    'بنس',
#    'نسا',
#    'ساه',
#    'اها',
#    'المش',
#    'لمشا',
#    'مشاع',
#    'شاعر',
#    'وبال',
#    'باله',
#    'الها',
#    'ضحكه',
#    'حكها',
#    'بكاه',
#    'كاها',
#    'لحال',
#    'حالي',
#    'ووقت',
#    'وقتي',
#    'الحا',
#    'لحال',
#    'حالي',
#    'والذ',
#    'الذك',
#    'لذكر',
#    'ذكري',
#    'كريا',
#    'ريات',
#    'الثق',
#    'لثقي',
#    'ثقيل',
#    'قيلة',
#    'بنسا',
#    'نساه',
#    'ساها'],
#   'pos'),
#  (['حيوان',
#    'عجيب',
#    'غريب',
#    'الله',
#    'حيو',
#    'يوا',
#    'وان',
#    'عجي',
#    'جيب',
#    'غري',
#    'ريب',
#    'الل',
#    'لله',
#    'حيوا',
#    'يوان'],
#   'neu'),
#  (['انا',
#    'قلقت',
#    'نص',
#    'ساعة',
#    'كدة',
#    'مبحلق',
#    'التويتة',
#    'ومش',
#    'عارف',
#    'ارد',
#    'اروح',
#    'شوية',
#    'وارجع',
#    'افتح',
#    'بقي',
#    'مش',
#    'عارف',
#    'اقول',
#    'ايه',
#    'قلق',
#    'لقت',
#    'ساع',
#    'اعة',
#    'مبح',
#    'بحل',
#    'حلق',
#    'الت',
#    'لتو',
#    'توي',
#    'ويت',
#    'يتة',
#    'عار',
#    'ارف',
#    'ارو',
#    'روح',
#    'شوي',
#    'وية',
#    'وار',
#    'ارج',
#    'رجع',
#    'افت',
#    'فتح',
#    'عار',
#    'ارف',
#    'اقو',
#    'قول',
#    'مبحل',
#    'بحلق',
#    'التو',
#    'لتوي',
#    'تويت',
#    'ويتة',
#    'وارج',
#    'ارجع'],
#   'neg'),
#  (['خليك',
#    'قاعد',
#    'تنسي',
#    'اللي',
#    'تنسيك',
#    'انه',
#    'إشي',
#    'تسوي',
#    'خلي',
#    'ليك',
#    'قاع',
#    'اعد',
#    'تنس',
#    'نسي',
#    'الل',
#    'للي',
#    'تنس',
#    'نسي',
#    'سيك',
#    'تسو',
#    'سوي',
#    'تنسي',
#    'نسيك'],
#   'neg'),
#  (['قاطعهم', 'وقل', 'تبا', 'قاط', 'اطع', 'طعه', 'عهم', 'قاطع', 'اطعه', 'طعهم'],
#   'neg'),
#  (['كنت', 'نايم', 'معلش', 'ناي', 'ايم', 'معل', 'علش'], 'neu'),
#  (['قلت',
#    'عاشق',
#    'ساقوني',
#    'كتير',
#    'المر',
#    'عاش',
#    'اشق',
#    'ساق',
#    'اقو',
#    'قون',
#    'وني',
#    'كتي',
#    'تير',
#    'الم',
#    'لمر',
#    'ساقو',
#    'اقون',
#    'قوني'],
#   'neg'),
#  (['اريد',
#    'عمل',
#    'اناسائق',
#    'اري',
#    'ريد',
#    'انا',
#    'ناس',
#    'اسا',
#    'سائ',
#    'ائق',
#    'اناس',
#    'ناسا',
#    'اسائ',
#    'سائق'],
#   'neu'),
#  (['البشر',
#    'تايهين',
#    'كأس',
#    'شاربين',
#    'زفتي',
#    'الب',
#    'لبش',
#    'بشر',
#    'تاي',
#    'ايه',
#    'يهي',
#    'هين',
#    'شار',
#    'ارب',
#    'ربي',
#    'بين',
#    'زفت',
#    'فتي',
#    'البش',
#    'لبشر',
#    'تايه',
#    'ايهي',
#    'يهين',
#    'شارب',
#    'اربي',
#    'ربين'],
#   'neg'),
#  (['انت',
#    'تقبل',
#    'علي',
#    'نفسك',
#    'انك',
#    'تمشي',
#    'جنب',
#    'واحدة',
#    'هب',
#    'ودب',
#    'بيبص',
#    'عليها',
#    'يشتم',
#    'فيك',
#    'تقب',
#    'قبل',
#    'نفس',
#    'فسك',
#    'تمش',
#    'مشي',
#    'واح',
#    'احد',
#    'حدة',
#    'بيب',
#    'يبص',
#    'علي',
#    'ليه',
#    'يها',
#    'يشت',
#    'شتم',
#    'واحد',
#    'احدة',
#    'عليه',
#    'ليها'],
#   'neg'),
#  (['أمريكا',
#    'داخله',
#    'مجلس',
#    'الأمن',
#    'عشان',
#    'تعمل',
#    'الفيتو',
#    'أمر',
#    'مري',
#    'ريك',
#    'يكا',
#    'داخ',
#    'اخل',
#    'خله',
#    'مجل',
#    'جلس',
#    'الأ',
#    'لأم',
#    'أمن',
#    'عشا',
#    'شان',
#    'تعم',
#    'عمل',
#    'الف',
#    'لفي',
#    'فيت',
#    'يتو',
#    'أمري',
#    'مريك',
#    'ريكا',
#    'داخل',
#    'اخله',
#    'الأم',
#    'لأمن',
#    'الفي',
#    'لفيت',
#    'فيتو'],
#   'neu'),
#  (['رب',
#    'اشفى',
#    'مريض',
#    'قولو',
#    'امين',
#    'اشف',
#    'شفى',
#    'مري',
#    'ريض',
#    'قول',
#    'ولو',
#    'امي',
#    'مين'],
#   'neu'),
#  (['شباب',
#    'رتويت',
#    'بليز',
#    'ضرورى',
#    'شبا',
#    'باب',
#    'رتو',
#    'توي',
#    'ويت',
#    'بلي',
#    'ليز',
#    'ضرو',
#    'رور',
#    'ورى',
#    'رتوي',
#    'تويت',
#    'ضرور',
#    'رورى'],
#   'neu'),
#  (['معلومه',
#    'اسم',
#    'حسن',
#    'شحاته',
#    'متطرحش',
#    'ابنه',
#    'قال',
#    'الخبر',
#    'الاعلام',
#    'الاتجاه',
#    'لمدير',
#    'فني',
#    'اجنبي',
#    'معل',
#    'علو',
#    'لوم',
#    'ومه',
#    'شحا',
#    'حات',
#    'اته',
#    'متط',
#    'تطر',
#    'طرح',
#    'رحش',
#    'ابن',
#    'بنه',
#    'الخ',
#    'لخب',
#    'خبر',
#    'الا',
#    'لاع',
#    'اعل',
#    'علا',
#    'لام',
#    'الا',
#    'لات',
#    'اتج',
#    'تجا',
#    'جاه',
#    'لمد',
#    'مدي',
#    'دير',
#    'اجن',
#    'جنب',
#    'نبي',
#    'معلو',
#    'علوم',
#    'لومه',
#    'شحات',
#    'حاته',
#    'متطر',
#    'تطرح',
#    'طرحش',
#    'الخب',
#    'لخبر',
#    'الاع',
#    'لاعل',
#    'اعلا',
#    'علام',
#    'الات',
#    'لاتج',
#    'اتجا',
#    'تجاه',
#    'لمدي',
#    'مدير',
#    'اجنب',
#    'جنبي'],
#   'neu'),
#  (['مجتمعات',
#    'مقرفه',
#    'وغبيه',
#    'ابو',
#    'بكر',
#    'الرازي',
#    'بيطعن',
#    'منطقيه',
#    'فكره',
#    'النبوه',
#    'نفسها',
#    'ومتعدمش',
#    'وكتاباته',
#    'عايشه',
#    'الى',
#    'اليوم',
#    'مجت',
#    'جتم',
#    'تمع',
#    'معا',
#    'عات',
#    'مقر',
#    'قرف',
#    'رفه',
#    'وغب',
#    'غبي',
#    'بيه',
#    'الر',
#    'لرا',
#    'راز',
#    'ازي',
#    'بيط',
#    'يطع',
#    'طعن',
#    'منط',
#    'نطق',
#    'طقي',
#    'قيه',
#    'فكر',
#    'كره',
#    'الن',
#    'لنب',
#    'نبو',
#    'بوه',
#    'نفس',
#    'فسه',
#    'سها',
#    'ومت',
#    'متع',
#    'تعد',
#    'عدم',
#    'دمش',
#    'وكت',
#    'كتا',
#    'تاب',
#    'ابا',
#    'بات',
#    'اته',
#    'عاي',
#    'ايش',
#    'يشه',
#    'الي',
#    'ليو',
#    'يوم',
#    'مجتم',
#    'جتمع',
#    'تمعا',
#    'معات',
#    'مقرف',
#    'قرفه',
#    'وغبي',
#    'غبيه',
#    'الرا',
#    'لراز',
#    'رازي',
#    'بيطع',
#    'يطعن',
#    'منطق',
#    'نطقي',
#    'طقيه',
#    'النب',
#    'لنبو',
#    'نبوه',
#    'نفسه',
#    'فسها',
#    'ومتع',
#    'متعد',
#    'تعدم',
#    'عدمش',
#    'وكتا',
#    'كتاب',
#    'تابا',
#    'ابات',
#    'باته',
#    'عايش',
#    'ايشه',
#    'اليو',
#    'ليوم'],
#   'neg'),
#  (['اجدع', 'حاجه', 'اجد', 'جدع', 'حاج', 'اجه'], 'pos'),
#  (['ايه',
#    'خايف',
#    'يقول',
#    'وانا',
#    'مش',
#    'هقول',
#    'اللى',
#    'حاسه',
#    'انا',
#    'بيه',
#    'خاي',
#    'ايف',
#    'يقو',
#    'قول',
#    'وان',
#    'انا',
#    'هقو',
#    'قول',
#    'الل',
#    'للى',
#    'حاس',
#    'اسه'],
#   'neg'),
#  (['وعيش',
#    'حياتك',
#    'غيرى',
#    'وعيب',
#    'عليا',
#    'وهتها',
#    'فيا',
#    'وعي',
#    'عيش',
#    'حيا',
#    'يات',
#    'اتك',
#    'غير',
#    'يرى',
#    'وعي',
#    'عيب',
#    'علي',
#    'ليا',
#    'وهت',
#    'هته',
#    'تها',
#    'حيات',
#    'ياتك',
#    'وهته',
#    'هتها'],
#   'neg'),
#  (['اللقب',
#    'يليق',
#    'الا',
#    'شاهينوو',
#    'الل',
#    'للق',
#    'لقب',
#    'يلي',
#    'ليق',
#    'شاه',
#    'اهي',
#    'هين',
#    'ينو',
#    'نوو',
#    'اللق',
#    'للقب',
#    'شاهي',
#    'اهين',
#    'هينو',
#    'ينوو'],
#   'pos'),
#  (['دا',
#    'كلام',
#    'النجم',
#    'محمد',
#    'حماقي',
#    'ميناا',
#    'فكواليس',
#    'البرايم',
#    'الواضح',
#    'ان',
#    'حماقي',
#    'ال',
#    'عجبه',
#    'وركز',
#    'معاه',
#    'مينا',
#    'عطا',
#    'كلا',
#    'لام',
#    'الن',
#    'لنج',
#    'نجم',
#    'محم',
#    'حمد',
#    'حما',
#    'ماق',
#    'اقي',
#    'مين',
#    'ينا',
#    'ناا',
#    'فكو',
#    'كوا',
#    'وال',
#    'الي',
#    'ليس',
#    'الب',
#    'لبر',
#    'برا',
#    'راي',
#    'ايم',
#    'الو',
#    'لوا',
#    'واض',
#    'اضح',
#    'حما',
#    'ماق',
#    'اقي',
#    'عجب',
#    'جبه',
#    'ورك',
#    'ركز',
#    'معا',
#    'عاه',
#    'مين',
#    'ينا',
#    'النج',
#    'لنجم',
#    'حماق',
#    'ماقي',
#    'مينا',
#    'يناا',
#    'فكوا',
#    'كوال',
#    'والي',
#    'اليس',
#    'البر',
#    'لبرا',
#    'براي',
#    'رايم',
#    'الوا',
#    'لواض',
#    'واضح',
#    'حماق',
#    'ماقي'],
#   'pos'),
#  (['استاد',
#    'موجود',
#    'الحرية',
#    'لجمهور',
#    'الزمالك',
#    'است',
#    'ستا',
#    'تاد',
#    'موج',
#    'وجو',
#    'جود',
#    'الح',
#    'لحر',
#    'حري',
#    'رية',
#    'لجم',
#    'جمه',
#    'مهو',
#    'هور',
#    'الز',
#    'لزم',
#    'زما',
#    'مال',
#    'الك',
#    'استا',
#    'ستاد',
#    'موجو',
#    'وجود',
#    'الحر',
#    'لحري',
#    'حرية',
#    'لجمه',
#    'جمهو',
#    'مهور',
#    'الزم',
#    'لزما',
#    'زمال',
#    'مالك'],
#   'pos'),
#  (['مــش',
#    'قادريــن',
#    'نصــدق',
#    'انه',
#    'هييــجي',
#    'يوم',
#    'ونبــكي',
#    'الفــرحة',
#    'علــى',
#    'غياب',
#    'نفــس',
#    'الحــاجة',
#    'اللي',
#    'بكينا',
#    'عليها',
#    'ليــالي',
#    'مــ',
#    'ــش',
#    'قاد',
#    'ادر',
#    'دري',
#    'ريـ',
#    'يــ',
#    'ــن',
#    'نصـ',
#    'صــ',
#    'ــد',
#    'ـدق',
#    'هيي',
#    'ييـ',
#    'يــ',
#    'ــج',
#    'ـجي',
#    'ونب',
#    'نبـ',
#    'بــ',
#    'ــك',
#    'ـكي',
#    'الف',
#    'لفـ',
#    'فــ',
#    'ــر',
#    'ـرح',
#    'رحة',
#    'علـ',
#    'لــ',
#    'ــى',
#    'غيا',
#    'ياب',
#    'نفـ',
#    'فــ',
#    'ــس',
#    'الح',
#    'لحـ',
#    'حــ',
#    'ــا',
#    'ـاج',
#    'اجة',
#    'الل',
#    'للي',
#    'بكي',
#    'كين',
#    'ينا',
#    'علي',
#    'ليه',
#    'يها',
#    'ليـ',
#    'يــ',
#    'ــا',
#    'ـال',
#    'الي',
#    'قادر',
#    'ادري',
#    'دريـ',
#    'ريــ',
#    'يــن',
#    'نصــ',
#    'صــد',
#    'ــدق',
#    'هييـ',
#    'ييــ',
#    'يــج',
#    'ــجي',
#    'ونبـ',
#    'نبــ',
#    'بــك',
#    'ــكي',
#    'الفـ',
#    'لفــ',
#    'فــر',
#    'ــرح',
#    'ـرحة',
#    'علــ',
#    'لــى',
#    'نفــ',
#    'فــس',
#    'الحـ',
#    'لحــ',
#    'حــا',
#    'ــاج',
#    'ـاجة',
#    'بكين',
#    'كينا',
#    'عليه',
#    'ليها',
#    'ليــ',
#    'يــا',
#    'ــال',
#    'ـالي'],
#   'pos'),
#  (['يارب',
#    'استاذه',
#    'لمياء',
#    'شاهين',
#    'ياخد',
#    'اللقب',
#    'انتى',
#    'مش',
#    'مصريه',
#    'صح',
#    'اهلا',
#    'بحضرتك',
#    'فى',
#    'مصر',
#    'يار',
#    'ارب',
#    'است',
#    'ستا',
#    'تاذ',
#    'اذه',
#    'لمي',
#    'ميا',
#    'ياء',
#    'شاه',
#    'اهي',
#    'هين',
#    'ياخ',
#    'اخد',
#    'الل',
#    'للق',
#    'لقب',
#    'انت',
#    'نتى',
#    'مصر',
#    'صري',
#    'ريه',
#    'اهل',
#    'هلا',
#    'بحض',
#    'حضر',
#    'ضرت',
#    'رتك',
#    'استا',
#    'ستاذ',
#    'تاذه',
#    'لميا',
#    'مياء',
#    'شاهي',
#    'اهين',
#    'اللق',
#    'للقب',
#    'مصري',
#    'صريه',
#    'بحضر',
#    'حضرت',
#    'ضرتك'],
#   'pos'),
#  (['يتري',
#    'الحاجات',
#    'ال',
#    'خيالي',
#    'ممكن',
#    'يوم',
#    'تحصل',
#    'يتر',
#    'تري',
#    'الح',
#    'لحا',
#    'حاج',
#    'اجا',
#    'جات',
#    'خيا',
#    'يال',
#    'الي',
#    'ممك',
#    'مكن',
#    'تحص',
#    'حصل',
#    'الحا',
#    'لحاج',
#    'حاجا',
#    'اجات',
#    'خيال',
#    'يالي'],
#   'neu'),
#  (['ابنى',
#    'انتو',
#    'زمالك',
#    'مين',
#    'وانبى',
#    'مين',
#    'لسه',
#    'فاضل',
#    'ماتش',
#    'الدورى',
#    'بتاعنا',
#    'خروف',
#    'منك',
#    'ليه',
#    'هلى',
#    'ابن',
#    'بنى',
#    'انت',
#    'نتو',
#    'زما',
#    'مال',
#    'الك',
#    'وان',
#    'انب',
#    'نبى',
#    'فاض',
#    'اضل',
#    'مات',
#    'اتش',
#    'الد',
#    'لدو',
#    'دور',
#    'ورى',
#    'بتا',
#    'تاع',
#    'اعن',
#    'عنا',
#    'خرو',
#    'روف',
#    'زمال',
#    'مالك',
#    'وانب',
#    'انبى',
#    'الدو',
#    'لدور',
#    'دورى',
#    'بتاع',
#    'تاعن',
#    'اعنا'],
#   'neg'),
#  (['يومك',
#    'سعيد',
#    'باءذن',
#    'الله',
#    'طيبه',
#    'القلب',
#    'ربنا',
#    'يجعل',
#    'فى',
#    'وشك',
#    'جوهره',
#    'ولسانك',
#    'سكره',
#    'يوم',
#    'ومك',
#    'سعي',
#    'عيد',
#    'باء',
#    'اءذ',
#    'ءذن',
#    'الل',
#    'لله',
#    'طيب',
#    'يبه',
#    'الق',
#    'لقل',
#    'قلب',
#    'ربن',
#    'بنا',
#    'يجع',
#    'جعل',
#    'جوه',
#    'وهر',
#    'هره',
#    'ولس',
#    'لسا',
#    'سان',
#    'انك',
#    'سكر',
#    'كره',
#    'باءذ',
#    'اءذن',
#    'القل',
#    'لقلب',
#    'جوهر',
#    'وهره',
#    'ولسا',
#    'لسان',
#    'سانك'],
#   'pos'),
#  (['زمن',
#    'الصحابة',
#    'آثر',
#    'الفقر',
#    'الطاعة',
#    'لله',
#    'ان',
#    'يسال',
#    'الناس',
#    'الحاجة',
#    'العلم',
#    'والعمل',
#    'الص',
#    'لصح',
#    'صحا',
#    'حاب',
#    'ابة',
#    'الف',
#    'لفق',
#    'فقر',
#    'الط',
#    'لطا',
#    'طاع',
#    'اعة',
#    'يسا',
#    'سال',
#    'الن',
#    'لنا',
#    'ناس',
#    'الح',
#    'لحا',
#    'حاج',
#    'اجة',
#    'الع',
#    'لعل',
#    'علم',
#    'وال',
#    'الع',
#    'لعم',
#    'عمل',
#    'الصح',
#    'لصحا',
#    'صحاب',
#    'حابة',
#    'الفق',
#    'لفقر',
#    'الطا',
#    'لطاع',
#    'طاعة',
#    'النا',
#    'لناس',
#    'الحا',
#    'لحاج',
#    'حاجة',
#    'العل',
#    'لعلم',
#    'والع',
#    'العم',
#    'لعمل'],
#   'neu'),
#  (['قصدك',
#    'مين',
#    'بيتجاهل',
#    'شيرو',
#    'قصد',
#    'صدك',
#    'بيت',
#    'يتج',
#    'تجا',
#    'جاه',
#    'اهل',
#    'شير',
#    'يرو',
#    'بيتج',
#    'يتجا',
#    'تجاه',
#    'جاهل'],
#   'neu'),
#  (['عينى',
#    'عالفوق',
#    'كتفه',
#    'هموم',
#    'جبلين',
#    'هندسة',
#    'عين',
#    'ينى',
#    'عال',
#    'الف',
#    'لفو',
#    'فوق',
#    'كتف',
#    'تفه',
#    'همو',
#    'موم',
#    'جبل',
#    'بلي',
#    'لين',
#    'هند',
#    'ندس',
#    'دسة',
#    'عالف',
#    'الفو',
#    'لفوق',
#    'جبلي',
#    'بلين',
#    'هندس',
#    'ندسة'],
#   'neg'),
#  (['وراء',
#    'فينا',
#    'بيستظرف',
#    'وعاملنا',
#    'قارنين',
#    'مش',
#    'لازم',
#    'القرنين',
#    'يكونو',
#    'مباشرين',
#    'مهو',
#    'ممكن',
#    'تكون',
#    'متجسدة',
#    'موقف',
#    'غلس',
#    'تقاطيف',
#    'حياة',
#    'ورا',
#    'راء',
#    'فين',
#    'ينا',
#    'بيس',
#    'يست',
#    'ستظ',
#    'تظر',
#    'ظرف',
#    'وعا',
#    'عام',
#    'امل',
#    'ملن',
#    'لنا',
#    'قار',
#    'ارن',
#    'رني',
#    'نين',
#    'لاز',
#    'ازم',
#    'الق',
#    'لقر',
#    'قرن',
#    'رني',
#    'نين',
#    'يكو',
#    'كون',
#    'ونو',
#    'مبا',
#    'باش',
#    'اشر',
#    'شري',
#    'رين',
#    'ممك',
#    'مكن',
#    'تكو',
#    'كون',
#    'متج',
#    'تجس',
#    'جسد',
#    'سدة',
#    'موق',
#    'وقف',
#    'تقا',
#    'قاط',
#    'اطي',
#    'طيف',
#    'حيا',
#    'ياة',
#    'بيست',
#    'يستظ',
#    'ستظر',
#    'تظرف',
#    'وعام',
#    'عامل',
#    'املن',
#    'ملنا',
#    'قارن',
#    'ارني',
#    'رنين',
#    'القر',
#    'لقرن',
#    'قرني',
#    'رنين',
#    'يكون',
#    'كونو',
#    'مباش',
#    'باشر',
#    'اشري',
#    'شرين',
#    'متجس',
#    'تجسد',
#    'جسدة',
#    'تقاط',
#    'قاطي',
#    'اطيف'],
#   'neg'),
#  (['تفتح',
#    'التلفزيون',
#    'تطلع',
#    'الحديدى',
#    'قصة',
#    'قصيرة',
#    'مرعبة',
#    'تفت',
#    'فتح',
#    'الت',
#    'لتل',
#    'تلف',
#    'لفز',
#    'فزي',
#    'زيو',
#    'يون',
#    'تطل',
#    'طلع',
#    'الح',
#    'لحد',
#    'حدي',
#    'ديد',
#    'يدى',
#    'قصي',
#    'صير',
#    'يرة',
#    'مرع',
#    'رعب',
#    'عبة',
#    'التل',
#    'لتلف',
#    'تلفز',
#    'لفزي',
#    'فزيو',
#    'زيون',
#    'الحد',
#    'لحدي',
#    'حديد',
#    'ديدى',
#    'قصير',
#    'صيرة',
#    'مرعب',
#    'رعبة'],
#   'neg'),
#  (['وانا',
#    'اشتقتلك',
#    'اووى',
#    'والله',
#    'وحشتينى',
#    'جداا',
#    'وان',
#    'انا',
#    'اشت',
#    'شتق',
#    'تقت',
#    'قتل',
#    'تلك',
#    'اوو',
#    'ووى',
#    'وال',
#    'الل',
#    'لله',
#    'وحش',
#    'حشت',
#    'شتي',
#    'تين',
#    'ينى',
#    'جدا',
#    'داا',
#    'اشتق',
#    'شتقت',
#    'تقتل',
#    'قتلك',
#    'والل',
#    'الله',
#    'وحشت',
#    'حشتي',
#    'شتين',
#    'تينى'],
#   'pos'),
#  (['اذا',
#    'بتنحاز',
#    'تماما',
#    'نحاز',
#    'فيهن',
#    'فلسطين',
#    'وحرر',
#    'بلدك',
#    'بطل',
#    'مش',
#    'تكونو',
#    'اعداء',
#    'لدولة',
#    'احتضنتكن',
#    'لعشرات',
#    'سنين',
#    'واكلتو',
#    'خيراتا',
#    'بتن',
#    'تنح',
#    'نحا',
#    'حاز',
#    'تما',
#    'مام',
#    'اما',
#    'نحا',
#    'حاز',
#    'فيه',
#    'يهن',
#    'فلس',
#    'لسط',
#    'سطي',
#    'طين',
#    'وحر',
#    'حرر',
#    'بلد',
#    'لدك',
#    'تكو',
#    'كون',
#    'ونو',
#    'اعد',
#    'عدا',
#    'داء',
#    'لدو',
#    'دول',
#    'ولة',
#    'احت',
#    'حتض',
#    'تضن',
#    'ضنت',
#    'نتك',
#    'تكن',
#    'لعش',
#    'عشر',
#    'شرا',
#    'رات',
#    'سني',
#    'نين',
#    'واك',
#    'اكل',
#    'كلت',
#    'لتو',
#    'خير',
#    'يرا',
#    'رات',
#    'اتا',
#    'بتنح',
#    'تنحا',
#    'نحاز',
#    'تمام',
#    'ماما',
#    'فلسط',
#    'لسطي',
#    'سطين',
#    'تكون',
#    'كونو',
#    'اعدا',
#    'عداء',
#    'لدول',
#    'دولة',
#    'احتض',
#    'حتضن',
#    'تضنت',
#    'ضنتك',
#    'نتكن',
#    'لعشر',
#    'عشرا',
#    'شرات',
#    'واكل',
#    'اكلت',
#    'كلتو',
#    'خيرا',
#    'يرات',
#    'راتا'],
#   'neg'),
#  (['خانت',
#    'المرأة',
#    'فهي',
#    'تبحث',
#    'الإهتمام',
#    'خان',
#    'الرجل',
#    'فهو',
#    'يبحث',
#    'عاهرة',
#    'خان',
#    'انت',
#    'الم',
#    'لمر',
#    'مرأ',
#    'رأة',
#    'تبح',
#    'بحث',
#    'الإ',
#    'لإه',
# ...
#    'لسيب',
#    'سيبا',
#    'يباع',
#    'باعى',
#    'الشك',
#    'لشكر'],
#   'neu'),
#  (['شوفو',
#    'قالت',
#    'ميركل',
#    'لمن',
#    'يطالبون',
#    'بمساواتهم',
#    'بالمعلمين',
#    'شوف',
#    'وفو',
#    'قال',
#    'الت',
#    'مير',
#    'يرك',
#    'ركل',
#    'يطا',
#    'طال',
#    'الب',
#    'لبو',
#    'بون',
#    'بمس',
#    'مسا',
#    'ساو',
#    'اوا',
#    'وات',
#    'اته',
#    'تهم',
#    'بال',
#    'الم',
#    'لمع',
#    'معل',
#    'علم',
#    'لمي',
#    'مين',
#    'ميرك',
#    'يركل',
#    'يطال',
#    'طالب',
#    'البو',
#    'لبون',
#    'بمسا',
#    'مساو',
#    'ساوا',
#    'اوات',
#    'واته',
#    'اتهم',
#    'بالم',
#    'المع',
#    'لمعل',
#    'معلم',
#    'علمي',
#    'لمين'],
#   'neu'),
#  (['بضان', 'بضا', 'ضان'], 'neg'),
#  (['اللهم',
#    'صل',
#    'سيدنا',
#    'حم',
#    'نبي',
#    'الهدى',
#    'والرحمة',
#    'يقطع',
#    'وصله',
#    'يرد',
#    'سأله',
#    'والرحمة',
#    'تسكن',
#    'قلبه',
#    'اللهم',
#    'إرزقنا',
#    'شفاعتة',
#    'رب',
#    'الل',
#    'لله',
#    'لهم',
#    'سيد',
#    'يدن',
#    'دنا',
#    'اله',
#    'لهد',
#    'هدى',
#    'وال',
#    'الر',
#    'لرح',
#    'رحم',
#    'حمة',
#    'يقط',
#    'قطع',
#    'وصل',
#    'صله',
#    'سأل',
#    'أله',
#    'وال',
#    'الر',
#    'لرح',
#    'رحم',
#    'حمة',
#    'تسك',
#    'سكن',
#    'قلب',
#    'لبه',
#    'الل',
#    'لله',
#    'لهم',
#    'إرز',
#    'رزق',
#    'زقن',
#    'قنا',
#    'شفا',
#    'فاع',
#    'اعت',
#    'عتة',
#    'الله',
#    'للهم',
#    'سيدن',
#    'يدنا',
#    'الهد',
#    'لهدى',
#    'والر',
#    'الرح',
#    'لرحم',
#    'رحمة',
#    'والر',
#    'الرح',
#    'لرحم',
#    'رحمة',
#    'الله',
#    'للهم',
#    'إرزق',
#    'رزقن',
#    'زقنا',
#    'شفاع',
#    'فاعت',
#    'اعتة'],
#   'pos'),
#  (['مش',
#    'عايز',
#    'حد',
#    'يثق',
#    'فيا',
#    'ومش',
#    'عايز',
#    'حد',
#    'يصدقنى',
#    'ماحلفلوا',
#    'اصل',
#    'احنا',
#    'مجتمغ',
#    'ابن',
#    'وسخة',
#    'نضف',
#    'عاي',
#    'ايز',
#    'عاي',
#    'ايز',
#    'يصد',
#    'صدق',
#    'دقن',
#    'قنى',
#    'ماح',
#    'احل',
#    'حلف',
#    'لفل',
#    'فلو',
#    'لوا',
#    'احن',
#    'حنا',
#    'مجت',
#    'جتم',
#    'تمغ',
#    'وسخ',
#    'سخة',
#    'يصدق',
#    'صدقن',
#    'دقنى',
#    'ماحل',
#    'احلف',
#    'حلفل',
#    'لفلو',
#    'فلوا',
#    'مجتم',
#    'جتمغ'],
#   'neg'),
#  (['ربنا',
#    'معاك',
#    'ياسطي',
#    'عايزك',
#    'تدعيلي',
#    'ربن',
#    'بنا',
#    'معا',
#    'عاك',
#    'ياس',
#    'اسط',
#    'سطي',
#    'عاي',
#    'ايز',
#    'يزك',
#    'تدع',
#    'دعي',
#    'عيل',
#    'يلي',
#    'ياسط',
#    'اسطي',
#    'عايز',
#    'ايزك',
#    'تدعي',
#    'دعيل',
#    'عيلي'],
#   'pos'),
#  (['موتى',
#    'اخر',
#    'نقطه',
#    'ندم',
#    'جوايا',
#    'ناحيتك',
#    'موت',
#    'وتى',
#    'نقط',
#    'قطه',
#    'جوا',
#    'واي',
#    'ايا',
#    'ناح',
#    'احي',
#    'حيت',
#    'يتك',
#    'جواي',
#    'وايا',
#    'ناحي',
#    'احيت',
#    'حيتك'],
#   'neg'),
#  (['احلى', 'ايام', 'احل', 'حلى', 'ايا', 'يام'], 'pos'),
#  (['نور',
#    'قلبت',
#    'عليا',
#    'مواجع',
#    'اغاني',
#    'ديمي',
#    'لوفاتو',
#    'قلب',
#    'لبت',
#    'علي',
#    'ليا',
#    'موا',
#    'واج',
#    'اجع',
#    'اغا',
#    'غان',
#    'اني',
#    'ديم',
#    'يمي',
#    'لوف',
#    'وفا',
#    'فات',
#    'اتو',
#    'مواج',
#    'واجع',
#    'اغان',
#    'غاني',
#    'لوفا',
#    'وفات',
#    'فاتو'],
#   'neg'),
#  (['انا',
#    'مدايقه',
#    'بقى',
#    'بكره',
#    'امتحاني',
#    'مدا',
#    'داي',
#    'ايق',
#    'يقه',
#    'بكر',
#    'كره',
#    'امت',
#    'متح',
#    'تحا',
#    'حان',
#    'اني',
#    'مداي',
#    'دايق',
#    'ايقه',
#    'امتح',
#    'متحا',
#    'تحان',
#    'حاني'],
#   'neg'),
#  (['اليوم',
#    'السابع',
#    'وفاة',
#    'فرد',
#    'الشرطة',
#    'المصاب',
#    'فى',
#    'حادث',
#    'سفنكس',
#    'الإرهابى',
#    'بالعجوزة',
#    'الي',
#    'ليو',
#    'يوم',
#    'الس',
#    'لسا',
#    'ساب',
#    'ابع',
#    'وفا',
#    'فاة',
#    'الش',
#    'لشر',
#    'شرط',
#    'رطة',
#    'الم',
#    'لمص',
#    'مصا',
#    'صاب',
#    'حاد',
#    'ادث',
#    'سفن',
#    'فنك',
#    'نكس',
#    'الإ',
#    'لإر',
#    'إره',
#    'رها',
#    'هاب',
#    'ابى',
#    'بال',
#    'الع',
#    'لعج',
#    'عجو',
#    'جوز',
#    'وزة',
#    'اليو',
#    'ليوم',
#    'السا',
#    'لساب',
#    'سابع',
#    'الشر',
#    'لشرط',
#    'شرطة',
#    'المص',
#    'لمصا',
#    'مصاب',
#    'سفنك',
#    'فنكس',
#    'الإر',
#    'لإره',
#    'إرها',
#    'رهاب',
#    'هابى',
#    'بالع',
#    'العج',
#    'لعجو',
#    'عجوز',
#    'جوزة'],
#   'neg'),
#  (['وانا',
#    'اقع',
#    'اقوم',
#    'ودى',
#    'مسألة',
#    'مبدأ',
#    'وان',
#    'انا',
#    'اقو',
#    'قوم',
#    'مسأ',
#    'سأل',
#    'ألة',
#    'مبد',
#    'بدأ',
#    'مسأل',
#    'سألة'],
#   'pos'),
#  (['هه',
#    'الكوره',
#    'نص',
#    'الملعب',
#    'وحسن',
#    'شخلته',
#    'بيجري',
#    'ادام',
#    'الحكم',
#    'تتلفي',
#    'ليه',
#    'الا',
#    'مفصوده',
#    'ربنا',
#    'ينتقم',
#    'ظالم',
#    'الك',
#    'لكو',
#    'كور',
#    'وره',
#    'الم',
#    'لمل',
#    'ملع',
#    'لعب',
#    'وحس',
#    'حسن',
#    'شخل',
#    'خلت',
#    'لته',
#    'بيج',
#    'يجر',
#    'جري',
#    'ادا',
#    'دام',
#    'الح',
#    'لحك',
#    'حكم',
#    'تتل',
#    'تلف',
#    'لفي',
#    'مفص',
#    'فصو',
#    'صود',
#    'وده',
#    'ربن',
#    'بنا',
#    'ينت',
#    'نتق',
#    'تقم',
#    'ظال',
#    'الم',
#    'الكو',
#    'لكور',
#    'كوره',
#    'المل',
#    'لملع',
#    'ملعب',
#    'شخلت',
#    'خلته',
#    'بيجر',
#    'يجري',
#    'الحك',
#    'لحكم',
#    'تتلف',
#    'تلفي',
#    'مفصو',
#    'فصود',
#    'صوده',
#    'ينتق',
#    'نتقم'],
#   'neg'),
#  (['يارب',
#    'ويسعدك',
#    'يار',
#    'ارب',
#    'ويس',
#    'يسع',
#    'سعد',
#    'عدك',
#    'ويسع',
#    'يسعد',
#    'سعدك'],
#   'pos'),
#  (['والله',
#    'بفرح',
#    'كتير',
#    'هه',
#    'وال',
#    'الل',
#    'لله',
#    'بفر',
#    'فرح',
#    'كتي',
#    'تير',
#    'والل',
#    'الله'],
#   'pos'),
#  (['نفسي',
#    'تبقي',
#    'بداية',
#    'حلوة',
#    'ايه',
#    'بقي',
#    'نفس',
#    'فسي',
#    'تبق',
#    'بقي',
#    'بدا',
#    'داي',
#    'اية',
#    'حلو',
#    'لوة',
#    'بداي',
#    'داية'],
#   'neg'),
#  (['ايام',
#    'ابتداءي',
#    'يعني',
#    'المتعه',
#    'الهلس',
#    'كوره',
#    'طوبات',
#    'المنديل',
#    'بيوضه',
#    'الواحد',
#    'مكنش',
#    'بينزل',
#    'بفلوس',
#    'وترجع',
#    'هدومك',
#    'متبهدله',
#    'كتر',
#    'اللعب',
#    'عيشة',
#    'تانيه',
#    'ايا',
#    'يام',
#    'ابت',
#    'بتد',
#    'تدا',
#    'داء',
#    'اءي',
#    'يعن',
#    'عني',
#    'الم',
#    'لمت',
#    'متع',
#    'تعه',
#    'اله',
#    'لهل',
#    'هلس',
#    'كور',
#    'وره',
#    'طوب',
#    'وبا',
#    'بات',
#    'الم',
#    'لمن',
#    'مند',
#    'ندي',
#    'ديل',
#    'بيو',
#    'يوض',
#    'وضه',
#    'الو',
#    'لوا',
#    'واح',
#    'احد',
#    'مكن',
#    'كنش',
#    'بين',
#    'ينز',
#    'نزل',
#    'بفل',
#    'فلو',
#    'لوس',
#    'وتر',
#    'ترج',
#    'رجع',
#    'هدو',
#    'دوم',
#    'ومك',
#    'متب',
#    'تبه',
#    'بهد',
#    'هدل',
#    'دله',
#    'الل',
#    'للع',
#    'لعب',
#    'عيش',
#    'يشة',
#    'تان',
#    'اني',
#    'نيه',
#    'ابتد',
#    'بتدا',
#    'تداء',
#    'داءي',
#    'المت',
#    'لمتع',
#    'متعه',
#    'الهل',
#    'لهلس',
#    'طوبا',
#    'وبات',
#    'المن',
#    'لمند',
#    'مندي',
#    'نديل',
#    'بيوض',
#    'يوضه',
#    'الوا',
#    'لواح',
#    'واحد',
#    'بينز',
#    'ينزل',
#    'بفلو',
#    'فلوس',
#    'وترج',
#    'ترجع',
#    'هدوم',
#    'دومك',
#    'متبه',
#    'تبهد',
#    'بهدل',
#    'هدله',
#    'اللع',
#    'للعب',
#    'تاني',
#    'انيه'],
#   'pos'),
#  (['شهوة',
#    'الجوع',
#    'تتغلب',
#    'احيانا',
#    'الشهوه',
#    'الجنسيه',
#    'شهو',
#    'هوة',
#    'الج',
#    'لجو',
#    'جوع',
#    'تتغ',
#    'تغل',
#    'غلب',
#    'احي',
#    'حيا',
#    'يان',
#    'انا',
#    'الش',
#    'لشه',
#    'شهو',
#    'هوه',
#    'الج',
#    'لجن',
#    'جنس',
#    'نسي',
#    'سيه',
#    'الجو',
#    'لجوع',
#    'تتغل',
#    'تغلب',
#    'احيا',
#    'حيان',
#    'يانا',
#    'الشه',
#    'لشهو',
#    'شهوه',
#    'الجن',
#    'لجنس',
#    'جنسي',
#    'نسيه'],
#   'neu'),
#  (['خايك',
#    'معا',
#    'حمد',
#    'ويقولوله',
#    'دودو',
#    'خاي',
#    'ايك',
#    'ويق',
#    'يقو',
#    'قول',
#    'ولو',
#    'لول',
#    'وله',
#    'دود',
#    'ودو',
#    'ويقو',
#    'يقول',
#    'قولو',
#    'ولول',
#    'لوله'],
#   'neu'),
#  (['وهذا',
#    'الانقسام',
#    'وهذ',
#    'هذا',
#    'الا',
#    'لان',
#    'انق',
#    'نقس',
#    'قسا',
#    'سام',
#    'الان',
#    'لانق',
#    'انقس',
#    'نقسا',
#    'قسام'],
#   'neg'),
#  (['هه',
#    'معلش',
#    'انا',
#    'هخلكى',
#    'تكلمى',
#    'زى',
#    'الحمار',
#    'كده',
#    'وزى',
#    'الغله',
#    'لى',
#    'بتشجعهاا',
#    'مش',
#    'هرد',
#    'عليكى',
#    'عشان',
#    'انتى',
#    'محروق',
#    'دمك',
#    'يعنى',
#    'هه',
#    'معل',
#    'علش',
#    'هخل',
#    'خلك',
#    'لكى',
#    'تكل',
#    'كلم',
#    'لمى',
#    'الح',
#    'لحم',
#    'حما',
#    'مار',
#    'الغ',
#    'لغل',
#    'غله',
#    'بتش',
#    'تشج',
#    'شجع',
#    'جعه',
#    'عها',
#    'هاا',
#    'علي',
#    'ليك',
#    'يكى',
#    'عشا',
#    'شان',
#    'انت',
#    'نتى',
#    'محر',
#    'حرو',
#    'روق',
#    'يعن',
#    'عنى',
#    'هخلك',
#    'خلكى',
#    'تكلم',
#    'كلمى',
#    'الحم',
#    'لحما',
#    'حمار',
#    'الغل',
#    'لغله',
#    'بتشج',
#    'تشجع',
#    'شجعه',
#    'جعها',
#    'عهاا',
#    'عليك',
#    'ليكى',
#    'محرو',
#    'حروق'],
#   'neg'),
#  (['مش',
#    'هنسى',
#    'ان',
#    'اول',
#    'بنت',
#    'عملتلها',
#    'ادد',
#    'الفيسبوك',
#    'عملتلى',
#    'بلوك',
#    'تعملى',
#    'اكسيبت',
#    'هنس',
#    'نسى',
#    'عمل',
#    'ملت',
#    'لتل',
#    'تله',
#    'لها',
#    'الف',
#    'لفي',
#    'فيس',
#    'يسب',
#    'سبو',
#    'بوك',
#    'عمل',
#    'ملت',
#    'لتل',
#    'تلى',
#    'بلو',
#    'لوك',
#    'تعم',
#    'عمل',
#    'ملى',
#    'اكس',
#    'كسي',
#    'سيب',
#    'يبت',
#    'عملت',
#    'ملتل',
#    'لتله',
#    'تلها',
#    'الفي',
#    'لفيس',
#    'فيسب',
#    'يسبو',
#    'سبوك',
#    'عملت',
#    'ملتل',
#    'لتلى',
#    'تعمل',
#    'عملى',
#    'اكسي',
#    'كسيب',
#    'سيبت'],
#   'neg'),
#  (['مرحبا',
#    'كيفك',
#    'احمد',
#    'رقم',
#    'الهاتف',
#    'الجوال',
#    'مرح',
#    'رحب',
#    'حبا',
#    'كيف',
#    'يفك',
#    'احم',
#    'حمد',
#    'اله',
#    'لها',
#    'هات',
#    'اتف',
#    'الج',
#    'لجو',
#    'جوا',
#    'وال',
#    'مرحب',
#    'رحبا',
#    'الها',
#    'لهات',
#    'هاتف',
#    'الجو',
#    'لجوا',
#    'جوال'],
#   'pos'),
#  (['المصحف',
#    'كاملا',
#    'أحمدالعجمي',
#    'الم',
#    'لمص',
#    'مصح',
#    'صحف',
#    'كام',
#    'امل',
#    'ملا',
#    'أحم',
#    'حمد',
#    'مدا',
#    'دال',
#    'الع',
#    'لعج',
#    'عجم',
#    'جمي',
#    'المص',
#    'لمصح',
#    'مصحف',
#    'كامل',
#    'املا',
#    'أحمد',
#    'حمدا',
#    'مدال',
#    'دالع',
#    'العج',
#    'لعجم',
#    'عجمي'],
#   'neu'),
#  (['يزم',
#    'الشواب',
#    'خربو',
#    'اسامي',
#    'الاكلات',
#    'الش',
#    'لشو',
#    'شوا',
#    'واب',
#    'خرب',
#    'ربو',
#    'اسا',
#    'سام',
#    'امي',
#    'الا',
#    'لاك',
#    'اكل',
#    'كلا',
#    'لات',
#    'الشو',
#    'لشوا',
#    'شواب',
#    'اسام',
#    'سامي',
#    'الاك',
#    'لاكل',
#    'اكلا',
#    'كلات'],
#   'neg'),
#  (['انا',
#    'فضلت',
#    'متمسمره',
#    'للدرجة',
#    'دى',
#    'انا',
#    'مبحسش',
#    'اسأله',
#    'طلعت',
#    'فى',
#    'راسي',
#    'وطفيت',
#    'الاغانى',
#    'وبعدين',
#    'قولت',
#    'طب',
#    'وانا',
#    'هعمل',
#    'ايه',
#    'وشغلت',
#    'الاغانى',
#    'تانى',
#    'فضل',
#    'ضلت',
#    'متم',
#    'تمس',
#    'مسم',
#    'سمر',
#    'مره',
#    'للد',
#    'لدر',
#    'درج',
#    'رجة',
#    'مبح',
#    'بحس',
#    'حسش',
#    'اسأ',
#    'سأل',
#    'أله',
#    'طلع',
#    'لعت',
#    'راس',
#    'اسي',
#    'وطف',
#    'طفي',
#    'فيت',
#    'الا',
#    'لاغ',
#    'اغا',
#    'غان',
#    'انى',
#    'وبع',
#    'بعد',
#    'عدي',
#    'دين',
#    'قول',
#    'ولت',
#    'وان',
#    'انا',
#    'هعم',
#    'عمل',
#    'وشغ',
#    'شغل',
#    'غلت',
#    'الا',
#    'لاغ',
#    'اغا',
#    'غان',
#    'انى',
#    'تان',
#    'انى',
#    'متمس',
#    'تمسم',
#    'مسمر',
#    'سمره',
#    'للدر',
#    'لدرج',
#    'درجة',
#    'مبحس',
#    'بحسش',
#    'اسأل',
#    'سأله',
#    'وطفي',
#    'طفيت',
#    'الاغ',
#    'لاغا',
#    'اغان',
#    'غانى',
#    'وبعد',
#    'بعدي',
#    'عدين',
#    'وشغل',
#    'شغلت',
#    'الاغ',
#    'لاغا',
#    'اغان',
#    'غانى'],
#   'neg'),
#  (['مش',
#    'عندك',
#    'امتحان',
#    'بكرة',
#    'اقفلي',
#    'ذكري',
#    'يلا',
#    'عند',
#    'ندك',
#    'امت',
#    'متح',
#    'تحا',
#    'حان',
#    'بكر',
#    'كرة',
#    'اقف',
#    'قفل',
#    'فلي',
#    'ذكر',
#    'كري',
#    'امتح',
#    'متحا',
#    'تحان',
#    'اقفل',
#    'قفلي'],
#   'neu'),
#  (['الصبر',
#    'لسه',
#    'ساكت',
#    'ويلي',
#    'سكاته',
#    'الص',
#    'لصب',
#    'صبر',
#    'ساك',
#    'اكت',
#    'ويل',
#    'يلي',
#    'سكا',
#    'كات',
#    'اته',
#    'الصب',
#    'لصبر',
#    'سكات',
#    'كاته'],
#   'neg'),
#  (['اللهم',
#    'ارزقنا',
#    'البر',
#    'والتقوي',
#    'الل',
#    'لله',
#    'لهم',
#    'ارز',
#    'رزق',
#    'زقن',
#    'قنا',
#    'الب',
#    'لبر',
#    'وال',
#    'الت',
#    'لتق',
#    'تقو',
#    'قوي',
#    'الله',
#    'للهم',
#    'ارزق',
#    'رزقن',
#    'زقنا',
#    'والت',
#    'التق',
#    'لتقو',
#    'تقوي'],
#   'pos'),
#  (['مخلصة',
#    'ومطمنة',
#    'وهصحى',
#    'بكرة',
#    'ابدا',
#    'تانى',
#    'اللهم',
#    'الحمد',
#    'مخل',
#    'خلص',
#    'لصة',
#    'ومط',
#    'مطم',
#    'طمن',
#    'منة',
#    'وهص',
#    'هصح',
#    'صحى',
#    'بكر',
#    'كرة',
#    'ابد',
#    'بدا',
#    'تان',
#    'انى',
#    'الل',
#    'لله',
#    'لهم',
#    'الح',
#    'لحم',
#    'حمد',
#    'مخلص',
#    'خلصة',
#    'ومطم',
#    'مطمن',
#    'طمنة',
#    'وهصح',
#    'هصحى',
#    'الله',
#    'للهم',
#    'الحم',
#    'لحمد'],
#   'pos'),
#  (['احساس',
#    'ان',
#    'فى',
#    'حد',
#    'تانى',
#    'خد',
#    'مكانك',
#    'وسط',
#    'الناس',
#    'اللى',
#    'بتحبهم',
#    'وهما',
#    'سابوه',
#    'يخدو',
#    'عادى',
#    'احساس',
#    'وحش',
#    'اوى',
#    'احس',
#    'حسا',
#    'ساس',
#    'تان',
#    'انى',
#    'مكا',
#    'كان',
#    'انك',
#    'الن',
#    'لنا',
#    'ناس',
#    'الل',
#    'للى',
#    'بتح',
#    'تحب',
#    'حبه',
#    'بهم',
#    'وهم',
#    'هما',
#    'ساب',
#    'ابو',
#    'بوه',
#    'يخد',
#    'خدو',
#    'عاد',
#    'ادى',
#    'احس',
#    'حسا',
#    'ساس',
#    'احسا',
#    'حساس',
#    'مكان',
#    'كانك',
#    'النا',
#    'لناس',
#    'بتحب',
#    'تحبه',
#    'حبهم',
#    'سابو',
#    'ابوه',
#    'احسا',
#    'حساس'],
#   'neg'),
#  (['أشهد',
#    'امرأة',
#    'تشبهني',
#    'كصورة',
#    'زيتية',
#    'الفكر',
#    'والسلوك',
#    'والعقل',
#    'والجنون',
#    'نزار',
#    'قباني',
#    'أشه',
#    'شهد',
#    'امر',
#    'مرأ',
#    'رأة',
#    'تشب',
#    'شبه',
#    'بهن',
#    'هني',
#    'كصو',
#    'صور',
#    'ورة',
#    'زيت',
#    'يتي',
#    'تية',
#    'الف',
#    'لفك',
#    'فكر',
#    'وال',
#    'الس',
#    'لسل',
#    'سلو',
#    'لوك',
#    'وال',
#    'الع',
#    'لعق',
#    'عقل',
#    'وال',
#    'الج',
#    'لجن',
#    'جنو',
#    'نون',
#    'نزا',
#    'زار',
#    'قبا',
#    'بان',
#    'اني',
#    'امرأ',
#    'مرأة',
#    'تشبه',
#    'شبهن',
#    'بهني',
#    'كصور',
#    'صورة',
#    'زيتي',
#    'يتية',
#    'الفك',
#    'لفكر',
#    'والس',
#    'السل',
#    'لسلو',
#    'سلوك',
#    'والع',
#    'العق',
#    'لعقل',
#    'والج',
#    'الجن',
#    'لجنو',
#    'جنون',
#    'قبان',
#    'باني'],
#   'pos'),
#  (['تكريم',
#    'أستاذنا',
#    'رافت',
#    'نجيب',
#    'تكر',
#    'كري',
#    'ريم',
#    'أست',
#    'ستا',
#    'تاذ',
#    'اذن',
#    'ذنا',
#    'راف',
#    'افت',
#    'نجي',
#    'جيب',
#    'تكري',
#    'كريم',
#    'أستا',
#    'ستاذ',
#    'تاذن',
#    'اذنا'],
#   'pos'),
#  (['فنيه',
#    'تمريض',
#    'بخميس',
#    'مشيط',
#    'ابي',
#    'بديله',
#    'لمنطقه',
#    'تبوك',
#    'وظائف',
#    'توظيف',
#    'فني',
#    'نيه',
#    'تمر',
#    'مري',
#    'ريض',
#    'بخم',
#    'خمي',
#    'ميس',
#    'مشي',
#    'شيط',
#    'بدي',
#    'ديل',
#    'يله',
#    'لمن',
#    'منط',
#    'نطق',
#    'طقه',
#    'تبو',
#    'بوك',
#    'وظا',
#    'ظائ',
#    'ائف',
#    'توظ',
#    'وظي',
#    'ظيف',
#    'تمري',
#    'مريض',
#    'بخمي',
#    'خميس',
#    'بديل',
#    'ديله',
#    'لمنط',
#    'منطق',
#    'نطقه',
#    'وظائ',
#    'ظائف',
#    'توظي',
#    'وظيف'],
#   'neu'),
#  (['السلام',
#    'ورحمة',
#    'الله',
#    'وبركاتة',
#    'وجوول',
#    'للاتحاد',
#    'الس',
#    'لسل',
#    'سلا',
#    'لام',
#    'ورح',
#    'رحم',
#    'حمة',
#    'الل',
#    'لله',
#    'وبر',
#    'برك',
#    'ركا',
#    'كات',
#    'اتة',
#    'وجو',
#    'جوو',
#    'وول',
#    'للا',
#    'لات',
#    'اتح',
#    'تحا',
#    'حاد',
#    'السل',
#    'لسلا',
#    'سلام',
#    'ورحم',
#    'رحمة',
#    'وبرك',
#    'بركا',
#    'ركات',
#    'كاتة',
#    'وجوو',
#    'جوول',
#    'للات',
#    'لاتح',
#    'اتحا',
#    'تحاد'],
#   'pos'),
#  (['الديمقراطية',
#    'حكم',
#    'اللي',
#    'يغلب',
#    'ولاد',
#    'الكلب',
#    'الد',
#    'لدي',
#    'ديم',
#    'يمق',
#    'مقر',
#    'قرا',
#    'راط',
#    'اطي',
#    'طية',
#    'الل',
#    'للي',
#    'يغل',
#    'غلب',
#    'ولا',
#    'لاد',
#    'الك',
#    'لكل',
#    'كلب',
#    'الدي',
#    'لديم',
#    'ديمق',
#    'يمقر',
#    'مقرا',
#    'قراط',
#    'راطي',
#    'اطية',
#    'الكل',
#    'لكلب'],
#   'neg'),
#  (['الصراحه',
#    'انا',
#    'مش',
#    'عارفه',
#    'اتعاطف',
#    'معاها',
#    'هى',
#    'دلعها',
#    'انانيتها',
#    'اللى',
#    'وصلوها',
#    'لكده',
#    'شغله',
#    'لازم',
#    'يستنى',
#    'عشان',
#    'خاطرها',
#    'الص',
#    'لصر',
#    'صرا',
#    'راح',
#    'احه',
#    'عار',
#    'ارف',
#    'رفه',
#    'اتع',
#    'تعا',
#    'عاط',
#    'اطف',
#    'معا',
#    'عاه',
#    'اها',
#    'دلع',
#    'لعه',
#    'عها',
#    'انا',
#    'نان',
#    'اني',
#    'نيت',
#    'يته',
#    'تها',
#    'الل',
#    'للى',
#    'وصل',
#    'صلو',
#    'لوه',
#    'وها',
#    'لكد',
#    'كده',
#    'شغل',
#    'غله',
#    'لاز',
#    'ازم',
#    'يست',
#    'ستن',
#    'تنى',
#    'عشا',
#    'شان',
#    'خاط',
#    'اطر',
#    'طره',
#    'رها',
#    'الصر',
#    'لصرا',
#    'صراح',
#    'راحه',
#    'عارف',
#    'ارفه',
#    'اتعا',
#    'تعاط',
#    'عاطف',
#    'معاه',
#    'عاها',
#    'دلعه',
#    'لعها',
#    'انان',
#    'ناني',
#    'انيت',
#    'نيته',
#    'يتها',
#    'وصلو',
#    'صلوه',
#    'لوها',
#    'يستن',
#    'ستنى',
#    'خاطر',
#    'اطره',
#    'طرها'],
#   'neg')]

# %% [markdown]
# # Sample training data

# %%
import random
sample_size = 100
print('{} random tweets .... '.format(sample_size))
for s in random.sample(train_data, sample_size):
    print(s)
# Out:
# 100 random tweets ....
# (['الواحد', 'بقي', 'مبضون', 'الناس', 'اللي', 'حوله', 'حاجة', 'الو', 'لوا', 'واح', 'احد', 'مبض', 'بضو', 'ضون', 'الن', 'لنا', 'ناس', 'الل', 'للي', 'حول', 'وله', 'حاج', 'اجة', 'الوا', 'لواح', 'واحد', 'مبضو', 'بضون', 'النا', 'لناس'], 'neg')
# (['أصابك', 'عشقا', 'أصا', 'صاب', 'ابك', 'عشق', 'شقا', 'أصاب', 'صابك'], 'neu')
# (['الى', 'الكنترول', 'انهاردة', 'اخر', 'يوم', 'حرام', 'امك', 'بقى', 'عايزين', 'نشوف', 'دعاء', 'السباعي', 'ليث', 'ابو', 'جودة', 'ارحم', 'امنا', 'العيانة', 'الك', 'لكن', 'كنت', 'نتر', 'ترو', 'رول', 'انه', 'نها', 'هار', 'ارد', 'ردة', 'حرا', 'رام', 'عاي', 'ايز', 'يزي', 'زين', 'نشو', 'شوف', 'دعا', 'عاء', 'الس', 'لسب', 'سبا', 'باع', 'اعي', 'جود', 'ودة', 'ارح', 'رحم', 'امن', 'منا', 'الع', 'لعي', 'عيا', 'يان', 'انة', 'الكن', 'لكنت', 'كنتر', 'نترو', 'ترول', 'انها', 'نهار', 'هارد', 'اردة', 'عايز', 'ايزي', 'يزين', 'السب', 'لسبا', 'سباع', 'باعي', 'العي', 'لعيا', 'عيان', 'يانة'], 'neg')
# (['اصلاا', 'ليث', 'ده', 'مصرري', 'ليث', 'جودة', 'اصل', 'صلا', 'لاا', 'مصر', 'صرر', 'رري', 'جود', 'ودة', 'اصلا', 'صلاا', 'مصرر', 'صرري'], 'neu')
# (['القرأنيه', 'واضحه', 'وخاصه', 'قوله', 'جمعهم', 'اذا', 'شاء', 'قدير', 'اي', 'وجود', 'حياه', 'اخرى', 'الق', 'لقر', 'قرأ', 'رأن', 'أني', 'نيه', 'واض', 'اضح', 'ضحه', 'وخا', 'خاص', 'اصه', 'قول', 'وله', 'جمع', 'معه', 'عهم', 'قدي', 'دير', 'وجو', 'جود', 'حيا', 'ياه', 'اخر', 'خرى', 'القر', 'لقرأ', 'قرأن', 'رأني', 'أنيه', 'واضح', 'اضحه', 'وخاص', 'خاصه', 'جمعه', 'معهم'], 'neu')
# (['والله', 'الحكام', 'دول', 'محتاجين', 'معجزه', 'سماويه', 'علشان', 'يتعدلو', 'وال', 'الل', 'لله', 'الح', 'لحك', 'حكا', 'كام', 'محت', 'حتا', 'تاج', 'اجي', 'جين', 'معج', 'عجز', 'جزه', 'سما', 'ماو', 'اوي', 'ويه', 'علش', 'لشا', 'شان', 'يتع', 'تعد', 'عدل', 'دلو', 'والل', 'الله', 'الحك', 'لحكا', 'حكام', 'محتا', 'حتاج', 'تاجي', 'اجين', 'معجز', 'عجزه', 'سماو', 'ماوي', 'اويه', 'علشا', 'لشان', 'يتعد', 'تعدل', 'عدلو'], 'neg')
# (['الطالب', 'الوحيد', 'تاريخ', 'ستاراك', 'اللى', 'غنا', 'لهحات', 'ولغات', 'مختلفه', 'وابدع', 'محمد', 'شاهين', 'ليث', 'المصري', 'السادس', 'كنزه', 'حبيبه', 'المصريين', 'الط', 'لطا', 'طال', 'الب', 'الو', 'لوح', 'وحي', 'حيد', 'تار', 'اري', 'ريخ', 'ستا', 'تار', 'ارا', 'راك', 'الل', 'للى', 'لهح', 'هحا', 'حات', 'ولغ', 'لغا', 'غات', 'مخت', 'ختل', 'تلف', 'لفه', 'واب', 'ابد', 'بدع', 'محم', 'حمد', 'شاه', 'اهي', 'هين', 'الم', 'لمص', 'مصر', 'صري', 'الس', 'لسا', 'ساد', 'ادس', 'كنز', 'نزه', 'حبي', 'بيب', 'يبه', 'الم', 'لمص', 'مصر', 'صري', 'ريي', 'يين', 'الطا', 'لطال', 'طالب', 'الوح', 'لوحي', 'وحيد', 'تاري', 'اريخ', 'ستار', 'تارا', 'اراك', 'لهحا', 'هحات', 'ولغا', 'لغات', 'مختل', 'ختلف', 'تلفه', 'وابد', 'ابدع', 'شاهي', 'اهين', 'المص', 'لمصر', 'مصري', 'السا', 'لساد', 'سادس', 'حبيب', 'بيبه', 'المص', 'لمصر', 'مصري', 'صريي', 'ريين'], 'pos')
# (['الافضل', 'ان', 'تعيش', 'حياتك', 'وتدعهم', 'يعيشوا', 'حياتهم', 'وعلي', 'قدر', 'اقترابهم', 'منك', 'اقترب', 'انت', 'واجعل', 'لمشاعرك', 'وزنا', 'تسريب', 'الشرق', 'لمكتب', 'السيسي', 'الا', 'لاف', 'افض', 'فضل', 'تعي', 'عيش', 'حيا', 'يات', 'اتك', 'وتد', 'تدع', 'دعه', 'عهم', 'يعي', 'عيش', 'يشو', 'شوا', 'حيا', 'يات', 'اته', 'تهم', 'وعل', 'علي', 'اقت', 'قتر', 'ترا', 'راب', 'ابه', 'بهم', 'اقت', 'قتر', 'ترب', 'واج', 'اجع', 'جعل', 'لمش', 'مشا', 'شاع', 'اعر', 'عرك', 'وزن', 'زنا', 'تسر', 'سري', 'ريب', 'الش', 'لشر', 'شرق', 'لمك', 'مكت', 'كتب', 'الس', 'لسي', 'سيس', 'يسي', 'الاف', 'لافض', 'افضل', 'حيات', 'ياتك', 'وتدع', 'تدعه', 'دعهم', 'يعيش', 'عيشو', 'يشوا', 'حيات', 'ياته', 'اتهم', 'اقتر', 'قترا', 'تراب', 'رابه', 'ابهم', 'اقتر', 'قترب', 'واجع', 'اجعل', 'لمشا', 'مشاع', 'شاعر', 'اعرك', 'تسري', 'سريب', 'الشر', 'لشرق', 'لمكت', 'مكتب', 'السي', 'لسيس', 'سيسي'], 'neu')
# (['العشري', 'تربية', 'جوزية', 'بقي', 'يلا', 'دوري', 'الع', 'لعش', 'عشر', 'شري', 'ترب', 'ربي', 'بية', 'جوز', 'وزي', 'زية', 'دور', 'وري', 'العش', 'لعشر', 'عشري', 'تربي', 'ربية', 'جوزي', 'وزية'], 'pos')
# (['الحضن', 'قشعرة', 'الح', 'لحض', 'حضن', 'قشع', 'شعر', 'عرة', 'الحض', 'لحضن', 'قشعر', 'شعرة'], 'neu')
# (['معي', 'ربي', 'سيهدين', 'سيه', 'يهد', 'هدي', 'دين', 'سيهد', 'يهدي', 'هدين'], 'pos')
# (['أسأل', 'أشرقت', 'الشمس', 'بأمره', 'وتوزعت', 'الارزاق', 'بكرمه', 'يغدق', 'عليكم', 'رزقه', 'وبركته', 'ويبلغكم', 'أعلى', 'مراتب', 'الدنيا', 'وأعلى', 'منازل', 'الجنه', 'العشم', 'الله', 'أسأ', 'سأل', 'أشر', 'شرق', 'رقت', 'الش', 'لشم', 'شمس', 'بأم', 'أمر', 'مره', 'وتو', 'توز', 'وزع', 'زعت', 'الا', 'لار', 'ارز', 'رزا', 'زاق', 'بكر', 'كرم', 'رمه', 'يغد', 'غدق', 'علي', 'ليك', 'يكم', 'رزق', 'زقه', 'وبر', 'برك', 'ركت', 'كته', 'ويب', 'يبل', 'بلغ', 'لغك', 'غكم', 'أعل', 'على', 'مرا', 'رات', 'اتب', 'الد', 'لدن', 'دني', 'نيا', 'وأع', 'أعل', 'على', 'منا', 'ناز', 'ازل', 'الج', 'لجن', 'جنه', 'الع', 'لعش', 'عشم', 'الل', 'لله', 'أشرق', 'شرقت', 'الشم', 'لشمس', 'بأمر', 'أمره', 'وتوز', 'توزع', 'وزعت', 'الار', 'لارز', 'ارزا', 'رزاق', 'بكرم', 'كرمه', 'عليك', 'ليكم', 'وبرك', 'بركت', 'ركته', 'ويبل', 'يبلغ', 'بلغك', 'لغكم', 'مرات', 'راتب', 'الدن', 'لدني', 'دنيا', 'وأعل', 'أعلى', 'مناز', 'نازل', 'الجن', 'لجنه', 'العش', 'لعشم'], 'pos')
# (['البلد', 'ده', 'اقصها', 'استك', 'وتبقى', 'لباس', 'كبيير', 'بيضم', 'طياز', 'اكبر', 'دماغات', 'الب', 'لبل', 'بلد', 'اقص', 'قصه', 'صها', 'است', 'ستك', 'وتب', 'تبق', 'بقى', 'لبا', 'باس', 'كبي', 'بيي', 'يير', 'بيض', 'يضم', 'طيا', 'ياز', 'اكب', 'كبر', 'دما', 'ماغ', 'اغا', 'غات', 'البل', 'لبلد', 'اقصه', 'قصها', 'وتبق', 'تبقى', 'كبيي', 'بيير', 'دماغ', 'ماغا', 'اغات'], 'neg')
# (['هاكل', 'اخير', 'هاك', 'اكل', 'اخي', 'خير'], 'pos')
# (['اجى', 'اركب', 'عليكى', 'ورا', 'احطه', 'جواكى', 'شرموطه', 'ارك', 'ركب', 'علي', 'ليك', 'يكى', 'احط', 'حطه', 'جوا', 'واك', 'اكى', 'شرم', 'رمو', 'موط', 'وطه', 'عليك', 'ليكى', 'جواك', 'واكى', 'شرمو', 'رموط', 'موطه'], 'neg')
# (['عادي', 'جدا', 'انك', 'تحب', 'حد', 'سبب', 'علشان', 'الحب', 'نفسه', 'حب', 'كدا', 'إزاي', 'وليه', 'عاد', 'ادي', 'علش', 'لشا', 'شان', 'الح', 'لحب', 'نفس', 'فسه', 'إزا', 'زاي', 'ولي', 'ليه', 'علشا', 'لشان'], 'pos')
# (['اه', 'مرارتي', 'مرا', 'رار', 'ارت', 'رتي', 'مرار', 'رارت', 'ارتي'], 'neg')
# (['مسا', 'الفل', 'الياسمين', 'حبيبي', 'الف', 'لفل', 'الي', 'ليا', 'ياس', 'اسم', 'سمي', 'مين', 'حبي', 'بيب', 'يبي', 'اليا', 'لياس', 'ياسم', 'اسمي', 'سمين', 'حبيب', 'بيبي'], 'pos')
# (['يسعدلى', 'هالصباح', 'عيونكو', 'الحلويين', 'يسع', 'سعد', 'عدل', 'دلى', 'هال', 'الص', 'لصب', 'صبا', 'باح', 'عيو', 'يون', 'ونك', 'نكو', 'الح', 'لحل', 'حلو', 'لوي', 'ويي', 'يين', 'يسعد', 'سعدل', 'عدلى', 'هالص', 'الصب', 'لصبا', 'صباح', 'عيون', 'يونك', 'ونكو', 'الحل', 'لحلو', 'حلوي', 'لويي', 'ويين'], 'pos')
# (['احتمالية', 'النواتج', 'ماتخلكش', 'ترفض', 'تجرب', 'لان', 'اكبد', 'نسبة', 'نجاح', 'حتي', 'صغيره', 'احت', 'حتم', 'تما', 'مال', 'الي', 'لية', 'الن', 'لنو', 'نوا', 'وات', 'اتج', 'مات', 'اتخ', 'تخل', 'خلك', 'لكش', 'ترف', 'رفض', 'تجر', 'جرب', 'اكب', 'كبد', 'نسب', 'سبة', 'نجا', 'جاح', 'صغي', 'غير', 'يره', 'احتم', 'حتما', 'تمال', 'مالي', 'الية', 'النو', 'لنوا', 'نوات', 'واتج', 'ماتخ', 'اتخل', 'تخلك', 'خلكش', 'صغير', 'غيره'], 'pos')
# (['الشناوي', 'هيلعب', 'ماتش', 'بتروجيت', 'الش', 'لشن', 'شنا', 'ناو', 'اوي', 'هيل', 'يلع', 'لعب', 'مات', 'اتش', 'بتر', 'ترو', 'روج', 'وجي', 'جيت', 'الشن', 'لشنا', 'شناو', 'ناوي', 'هيلع', 'يلعب', 'بترو', 'تروج', 'روجي', 'وجيت'], 'neu')
# (['حب', 'لصوتك', 'اضعافه', 'رنا', 'سماحة', 'عمرو', 'الليثي', 'لصو', 'صوت', 'وتك', 'اضع', 'ضعا', 'عاف', 'افه', 'سما', 'ماح', 'احة', 'عمر', 'مرو', 'الل', 'للي', 'ليث', 'يثي', 'لصوت', 'صوتك', 'اضعا', 'ضعاف', 'عافه', 'سماح', 'ماحة', 'اللي', 'لليث', 'ليثي'], 'pos')
# (['أحببتك', 'مرغما', 'لأنك', 'الاجمل', 'لأنك', 'الأعمق', 'فعاشق', 'الجمال', 'العادة', 'أحمق', 'أحب', 'حبب', 'ببت', 'بتك', 'مرغ', 'رغم', 'غما', 'لأن', 'أنك', 'الا', 'لاج', 'اجم', 'جمل', 'لأن', 'أنك', 'الأ', 'لأع', 'أعم', 'عمق', 'فعا', 'عاش', 'اشق', 'الج', 'لجم', 'جما', 'مال', 'الع', 'لعا', 'عاد', 'ادة', 'أحم', 'حمق', 'أحبب', 'حببت', 'ببتك', 'مرغم', 'رغما', 'الاج', 'لاجم', 'اجمل', 'الأع', 'لأعم', 'أعمق', 'فعاش', 'عاشق', 'الجم', 'لجما', 'جمال', 'العا', 'لعاد', 'عادة'], 'pos')
# (['اللي', 'تقهرني', 'مدن', 'ايام', 'الثورةوالدق', 'الصح', 'رايات', 'خضروجوسمح', 'وفلوس', 'وتوا', 'توار', 'حقيقيين', 'ومع', 'الخوارج', 'وكلاب', 'لمليشيات', 'مزراطةكيف', 'جت', 'يي', 'ياما', 'دونها', 'الل', 'للي', 'تقه', 'قهر', 'هرن', 'رني', 'ايا', 'يام', 'الث', 'لثو', 'ثور', 'ورة', 'رةو', 'ةوا', 'وال', 'الد', 'لدق', 'الص', 'لصح', 'راي', 'ايا', 'يات', 'خضر', 'ضرو', 'روج', 'وجو', 'جوس', 'وسم', 'سمح', 'وفل', 'فلو', 'لوس', 'وتو', 'توا', 'توا', 'وار', 'حقي', 'قيق', 'يقي', 'قيي', 'يين', 'الخ', 'لخو', 'خوا', 'وار', 'ارج', 'وكل', 'كلا', 'لاب', 'لمل', 'ملي', 'ليش', 'يشي', 'شيا', 'يات', 'مزر', 'زرا', 'راط', 'اطة', 'طةك', 'ةكي', 'كيف', 'يام', 'اما', 'دون', 'ونه', 'نها', 'تقهر', 'قهرن', 'هرني', 'الثو', 'لثور', 'ثورة', 'ورةو', 'رةوا', 'ةوال', 'والد', 'الدق', 'رايا', 'ايات', 'خضرو', 'ضروج', 'روجو', 'وجوس', 'جوسم', 'وسمح', 'وفلو', 'فلوس', 'حقيق', 'قيقي', 'يقيي', 'قيين', 'الخو', 'لخوا', 'خوار', 'وارج', 'وكلا', 'كلاب', 'لملي', 'مليش', 'ليشي', 'يشيا', 'شيات', 'مزرا', 'زراط', 'راطة', 'اطةك', 'طةكي', 'ةكيف', 'دونه', 'ونها'], 'neg')
# (['انا', 'مشروخ', 'مشروخ', 'جمي', 'مشر', 'شرو', 'روخ', 'مشر', 'شرو', 'روخ', 'مشرو', 'شروخ', 'مشرو', 'شروخ'], 'neg')
# (['فهو', 'يبحث', 'الحب', 'بالفطرة', 'الامتنان', 'لسه', 'بقول', 'ليك', 'الامتنان', 'الوعي', 'المرتبط', 'بالمادة', 'والقواعد', 'حد', 'قولك', 'يبح', 'بحث', 'الح', 'لحب', 'بال', 'الف', 'لفط', 'فطر', 'طرة', 'الا', 'لام', 'امت', 'متن', 'تنا', 'نان', 'بقو', 'قول', 'الا', 'لام', 'امت', 'متن', 'تنا', 'نان', 'الو', 'لوع', 'وعي', 'الم', 'لمر', 'مرت', 'رتب', 'تبط', 'بال', 'الم', 'لما', 'ماد', 'ادة', 'وال', 'الق', 'لقو', 'قوا', 'واع', 'اعد', 'قول', 'ولك', 'بالف', 'الفط', 'لفطر', 'فطرة', 'الام', 'لامت', 'امتن', 'متنا', 'تنان', 'الام', 'لامت', 'امتن', 'متنا', 'تنان', 'الوع', 'لوعي', 'المر', 'لمرت', 'مرتب', 'رتبط', 'بالم', 'الما', 'لماد', 'مادة', 'والق', 'القو', 'لقوا', 'قواع', 'واعد'], 'neu')
# (['جماعة', 'والله', 'كبرنا', 'الكلام', 'السياسة', 'جما', 'ماع', 'اعة', 'وال', 'الل', 'لله', 'كبر', 'برن', 'رنا', 'الك', 'لكل', 'كلا', 'لام', 'الس', 'لسي', 'سيا', 'ياس', 'اسة', 'جماع', 'ماعة', 'والل', 'الله', 'كبرن', 'برنا', 'الكل', 'لكلا', 'كلام', 'السي', 'لسيا', 'سياس', 'ياسة'], 'neu')
# (['تعالى', 'اقعدى', 'زوبرى', 'كله', 'طيزك', 'منيوكه', 'تعا', 'عال', 'الى', 'اقع', 'قعد', 'عدى', 'زوب', 'وبر', 'برى', 'طيز', 'يزك', 'مني', 'نيو', 'يوك', 'وكه', 'تعال', 'عالى', 'اقعد', 'قعدى', 'زوبر', 'وبرى', 'منيو', 'نيوك', 'يوكه'], 'neg')
# (['مينا', 'عطا', 'منا', 'عطا', 'ال', 'اجبرني', 'اتابع', 'سيزون', 'مين', 'ينا', 'اجب', 'جبر', 'برن', 'رني', 'اتا', 'تاب', 'ابع', 'سيز', 'يزو', 'زون', 'اجبر', 'جبرن', 'برني', 'اتاب', 'تابع', 'سيزو', 'يزون'], 'neu')
# (['بتبقي', 'بنت', 'كلب', 'بتب', 'تبق', 'بقي', 'بتبق', 'تبقي'], 'neg')
# (['يصبحوا', 'اصدقائنا', 'بالصدفة', 'اسوا', 'الاصدقاء', 'حينما', 'يصبحوا', 'غرباء', 'يصب', 'صبح', 'بحو', 'حوا', 'اصد', 'صدق', 'دقا', 'قائ', 'ائن', 'ئنا', 'بال', 'الص', 'لصد', 'صدف', 'دفة', 'اسو', 'سوا', 'الا', 'لاص', 'اصد', 'صدق', 'دقا', 'قاء', 'حين', 'ينم', 'نما', 'يصب', 'صبح', 'بحو', 'حوا', 'غرب', 'ربا', 'باء', 'يصبح', 'صبحو', 'بحوا', 'اصدق', 'صدقا', 'دقائ', 'قائن', 'ائنا', 'بالص', 'الصد', 'لصدف', 'صدفة', 'الاص', 'لاصد', 'اصدق', 'صدقا', 'دقاء', 'حينم', 'ينما', 'يصبح', 'صبحو', 'بحوا', 'غربا', 'رباء'], 'neg')
# (['لييه', 'كده', 'اخى', 'اخى', 'حرام', 'اخى', 'بصوت', 'عبد', 'العزيز', 'ليي', 'ييه', 'حرا', 'رام', 'بصو', 'صوت', 'الع', 'لعز', 'عزي', 'زيز', 'العز', 'لعزي', 'عزيز'], 'neg')
# (['ريتاج', 'وحشتنى', 'قمر', 'انا', 'زنيب', 'يلدريم', 'علشان', 'عيونك', 'حلوة', 'حياتى', 'ذاد', 'حلاوة', 'فيهم', 'ريت', 'يتا', 'تاج', 'وحش', 'حشت', 'شتن', 'تنى', 'زني', 'نيب', 'يلد', 'لدر', 'دري', 'ريم', 'علش', 'لشا', 'شان', 'عيو', 'يون', 'ونك', 'حلو', 'لوة', 'حيا', 'يات', 'اتى', 'حلا', 'لاو', 'اوة', 'فيه', 'يهم', 'ريتا', 'يتاج', 'وحشت', 'حشتن', 'شتنى', 'يلدر', 'لدري', 'دريم', 'علشا', 'لشان', 'عيون', 'يونك', 'حيات', 'ياتى', 'حلاو', 'لاوة'], 'pos')
# (['احا', 'يعنى', 'صاحى', 'بليز', 'كول', 'مى', 'وقولنا', 'ماشى', 'انما', 'ملاقيش', 'علبه', 'السجاير', 'احا', 'بجد', 'دا', 'انا', 'شارب', 'سجارة', 'واحده', 'يعن', 'عنى', 'صاح', 'احى', 'بلي', 'ليز', 'وقو', 'قول', 'ولن', 'لنا', 'ماش', 'اشى', 'انم', 'نما', 'ملا', 'لاق', 'اقي', 'قيش', 'علب', 'لبه', 'الس', 'لسج', 'سجا', 'جاي', 'اير', 'شار', 'ارب', 'سجا', 'جار', 'ارة', 'واح', 'احد', 'حده', 'وقول', 'قولن', 'ولنا', 'ملاق', 'لاقي', 'اقيش', 'السج', 'لسجا', 'سجاي', 'جاير', 'سجار', 'جارة', 'واحد', 'احده'], 'neg')
# (['والله', 'انا', 'كتبها', 'عشان', 'كدة', 'برافو', 'عليكي', 'وال', 'الل', 'لله', 'كتب', 'تبه', 'بها', 'عشا', 'شان', 'برا', 'راف', 'افو', 'علي', 'ليك', 'يكي', 'والل', 'الله', 'كتبه', 'تبها', 'براف', 'رافو', 'عليك', 'ليكي'], 'pos')
# (['الاغنية', 'اللى', 'تهز', 'قلبك', 'وتنزل', 'دمعتك', 'وتقربك', 'لربنا', 'يترفعلها', 'القبعة', 'الا', 'لاغ', 'اغن', 'غني', 'نية', 'الل', 'للى', 'قلب', 'لبك', 'وتن', 'تنز', 'نزل', 'دمع', 'معت', 'عتك', 'وتق', 'تقر', 'قرب', 'ربك', 'لرب', 'ربن', 'بنا', 'يتر', 'ترف', 'رفع', 'فعل', 'عله', 'لها', 'الق', 'لقب', 'قبع', 'بعة', 'الاغ', 'لاغن', 'اغني', 'غنية', 'وتنز', 'تنزل', 'دمعت', 'معتك', 'وتقر', 'تقرب', 'قربك', 'لربن', 'ربنا', 'يترف', 'ترفع', 'رفعل', 'فعله', 'علها', 'القب', 'لقبع', 'قبعة'], 'pos')
# (['هى', 'الايموشنز', 'اللى', 'هى', 'بيعيط', 'الضحك', 'والقلوب', 'الخضرا', 'والحمرا', 'والحاجات', 'دى', 'بتنزل', 'للبروزر', 'انا', 'عارف', 'انه', 'مش', 'وقته', 'قشطة', 'يعنى', 'الا', 'لاي', 'ايم', 'يمو', 'موش', 'وشن', 'شنز', 'الل', 'للى', 'بيع', 'يعي', 'عيط', 'الض', 'لضح', 'ضحك', 'وال', 'الق', 'لقل', 'قلو', 'لوب', 'الخ', 'لخض', 'خضر', 'ضرا', 'وال', 'الح', 'لحم', 'حمر', 'مرا', 'وال', 'الح', 'لحا', 'حاج', 'اجا', 'جات', 'بتن', 'تنز', 'نزل', 'للب', 'لبر', 'برو', 'روز', 'وزر', 'عار', 'ارف', 'وقت', 'قته', 'قشط', 'شطة', 'يعن', 'عنى', 'الاي', 'لايم', 'ايمو', 'يموش', 'موشن', 'وشنز', 'بيعي', 'يعيط', 'الضح', 'لضحك', 'والق', 'القل', 'لقلو', 'قلوب', 'الخض', 'لخضر', 'خضرا', 'والح', 'الحم', 'لحمر', 'حمرا', 'والح', 'الحا', 'لحاج', 'حاجا', 'اجات', 'بتنز', 'تنزل', 'للبر', 'لبرو', 'بروز', 'روزر'], 'neu')
# (['مش', 'جمب', 'مني', 'عزيز', 'عليا', 'غايب', 'عنايا', 'هقول', 'بعيد', 'ناس', 'ناسيهم', 'قلبي', 'وهما', 'قصاد', 'عنيا', 'وناس', 'مجرد', 'افتكرها', 'بكون', 'سعيد', 'عزي', 'زيز', 'علي', 'ليا', 'غاي', 'ايب', 'عنا', 'ناي', 'ايا', 'هقو', 'قول', 'بعي', 'عيد', 'ناس', 'اسي', 'سيه', 'يهم', 'قلب', 'لبي', 'وهم', 'هما', 'قصا', 'صاد', 'عني', 'نيا', 'ونا', 'ناس', 'مجر', 'جرد', 'افت', 'فتك', 'تكر', 'كره', 'رها', 'بكو', 'كون', 'سعي', 'عيد', 'عناي', 'نايا', 'ناسي', 'اسيه', 'سيهم', 'افتك', 'فتكر', 'تكره', 'كرها'], 'neu')
# (['تسريب', 'الشرق', 'لمكتب', 'السيسي', 'أسوأ', 'التسريبات', 'الحاجة', 'وتلاتين', 'فهي', 'تختصر', 'قيمة', 'الانسان', 'العسكر', 'تسر', 'سري', 'ريب', 'الش', 'لشر', 'شرق', 'لمك', 'مكت', 'كتب', 'الس', 'لسي', 'سيس', 'يسي', 'أسو', 'سوأ', 'الت', 'لتس', 'تسر', 'سري', 'ريب', 'يبا', 'بات', 'الح', 'لحا', 'حاج', 'اجة', 'وتل', 'تلا', 'لات', 'اتي', 'تين', 'تخت', 'ختص', 'تصر', 'قيم', 'يمة', 'الا', 'لان', 'انس', 'نسا', 'سان', 'الع', 'لعس', 'عسك', 'سكر', 'تسري', 'سريب', 'الشر', 'لشرق', 'لمكت', 'مكتب', 'السي', 'لسيس', 'سيسي', 'التس', 'لتسر', 'تسري', 'سريب', 'ريبا', 'يبات', 'الحا', 'لحاج', 'حاجة', 'وتلا', 'تلات', 'لاتي', 'اتين', 'تختص', 'ختصر', 'الان', 'لانس', 'انسا', 'نسان', 'العس', 'لعسك', 'عسكر'], 'neg')
# (['التشكيل', 'الخاطئ', 'جاريدو', 'وإفتقاد', 'اللاعبين', 'للروح', 'الت', 'لتش', 'تشك', 'شكي', 'كيل', 'الخ', 'لخا', 'خاط', 'اطئ', 'جار', 'اري', 'ريد', 'يدو', 'وإف', 'إفت', 'فتق', 'تقا', 'قاد', 'الل', 'للا', 'لاع', 'اعب', 'عبي', 'بين', 'للر', 'لرو', 'روح', 'التش', 'لتشك', 'تشكي', 'شكيل', 'الخا', 'لخاط', 'خاطئ', 'جاري', 'اريد', 'ريدو', 'وإفت', 'إفتق', 'فتقا', 'تقاد', 'اللا', 'للاع', 'لاعب', 'اعبي', 'عبين', 'للرو', 'لروح'], 'neg')
# (['اربعة', 'اصفار', 'الساعة', 'وبداية', 'يوم', 'جديد', 'حياة', 'منتهية', 'ارب', 'ربع', 'بعة', 'اصف', 'صفا', 'فار', 'الس', 'لسا', 'ساع', 'اعة', 'وبد', 'بدا', 'داي', 'اية', 'جدي', 'ديد', 'حيا', 'ياة', 'منت', 'نته', 'تهي', 'هية', 'اربع', 'ربعة', 'اصفا', 'صفار', 'السا', 'لساع', 'ساعة', 'وبدا', 'بداي', 'داية', 'منته', 'نتهي', 'تهية'], 'neu')
# (['انا', 'ملاانة', 'ملا', 'لاا', 'اان', 'انة', 'ملاا', 'لاان', 'اانة'], 'neg')
# (['انام', 'اصحى', 'الاقي', 'قلة', 'الادب', 'دي', 'انا', 'نام', 'اصح', 'صحى', 'الا', 'لاق', 'اقي', 'الا', 'لاد', 'ادب', 'الاق', 'لاقي', 'الاد', 'لادب'], 'neg')
# (['ياابنى', 'انت', 'وهوه', 'خدوا', 'بالكم', 'فرق', 'الاقتصاد', 'القبلى', 'العائلى', 'والاقتصاد', 'القومى', 'القومى', 'بناع', 'الدول', 'ده', 'كبير', 'ومستوى', 'تانى', 'خالص', 'ياا', 'ااب', 'ابن', 'بنى', 'وهو', 'هوه', 'خدو', 'دوا', 'بال', 'الك', 'لكم', 'الا', 'لاق', 'اقت', 'قتص', 'تصا', 'صاد', 'الق', 'لقب', 'قبل', 'بلى', 'الع', 'لعا', 'عائ', 'ائل', 'ئلى', 'وال', 'الا', 'لاق', 'اقت', 'قتص', 'تصا', 'صاد', 'الق', 'لقو', 'قوم', 'ومى', 'الق', 'لقو', 'قوم', 'ومى', 'بنا', 'ناع', 'الد', 'لدو', 'دول', 'كبي', 'بير', 'ومس', 'مست', 'ستو', 'توى', 'تان', 'انى', 'خال', 'الص', 'يااب', 'اابن', 'ابنى', 'بالك', 'الكم', 'الاق', 'لاقت', 'اقتص', 'قتصا', 'تصاد', 'القب', 'لقبل', 'قبلى', 'العا', 'لعائ', 'عائل', 'ائلى', 'والا', 'الاق', 'لاقت', 'اقتص', 'قتصا', 'تصاد', 'القو', 'لقوم', 'قومى', 'القو', 'لقوم', 'قومى', 'الدو', 'لدول', 'ومست', 'مستو', 'ستوى'], 'neu')
# (['متبقيش', 'بنت', 'منزلة', 'تويتات', 'سفالة', 'وصور', 'تدل', 'البيئة', 'الا', 'انتي', 'وتقولي', 'تويتر', 'بقي', 'حك', 'كتير', 'متب', 'تبق', 'بقي', 'قيش', 'منز', 'نزل', 'زلة', 'توي', 'ويت', 'يتا', 'تات', 'سفا', 'فال', 'الة', 'وصو', 'صور', 'الب', 'لبي', 'بيئ', 'يئة', 'انت', 'نتي', 'وتق', 'تقو', 'قول', 'ولي', 'توي', 'ويت', 'يتر', 'كتي', 'تير', 'متبق', 'تبقي', 'بقيش', 'منزل', 'نزلة', 'تويت', 'ويتا', 'يتات', 'سفال', 'فالة', 'البي', 'لبيئ', 'بيئة', 'وتقو', 'تقول', 'قولي', 'تويت', 'ويتر'], 'neg')
# (['ده', 'انا', 'عايشه', 'عشانك', 'عاي', 'ايش', 'يشه', 'عشا', 'شان', 'انك', 'عايش', 'ايشه', 'عشان', 'شانك'], 'pos')
# (['انصرنا', 'انصرنا', 'يارب', 'انصرناا', 'انص', 'نصر', 'صرن', 'رنا', 'انص', 'نصر', 'صرن', 'رنا', 'يار', 'ارب', 'انص', 'نصر', 'صرن', 'رنا', 'ناا', 'انصر', 'نصرن', 'صرنا', 'انصر', 'نصرن', 'صرنا', 'انصر', 'نصرن', 'صرنا', 'رناا'], 'pos')
# (['سامحك', 'الله', 'مك', 'تكون', 'خيبة', 'سام', 'امح', 'محك', 'الل', 'لله', 'تكو', 'كون', 'خيب', 'يبة', 'سامح', 'امحك'], 'neg')
# (['انا', 'عايز', 'احكى', 'قصة', 'محتاج', 'حد', 'يكتبها', 'معايا', 'حد', 'راشق', 'عاي', 'ايز', 'احك', 'حكى', 'محت', 'حتا', 'تاج', 'يكت', 'كتب', 'تبه', 'بها', 'معا', 'عاي', 'ايا', 'راش', 'اشق', 'محتا', 'حتاج', 'يكتب', 'كتبه', 'تبها', 'معاي', 'عايا'], 'neu')
# (['يعش', 'ببساطة', 'ويتعامل', 'بأناقة', 'يجبر', 'الجميع', 'احترامه', 'وحبه', 'بسيط', 'تكن', 'أجمل', 'ببس', 'بسا', 'ساط', 'اطة', 'ويت', 'يتع', 'تعا', 'عام', 'امل', 'بأن', 'أنا', 'ناق', 'اقة', 'يجب', 'جبر', 'الج', 'لجم', 'جمي', 'ميع', 'احت', 'حتر', 'ترا', 'رام', 'امه', 'وحب', 'حبه', 'بسي', 'سيط', 'أجم', 'جمل', 'ببسا', 'بساط', 'ساطة', 'ويتع', 'يتعا', 'تعام', 'عامل', 'بأنا', 'أناق', 'ناقة', 'الجم', 'لجمي', 'جميع', 'احتر', 'حترا', 'ترام', 'رامه'], 'pos')
# (['اعلم', 'الله', 'اعل', 'علم', 'الل', 'لله'], 'pos')
# (['حكم', 'ابن', 'وسخه', 'هيودينا', 'دهيه', 'وسخ', 'سخه', 'هيو', 'يود', 'ودي', 'دين', 'ينا', 'دهي', 'هيه', 'هيود', 'يودي', 'ودين', 'دينا'], 'neg')
# (['فى', 'انت', 'حر', 'مدحت', 'العدل', 'حنكون', 'فى', 'انتظارك', 'ياملكة', 'اطربينا', 'بااجمل', 'اىعانى', 'بصوتك', 'العذب', 'والاحساس', 'الرائع', 'والطرب', 'الاصيل', 'مدح', 'دحت', 'الع', 'لعد', 'عدل', 'حنك', 'نكو', 'كون', 'انت', 'نتظ', 'تظا', 'ظار', 'ارك', 'يام', 'امل', 'ملك', 'لكة', 'اطر', 'طرب', 'ربي', 'بين', 'ينا', 'باا', 'ااج', 'اجم', 'جمل', 'اىع', 'ىعا', 'عان', 'انى', 'بصو', 'صوت', 'وتك', 'الع', 'لعذ', 'عذب', 'وال', 'الا', 'لاح', 'احس', 'حسا', 'ساس', 'الر', 'لرا', 'رائ', 'ائع', 'وال', 'الط', 'لطر', 'طرب', 'الا', 'لاص', 'اصي', 'صيل', 'العد', 'لعدل', 'حنكو', 'نكون', 'انتظ', 'نتظا', 'تظار', 'ظارك', 'يامل', 'املك', 'ملكة', 'اطرب', 'طربي', 'ربين', 'بينا', 'بااج', 'ااجم', 'اجمل', 'اىعا', 'ىعان', 'عانى', 'بصوت', 'صوتك', 'العذ', 'لعذب', 'والا', 'الاح', 'لاحس', 'احسا', 'حساس', 'الرا', 'لرائ', 'رائع', 'والط', 'الطر', 'لطرب', 'الاص', 'لاصي', 'اصيل'], 'pos')
# (['ربك', 'بغافل', 'تعملون', 'بغا', 'غاف', 'افل', 'تعم', 'عمل', 'ملو', 'لون', 'بغاف', 'غافل', 'تعمل', 'عملو', 'ملون'], 'neu')
# (['ننسي', 'الأندلس', 'ننس', 'نسي', 'الأ', 'لأن', 'أند', 'ندل', 'دلس', 'الأن', 'لأند', 'أندل', 'ندلس'], 'neu')
# (['موافقه', 'جدا', 'موا', 'واف', 'افق', 'فقه', 'مواف', 'وافق', 'افقه'], 'pos')
# (['ريتك', 'معايا', 'تطوفي', 'وسط', 'البشر', 'والزحام', 'وتشوفي', 'حيرتي', 'وخوفي', 'عليكي', 'دي', 'الالآم', 'ريت', 'يتك', 'معا', 'عاي', 'ايا', 'تطو', 'طوف', 'وفي', 'الب', 'لبش', 'بشر', 'وال', 'الز', 'لزح', 'زحا', 'حام', 'وتش', 'تشو', 'شوف', 'وفي', 'حير', 'يرت', 'رتي', 'وخو', 'خوف', 'وفي', 'علي', 'ليك', 'يكي', 'الا', 'لال', 'الآ', 'لآم', 'معاي', 'عايا', 'تطوف', 'طوفي', 'البش', 'لبشر', 'والز', 'الزح', 'لزحا', 'زحام', 'وتشو', 'تشوف', 'شوفي', 'حيرت', 'يرتي', 'وخوف', 'خوفي', 'عليك', 'ليكي', 'الال', 'لالآ', 'الآم'], 'neg')
# (['تم', 'زميلى', 'زمي', 'ميل', 'يلى', 'زميل', 'ميلى'], 'neu')
# (['بكره', 'الأتحاد', 'بكرهوو', 'بكر', 'كره', 'الأ', 'لأت', 'أتح', 'تحا', 'حاد', 'بكر', 'كره', 'رهو', 'هوو', 'الأت', 'لأتح', 'أتحا', 'تحاد', 'بكره', 'كرهو', 'رهوو'], 'neg')
# (['ماشي', 'كمان', 'مرة', 'عشان', 'خاطر', 'رودينا', 'فولورز', 'رودينا', 'هيحتلو', 'التريند', 'ماش', 'اشي', 'كما', 'مان', 'عشا', 'شان', 'خاط', 'اطر', 'رود', 'ودي', 'دين', 'ينا', 'فول', 'ولو', 'لور', 'ورز', 'رود', 'ودي', 'دين', 'ينا', 'هيح', 'يحت', 'حتل', 'تلو', 'الت', 'لتر', 'تري', 'رين', 'يند', 'رودي', 'ودين', 'دينا', 'فولو', 'ولور', 'لورز', 'رودي', 'ودين', 'دينا', 'هيحت', 'يحتل', 'حتلو', 'التر', 'لتري', 'ترين', 'ريند'], 'pos')
# (['موجز', 'الصحف', 'العربية', 'موج', 'وجز', 'الص', 'لصح', 'صحف', 'الع', 'لعر', 'عرب', 'ربي', 'بية', 'الصح', 'لصحف', 'العر', 'لعرب', 'عربي', 'ربية'], 'neu')
# (['زهقنا', 'اي', 'حد', 'بيقول', 'معلومه', 'وغير', 'بيها', 'حياة', 'ناس', 'وهي', 'غلط', 'زهق', 'هقن', 'قنا', 'بيق', 'يقو', 'قول', 'معل', 'علو', 'لوم', 'ومه', 'وغي', 'غير', 'بيه', 'يها', 'حيا', 'ياة', 'زهقن', 'هقنا', 'بيقو', 'يقول', 'معلو', 'علوم', 'لومه'], 'neg')
# (['ازيك', 'ازي', 'زيك'], 'neu')
# (['دا', 'الدين', 'عرف', 'الحر', 'مذلة', 'مر', 'الد', 'لدي', 'دين', 'الح', 'لحر', 'مذل', 'ذلة', 'الدي', 'لدين'], 'neg')
# (['اه', 'الله', 'تعبنا', 'فشخ', 'الل', 'لله', 'تعب', 'عبن', 'بنا', 'تعبن', 'عبنا'], 'neg')
# (['الأطفال', 'ليهم', 'الحق', 'فـ', 'رأيهم', 'السياسي', 'أصل', 'طفل', 'يبقى', 'صاحبه', 'معتقل', 'او', 'شهيد', 'اكيد', 'مش', 'هيسكت', 'الأ', 'لأط', 'أطف', 'طفا', 'فال', 'ليه', 'يهم', 'الح', 'لحق', 'رأي', 'أيه', 'يهم', 'الس', 'لسي', 'سيا', 'ياس', 'اسي', 'يبق', 'بقى', 'صاح', 'احب', 'حبه', 'معت', 'عتق', 'تقل', 'شهي', 'هيد', 'اكي', 'كيد', 'هيس', 'يسك', 'سكت', 'الأط', 'لأطف', 'أطفا', 'طفال', 'رأيه', 'أيهم', 'السي', 'لسيا', 'سياس', 'ياسي', 'صاحب', 'احبه', 'معتق', 'عتقل', 'هيسك', 'يسكت'], 'neu')
# (['خبر', 'يغطى', 'التسريبات', 'القبض', 'قاتل', 'سعاد', 'حسنى', 'يغط', 'غطى', 'الت', 'لتس', 'تسر', 'سري', 'ريب', 'يبا', 'بات', 'الق', 'لقب', 'قبض', 'قات', 'اتل', 'سعا', 'عاد', 'حسن', 'سنى', 'التس', 'لتسر', 'تسري', 'سريب', 'ريبا', 'يبات', 'القب', 'لقبض'], 'neu')
# (['عاجل', 'تردد', 'قنوات', 'الجزيره', 'مباشر', 'مصر', 'التركيه', 'دا', 'التردد', 'ياشباب', 'علي', 'معدل', 'ترميز', 'مدار', 'نايل', 'سات', 'مبروك', 'يااحرار', 'شير', 'عاج', 'اجل', 'ترد', 'ردد', 'قنو', 'نوا', 'وات', 'الج', 'لجز', 'جزي', 'زير', 'يره', 'مبا', 'باش', 'اشر', 'الت', 'لتر', 'ترك', 'ركي', 'كيه', 'الت', 'لتر', 'ترد', 'ردد', 'ياش', 'اشب', 'شبا', 'باب', 'معد', 'عدل', 'ترم', 'رمي', 'ميز', 'مدا', 'دار', 'ناي', 'ايل', 'مبر', 'برو', 'روك', 'ياا', 'ااح', 'احر', 'حرا', 'رار', 'قنوا', 'نوات', 'الجز', 'لجزي', 'جزير', 'زيره', 'مباش', 'باشر', 'التر', 'لترك', 'تركي', 'ركيه', 'التر', 'لترد', 'تردد', 'ياشب', 'اشبا', 'شباب', 'ترمي', 'رميز', 'مبرو', 'بروك', 'يااح', 'ااحر', 'احرا', 'حرار'], 'neu')
# (['مييرسي', 'ميي', 'يير', 'يرس', 'رسي', 'ميير', 'ييرس', 'يرسي'], 'pos')
# (['الجهل', 'يحقق', 'رابطة', 'متينة', 'الفئات', 'المصابة', 'ويرصها', 'جميعا', 'صفا', 'واحدا', 'ضد', 'الأعداء', 'وراء', 'الجدار', 'حالة', 'استعداد', 'دائمة', 'للبدء', 'القتال', 'الج', 'لجه', 'جهل', 'يحق', 'حقق', 'راب', 'ابط', 'بطة', 'متي', 'تين', 'ينة', 'الف', 'لفئ', 'فئا', 'ئات', 'الم', 'لمص', 'مصا', 'صاب', 'ابة', 'وير', 'يرص', 'رصه', 'صها', 'جمي', 'ميع', 'يعا', 'واح', 'احد', 'حدا', 'الأ', 'لأع', 'أعد', 'عدا', 'داء', 'ورا', 'راء', 'الج', 'لجد', 'جدا', 'دار', 'حال', 'الة', 'است', 'ستع', 'تعد', 'عدا', 'داد', 'دائ', 'ائم', 'ئمة', 'للب', 'لبد', 'بدء', 'الق', 'لقت', 'قتا', 'تال', 'الجه', 'لجهل', 'رابط', 'ابطة', 'متين', 'تينة', 'الفئ', 'لفئا', 'فئات', 'المص', 'لمصا', 'مصاب', 'صابة', 'ويرص', 'يرصه', 'رصها', 'جميع', 'ميعا', 'واحد', 'احدا', 'الأع', 'لأعد', 'أعدا', 'عداء', 'الجد', 'لجدا', 'جدار', 'استع', 'ستعد', 'تعدا', 'عداد', 'دائم', 'ائمة', 'للبد', 'لبدء', 'القت', 'لقتا', 'قتال'], 'neg')
# (['بهواك', 'بهو', 'هوا', 'واك', 'بهوا', 'هواك'], 'pos')
# (['نمرة', 'السلامة', 'ألبوم', 'اسمعني', 'خلال', 'نمر', 'مرة', 'الس', 'لسل', 'سلا', 'لام', 'امة', 'ألب', 'لبو', 'بوم', 'اسم', 'سمع', 'معن', 'عني', 'خلا', 'لال', 'السل', 'لسلا', 'سلام', 'لامة', 'ألبو', 'لبوم', 'اسمع', 'سمعن', 'معني'], 'neu')
# (['احبك', 'بصدق', 'ابعد', 'عنك', 'يجرحك', 'احب', 'حبك', 'بصد', 'صدق', 'ابع', 'بعد', 'يجر', 'جرح', 'رحك', 'يجرح', 'جرحك'], 'pos')
# (['الله', 'يسمح', 'دروبك', 'الل', 'لله', 'يسم', 'سمح', 'درو', 'روب', 'وبك', 'دروب', 'روبك'], 'neu')
# (['فورد', 'توورس', 'بوابة', 'المصدر', 'شاهد', 'الاعلان', 'بالكامل', 'فور', 'ورد', 'توو', 'وور', 'ورس', 'بوا', 'واب', 'ابة', 'الم', 'لمص', 'مصد', 'صدر', 'شاه', 'اهد', 'الا', 'لاع', 'اعل', 'علا', 'لان', 'بال', 'الك', 'لكا', 'كام', 'امل', 'توور', 'وورس', 'بواب', 'وابة', 'المص', 'لمصد', 'مصدر', 'الاع', 'لاعل', 'اعلا', 'علان', 'بالك', 'الكا', 'لكام', 'كامل'], 'neu')
# (['بالفيديو', 'نوال', 'الزغبي', 'أطلقت', 'كليب', 'أغنيتها', 'الهيت', 'بحبك', 'بال', 'الف', 'لفي', 'فيد', 'يدي', 'ديو', 'نوا', 'وال', 'الز', 'لزغ', 'زغب', 'غبي', 'أطل', 'طلق', 'لقت', 'كلي', 'ليب', 'أغن', 'غني', 'نيت', 'يته', 'تها', 'اله', 'لهي', 'هيت', 'بحب', 'حبك', 'بالف', 'الفي', 'لفيد', 'فيدي', 'يديو', 'الزغ', 'لزغب', 'زغبي', 'أطلق', 'طلقت', 'أغني', 'غنيت', 'نيته', 'يتها', 'الهي', 'لهيت'], 'neu')
# (['اعتاد', 'ان', 'يوزع', 'الورد', 'سيبقى', 'شيئ', 'العطر', 'بيده', 'اعت', 'عتا', 'تاد', 'يوز', 'وزع', 'الو', 'لور', 'ورد', 'سيب', 'يبق', 'بقى', 'الع', 'لعط', 'عطر', 'بيد', 'يده', 'اعتا', 'عتاد', 'الور', 'لورد', 'سيبق', 'يبقى', 'العط', 'لعطر'], 'pos')
# (['البنقدر', 'عليو', 'نحلم', 'بكره', 'احسن', 'ماورديين', 'برضو', 'مسودنها', 'شدييد', 'الب', 'لبن', 'بنق', 'نقد', 'قدر', 'علي', 'ليو', 'نحل', 'حلم', 'بكر', 'كره', 'احس', 'حسن', 'ماو', 'اور', 'ورد', 'ردي', 'ديي', 'يين', 'برض', 'رضو', 'مسو', 'سود', 'ودن', 'دنه', 'نها', 'شدي', 'ديي', 'ييد', 'البن', 'لبنق', 'بنقد', 'نقدر', 'ماور', 'اورد', 'وردي', 'رديي', 'ديين', 'مسود', 'سودن', 'ودنه', 'دنها', 'شديي', 'دييد'], 'pos')
# (['مراحل', 'حياة', 'الإنسان', 'الميلاد', 'أحا', 'فى', 'الموت', 'مرا', 'راح', 'احل', 'حيا', 'ياة', 'الإ', 'لإن', 'إنس', 'نسا', 'سان', 'الم', 'لمي', 'ميل', 'يلا', 'لاد', 'الم', 'لمو', 'موت', 'مراح', 'راحل', 'الإن', 'لإنس', 'إنسا', 'نسان', 'المي', 'لميل', 'ميلا', 'يلاد', 'المو', 'لموت'], 'neg')
# (['ظن', 'ان', 'الرزق', 'ياتى', 'بقوه', 'اكل', 'العصفور', 'شيئا', 'النسر', 'تزول', 'الدنيا', 'فانك', 'لاتدرىاذا', 'جن', 'الليل', 'تعيش', 'الى', 'الفجر', 'الامام', 'الشافعى', 'الر', 'لرز', 'رزق', 'يات', 'اتى', 'بقو', 'قوه', 'الع', 'لعص', 'عصف', 'صفو', 'فور', 'شيئ', 'يئا', 'الن', 'لنس', 'نسر', 'تزو', 'زول', 'الد', 'لدن', 'دني', 'نيا', 'فان', 'انك', 'لات', 'اتد', 'تدر', 'درى', 'رىا', 'ىاذ', 'اذا', 'الل', 'للي', 'ليل', 'تعي', 'عيش', 'الف', 'لفج', 'فجر', 'الا', 'لام', 'اما', 'مام', 'الش', 'لشا', 'شاف', 'افع', 'فعى', 'الرز', 'لرزق', 'العص', 'لعصف', 'عصفو', 'صفور', 'النس', 'لنسر', 'الدن', 'لدني', 'دنيا', 'لاتد', 'اتدر', 'تدرى', 'درىا', 'رىاذ', 'ىاذا', 'اللي', 'لليل', 'الفج', 'لفجر', 'الام', 'لاما', 'امام', 'الشا', 'لشاف', 'شافع', 'افعى'], 'pos')
# (['تنسوا', 'الفضل', 'بينكم', 'قرءان', 'تنس', 'نسو', 'سوا', 'الف', 'لفض', 'فضل', 'بين', 'ينك', 'نكم', 'قرء', 'رءا', 'ءان', 'تنسو', 'نسوا', 'الفض', 'لفضل', 'بينك', 'ينكم', 'قرءا', 'رءان'], 'pos')
# (['الأهلي', 'سيد', 'الدوري', 'الأ', 'لأه', 'أهل', 'هلي', 'الد', 'لدو', 'دور', 'وري', 'الأه', 'لأهل', 'أهلي', 'الدو', 'لدور', 'دوري'], 'pos')
# (['قناه', 'مكملين', 'عرضت', 'التسريب', 'قنا', 'ناه', 'مكم', 'كمل', 'ملي', 'لين', 'عرض', 'رضت', 'الت', 'لتس', 'تسر', 'سري', 'ريب', 'مكمل', 'كملي', 'ملين', 'التس', 'لتسر', 'تسري', 'سريب'], 'neu')
# (['إليسا', 'النجمة', 'الأولى', 'عربيا', 'أنغامي', 'لعام', 'وكليبها', 'حب', 'حياتي', 'يحقق', 'مليون', 'مشاهدة', 'إلي', 'ليس', 'يسا', 'الن', 'لنج', 'نجم', 'جمة', 'الأ', 'لأو', 'أول', 'ولى', 'عرب', 'ربي', 'بيا', 'أنغ', 'نغا', 'غام', 'امي', 'لعا', 'عام', 'وكل', 'كلي', 'ليب', 'يبه', 'بها', 'حيا', 'يات', 'اتي', 'يحق', 'حقق', 'ملي', 'ليو', 'يون', 'مشا', 'شاه', 'اهد', 'هدة', 'إليس', 'ليسا', 'النج', 'لنجم', 'نجمة', 'الأو', 'لأول', 'أولى', 'عربي', 'ربيا', 'أنغا', 'نغام', 'غامي', 'وكلي', 'كليب', 'ليبه', 'يبها', 'حيات', 'ياتي', 'مليو', 'ليون', 'مشاه', 'شاهد', 'اهدة'], 'neu')
# (['كسبنا', 'دمنهور', 'متصدر', 'تكلمني', 'المصري', 'هيعملها', 'انبي', 'كسب', 'سبن', 'بنا', 'دمن', 'منه', 'نهو', 'هور', 'متص', 'تصد', 'صدر', 'تكل', 'كلم', 'لمن', 'مني', 'الم', 'لمص', 'مصر', 'صري', 'هيع', 'يعم', 'عمل', 'مله', 'لها', 'انب', 'نبي', 'كسبن', 'سبنا', 'دمنه', 'منهو', 'نهور', 'متصد', 'تصدر', 'تكلم', 'كلمن', 'لمني', 'المص', 'لمصر', 'مصري', 'هيعم', 'يعمل', 'عمله', 'ملها'], 'pos')
# (['امراه', 'رائعه', 'امر', 'مرا', 'راه', 'رائ', 'ائع', 'ئعه', 'امرا', 'مراه', 'رائع', 'ائعه'], 'pos')
# (['اهنا', 'دايما', 'محتاجين', 'ربنا', 'مش', 'وقت', 'زنقه', 'اهن', 'هنا', 'داي', 'ايم', 'يما', 'محت', 'حتا', 'تاج', 'اجي', 'جين', 'ربن', 'بنا', 'زنق', 'نقه', 'دايم', 'ايما', 'محتا', 'حتاج', 'تاجي', 'اجين'], 'pos')
# (['تصبحو', 'علي', 'خير', 'تصب', 'صبح', 'بحو', 'تصبح', 'صبحو'], 'neu')
# (['عبد', 'المنعم', 'محمود', 'ياترى', 'كام', 'زى', 'محمد', 'لسه', 'فى', 'الأخوان', 'يكتشف', 'الم', 'لمن', 'منع', 'نعم', 'محم', 'حمو', 'مود', 'يات', 'اتر', 'ترى', 'محم', 'حمد', 'الأ', 'لأخ', 'أخو', 'خوا', 'وان', 'يكت', 'كتش', 'تشف', 'المن', 'لمنع', 'منعم', 'محمو', 'حمود', 'ياتر', 'اترى', 'الأخ', 'لأخو', 'أخوا', 'خوان', 'يكتش', 'كتشف'], 'neu')
# (['لماذا', 'الدولة', 'الإسلامية', 'تذبح', 'الشيعة', 'والنصيرية', 'لما', 'ماذ', 'اذا', 'الد', 'لدو', 'دول', 'ولة', 'الإ', 'لإس', 'إسل', 'سلا', 'لام', 'امي', 'مية', 'تذب', 'ذبح', 'الش', 'لشي', 'شيع', 'يعة', 'وال', 'الن', 'لنص', 'نصي', 'صير', 'يري', 'رية', 'لماذ', 'ماذا', 'الدو', 'لدول', 'دولة', 'الإس', 'لإسل', 'إسلا', 'سلام', 'لامي', 'امية', 'الشي', 'لشيع', 'شيعة', 'والن', 'النص', 'لنصي', 'نصير', 'صيري', 'يرية'], 'neg')
# (['الله', 'يسامحك', 'مابي', 'أدعي', 'بلحظه', 'غضب', 'الل', 'لله', 'يسا', 'سام', 'امح', 'محك', 'ماب', 'ابي', 'أدع', 'دعي', 'بلح', 'لحظ', 'حظه', 'يسام', 'سامح', 'امحك', 'بلحظ', 'لحظه'], 'neg')
# (['هه'], 'pos')
# (['ماسبق', 'أسئلة', 'مفيد', 'فوزي', 'العميقة', 'ليسرا', 'حدث', 'حالا', 'شلل', 'الحقوني', 'ماس', 'اسب', 'سبق', 'أسئ', 'سئل', 'ئلة', 'مفي', 'فيد', 'فوز', 'وزي', 'الع', 'لعم', 'عمي', 'ميق', 'يقة', 'ليس', 'يسر', 'سرا', 'حال', 'الا', 'الح', 'لحق', 'حقو', 'قون', 'وني', 'ماسب', 'اسبق', 'أسئل', 'سئلة', 'العم', 'لعمي', 'عميق', 'ميقة', 'ليسر', 'يسرا', 'الحق', 'لحقو', 'حقون', 'قوني'], 'neg')
# (['الكفن', 'ملوش', 'جيوب', 'يتحط', 'الفلوس', 'الك', 'لكف', 'كفن', 'ملو', 'لوش', 'جيو', 'يوب', 'يتح', 'تحط', 'الف', 'لفل', 'فلو', 'لوس', 'الكف', 'لكفن', 'الفل', 'لفلو', 'فلوس'], 'neg')
# (['مالها', 'كنزه', 'يعني', 'مال', 'اله', 'لها', 'كنز', 'نزه', 'يعن', 'عني', 'ماله', 'الها'], 'neu')
# (['ربنا', 'يخليكم', 'لبعض', 'ربن', 'بنا', 'يخل', 'خلي', 'ليك', 'يكم', 'لبع', 'بعض', 'يخلي', 'خليك', 'ليكم'], 'pos')
# (['أجد', 'حل', 'يحل', 'محل', 'الحال', 'الحالي', 'لحالتي', 'حاليا', 'الح', 'لحا', 'حال', 'الح', 'لحا', 'حال', 'الي', 'لحا', 'حال', 'الت', 'لتي', 'حال', 'الي', 'ليا', 'الحا', 'لحال', 'الحا', 'لحال', 'حالي', 'لحال', 'حالت', 'التي', 'حالي', 'اليا'], 'neg')
# (['الله', 'يوفق', 'طلاب', 'التوجيي', 'يضيع', 'لحدا', 'تعب', 'ويفرح', 'اهاليهم', 'بنجاحهم', 'رب', 'الل', 'لله', 'يوف', 'وفق', 'طلا', 'لاب', 'الت', 'لتو', 'توج', 'وجي', 'جيي', 'يضي', 'ضيع', 'لحد', 'حدا', 'ويف', 'يفر', 'فرح', 'اها', 'هال', 'الي', 'ليه', 'يهم', 'بنج', 'نجا', 'جاح', 'احه', 'حهم', 'التو', 'لتوج', 'توجي', 'وجيي', 'ويفر', 'يفرح', 'اهال', 'هالي', 'اليه', 'ليهم', 'بنجا', 'نجاح', 'جاحه', 'احهم'], 'pos')
# (['عام', 'وانت', 'بالف', 'خير', 'ينعاد', 'فلسطين', 'وع', 'البلدان', 'بالخير', 'والمحبة', 'والسلام', 'وان', 'انت', 'بال', 'الف', 'ينع', 'نعا', 'عاد', 'فلس', 'لسط', 'سطي', 'طين', 'الب', 'لبل', 'بلد', 'لدا', 'دان', 'بال', 'الخ', 'لخي', 'خير', 'وال', 'الم', 'لمح', 'محب', 'حبة', 'وال', 'الس', 'لسل', 'سلا', 'لام', 'ينعا', 'نعاد', 'فلسط', 'لسطي', 'سطين', 'البل', 'لبلد', 'بلدا', 'لدان', 'بالخ', 'الخي', 'لخير', 'والم', 'المح', 'لمحب', 'محبة', 'والس', 'السل', 'لسلا', 'سلام'], 'pos')
# (['كسم', 'مدريد', 'ياعم', 'مدر', 'دري', 'ريد', 'ياع', 'اعم', 'مدري', 'دريد'], 'neg')

# %% [markdown]
# # Test data info

# %%
# print('test data info')
# test_data = 
# print('test data size', len(train_data))
# print('# of positive', len(pos_test_data))
# print('# of negative', len(neg_test_data))

# %% [markdown]
# # merging all features ...

# %%
print('merging all features ... ')
all_features = train_feat + test_feat
print('len(all_features):', len(all_features))
# Out:
# merging all features ...
# len(all_features): 112650

# %% [markdown]
# # Sample features

# %%
print('{} sample features ...'.format(sample_size))
print(random.sample(all_features, sample_size))
# Out:
# 100 sample features ...
# ['عدش', 'ليثي', 'اضحكوا', 'مسا', 'قصو', 'البلونة', 'الم', 'اعه', 'احا', 'بيد', 'ستم', 'فضل', 'يحطو', 'فرح', 'الا', 'السا', 'حزان', 'تشبهني', 'حبيبه', 'واحش', 'لناد', 'الجر', 'شهي', 'الصع', 'حد', 'شان', 'السي', 'لات', 'يكو', 'دري', 'كسم', 'عايزة', 'يران', 'يرن', 'تايهين', 'خلي', 'لافتتاح', 'لأوط', 'لنكد', 'شرموطه', 'اعات', 'غرت', 'الد', 'جوه', 'سطي', 'لمن', 'روح', 'تحطلها', 'الص', 'جين', 'تأدية', 'الرح', 'رير', 'كاتف', 'كنت', 'ينا', 'بلقاء', 'وفيق', 'سود', 'ايف', 'محبت', 'انتر', 'خير', 'خلـقا', 'عقاب', 'وسيك', 'وهته', 'الزي', 'وبلن', 'اخدي', 'عارف', 'وال', 'ايدة', 'بيتنا', 'لمهم', 'قلب', 'شعل', 'لوق', 'وات', 'يارب', 'الدي', 'لأع', 'كري', 'الس', 'الن', 'وال', 'وعل', 'قعها', 'لعال', 'ازا', 'وال', 'رافع', 'وتعددت', 'فقك', 'صاد', 'لشا', 'حد', 'اقف', 'يبو', 'لمر']

# %% [markdown]
# # compute frequencies

# %%
all_features_count = {}
for w in all_features:
    all_features_count[w] = all_features_count.get(w, 0) + 1

# %%
all_features_count
# Out:
# {'صلاة': 9,
#  'الفجر': 8,
#  'ركعتين': 2,
#  'ادين': 8,
#  'ربنا': 86,
#  'الدنيا': 39,
#  'كلها': 20,
#  'صلا': 46,
#  'لاة': 9,
#  'الف': 165,
#  'لفج': 8,
#  'فجر': 12,
#  'ركع': 2,
#  'كعت': 2,
#  'عتي': 9,
#  'تين': 30,
#  'ادي': 58,
#  'دين': 73,
#  'ربن': 86,
#  'بنا': 146,
#  'الد': 127,
#  'لدن': 45,
#  'دني': 53,
#  'نيا': 58,
#  'كله': 75,
#  'لها': 82,
#  'الفج': 8,
#  'لفجر': 8,
#  'ركعت': 2,
#  'كعتي': 2,
#  'عتين': 4,
#  'الدن': 43,
#  'لدني': 43,
#  'دنيا': 46,
#  'مهو': 17,
#  'شغال': 6,
#  'عادى': 5,
#  'المشكله': 6,
#  'فى': 135,
#  'الفون': 1,
#  'حاول': 23,
#  'تحب': 32,
#  'اللاب': 1,
#  'بقى': 58,
#  'شغا': 7,
#  'غال': 19,
#  'عاد': 52,
#  'ادى': 12,
#  'الم': 488,
#  'لمش': 30,
#  'مشك': 22,
#  'شكل': 31,
#  'لفو': 11,
#  'فون': 12,
#  'حاو': 25,
#  'اول': 75,
#  'الل': 618,
#  'للا': 21,
#  'لاب': 34,
#  'المش': 29,
#  'لمشك': 13,
#  'مشكل': 21,
#  'شكله': 13,
#  'الفو': 9,
#  'لفون': 2,
#  'اللا': 6,
#  'للاب': 1,
#  'انا': 295,
#  'عايز': 38,
#  'حد': 85,
#  'يكون': 21,
#  'يفضل': 6,
#  'يايا': 1,
#  'بدون': 5,
#  'أسباب': 2,
#  'دورت': 1,
#  'فـ': 6,
#  'كشف': 6,
#  'اللى': 69,
#  'أعرفهم': 1,
#  'لقيتنى': 1,
#  'أخدت': 2,
#  'الكل': 56,
#  'غياب': 7,
#  'عاي': 77,
#  'ايز': 40,
#  'يكو': 36,
#  'كون': 84,
#  'يفض': 8,
#  'فضل': 50,
#  'ياي': 2,
#  'ايا': 53,
#  'بدو': 11,
#  'دون': 15,
#  'أسب': 9,
#  'سبا': 23,
#  'باب': 34,
#  'دور': 26,
#  'ورت': 17,
#  'للى': 70,
#  'أعر': 2,
#  'عرف': 79,
#  'رفه': 21,
#  'فهم': 26,
#  'لقي': 17,
#  'قيت': 16,
#  'يتن': 13,
#  'تنى': 10,
#  'أخد': 3,
#  'خدت': 7,
#  'الك': 204,
#  'لكل': 72,
#  'غيا': 8,
#  'ياب': 23,
#  'أسبا': 5,
#  'سباب': 4,
#  'أعرف': 2,
#  'عرفه': 7,
#  'رفهم': 2,
#  'لقيت': 5,
#  'قيتن': 2,
#  'يتنى': 1,
#  'خشيت': 1,
#  'علمي': 3,
#  'عشان': 81,
#  'احفظ': 5,
#  'طلع': 38,
#  'حفظ': 18,
#  'خشي': 2,
#  'شيت': 3,
#  'علم': 35,
#  'لمي': 47,
#  'عشا': 83,
#  'شان': 102,
#  'احف': 6,
#  'فرحة': 3,
#  'ميناا': 4,
#  'وشيريين': 1,
#  'لاخوهم': 1,
#  'شاهين': 28,
#  'دول': 34,
#  'ولاد': 19,
#  'البلد': 13,
#  'وهى': 4,
#  'دى': 39,
#  'مصرر': 4,
#  'تحيا': 7,
#  'مصر': 131,
#  'مينا': 70,
#  'فخر': 6,
#  'العرب': 13,
#  'فرح': 55,
#  'رحة': 5,
#  'مين': 171,
#  'ينا': 161,
#  'ناا': 20,
#  'وشي': 7,
#  'شير': 33,
#  'يري': 41,
#  'ريي': 22,
#  'يين': 43,
#  'لاخ': 26,
#  'اخو': 15,
#  'خوه': 3,
#  'وهم': 20,
#  'شاه': 47,
#  'اهي': 56,
#  'هين': 45,
#  'ولا': 45,
#  'لاد': 36,
#  'الب': 178,
#  'لبل': 21,
#  'بلد': 29,
#  'صرر': 4,
#  'تحي': 21,
#  'حيا': 109,
#  'الع': 219,
#  'لعر': 28,
#  'عرب': 31,
#  'يناا': 6,
#  'وشير': 3,
#  'شيري': 24,
#  'يريي': 1,
#  'ريين': 22,
#  'لاخو': 6,
#  'اخوه': 1,
#  'خوهم': 1,
#  'شاهي': 37,
#  'اهين': 37,
#  'البل': 21,
#  'لبلد': 14,
#  'العر': 28,
#  'لعرب': 19,
#  'مشكلتنا': 1,
#  'ان': 113,
#  'احنا': 52,
#  'عاملين': 3,
#  'نفسنا': 3,
#  'فاهمين': 2,
#  'الدين': 10,
#  'صح': 11,
#  'مش': 214,
#  'عارفين': 4,
#  'اننا': 6,
#  'حاولنا': 2,
#  'حتي': 19,
#  'نفهم': 3,
#  'هيكون': 3,
#  'دا': 59,
#  'حالنا': 2,
#  'ربي': 47,
#  'اصلح': 2,
#  'الامة': 1,
#  'كلت': 4,
#  'لتن': 7,
#  'تنا': 47,
#  'احن': 53,
#  'حنا': 66,
#  'عام': 88,
#  'امل': 59,
#  'ملي': 47,
#  'لين': 58,
#  'نفس': 113,
#  'فسن': 7,
#  'سنا': 16,
#  'فاه': 37,
#  'اهم': 52,
#  'همي': 8,
#  'لدي': 25,
#  'عار': 63,
#  'ارف': 52,
#  'رفي': 10,
#  'فين': 57,
#  'انن': 6,
#  'ننا': 21,
#  'ولن': 9,
#  'لنا': 161,
#  'نفه': 3,
#  'هيك': 8,
#  'حال': 53,
#  'الن': 245,
#  'اصل': 39,
#  'صلح': 12,
#  'الا': 396,
#  'لام': 175,
#  'امة': 18,
#  'شكلت': 1,
#  'كلتن': 1,
#  'لتنا': 1,
#  'عامل': 35,
#  'املي': 6,
#  'ملين': 12,
#  'نفسن': 6,
#  'فسنا': 5,
#  'فاهم': 32,
#  'اهمي': 2,
#  'همين': 3,
#  'الدي': 17,
#  'لدين': 13,
#  'عارف': 49,
#  'ارفي': 4,
#  'رفين': 6,
#  'اولن': 2,
#  'ولنا': 5,
#  'هيكو': 4,
#  'حالن': 2,
#  'النا': 104,
#  'الام': 37,
#  'لامة': 11,
#  'للأبد': 2,
#  'بكذب': 1,
#  'وبحكي': 1,
#  'بكره': 21,
#  'بصحى': 1,
#  'الصبح': 10,
#  'بكير': 1,
#  'بدرس': 1,
#  'للأ': 10,
#  'لأب': 3,
#  'أبد': 3,
#  'بكذ': 1,
#  'كذب': 4,
#  'وبح': 7,
#  'بحك': 5,
#  'حكي': 16,
#  'بكر': 33,
#  'كره': 56,
#  'بصح': 3,
#  'صحى': 8,
#  'الص': 135,
#  'لصب': 21,
#  'صبح': 39,
#  'بكي': 7,
#  'كير': 8,
#  'بدر': 8,
#  'درس': 16,
#  'للأب': 2,
#  'لأبد': 2,
#  'وبحك': 1,
#  'بحكي': 3,
#  'الصب': 20,
#  'لصبح': 11,
#  'بيقول': 10,
#  'البص': 3,
#  'عايزا': 1,
#  'جزئه': 1,
#  'يتثبت': 1,
#  'بيق': 23,
#  'يقو': 47,
#  'قول': 131,
#  'لبص': 3,
#  'يزا': 9,
#  'جزئ': 1,
#  'زئه': 1,
#  'يتث': 2,
#  'تثب': 4,
#  'ثبت': 9,
#  'بيقو': 17,
#  'يقول': 41,
#  'ايزا': 2,
#  'يتثب': 2,
#  'تثبت': 4,
#  'هري': 5,
#  'بليل': 5,
#  'هيبان': 1,
#  'حاجه': 43,
#  'بلي': 28,
#  'ليل': 50,
#  'هيب': 7,
#  'يبا': 25,
#  'بان': 21,
#  'حاج': 118,
#  'اجه': 57,
#  'هيبا': 1,
#  'يبان': 2,
#  'اتندم': 1,
#  'الساعه': 6,
#  'يلي': 25,
#  'فتت': 5,
#  'الجامعه': 1,
#  'الهاشميه': 1,
#  'اتن': 20,
#  'تند': 4,
#  'ندم': 25,
#  'الس': 236,
#  'لسا': 36,
#  'ساع': 37,
#  'اعه': 23,
#  'الج': 139,
#  'لجا': 13,
#  'جام': 11,
#  'امع': 14,
#  'معه': 11,
#  'اله': 98,
#  'هاش': 13,
#  'اشم': 2,
#  'شمي': 1,
#  'ميه': 11,
#  'اتند': 1,
#  'تندم': 4,
#  'السا': 30,
#  'لساع': 8,
#  'ساعه': 10,
#  'الجا': 12,
#  'لجام': 5,
#  'جامع': 5,
#  'امعه': 2,
#  'الها': 25,
#  'لهاش': 6,
#  'هاشم': 1,
#  'اشمي': 1,
#  'شميه': 1,
#  'سنه': 35,
#  'انتى': 26,
#  'طيوبه': 1,
#  'انت': 253,
#  'نتى': 32,
#  'طيو': 1,
#  'يوب': 5,
#  'وبه': 6,
#  'طيوب': 1,
#  'يوبه': 2,
#  'يعني': 34,
#  'باسم': 7,
#  'مزقش': 1,
#  'لطفي': 1,
#  'الكورة': 3,
#  'وقعت': 2,
#  'يعن': 57,
#  'عني': 59,
#  'باس': 15,
#  'اسم': 41,
#  'مزق': 1,
#  'زقش': 1,
#  'لطف': 3,
#  'طفي': 3,
#  'لكو': 23,
#  'كور': 16,
#  'ورة': 24,
#  'وقع': 15,
#  'قعت': 2,
#  'الكو': 14,
#  'لكور': 4,
#  'كورة': 3,
#  'موديول': 1,
#  'منحس': 1,
#  'اوله': 1,
#  'مود': 16,
#  'ودي': 27,
#  'ديو': 28,
#  'يول': 3,
#  'منح': 8,
#  'نحس': 2,
#  'وله': 29,
#  'مودي': 4,
#  'وديو': 2,
#  'ديول': 1,
#  'اه': 21,
#  'طبعا': 11,
#  'يلا': 45,
#  'بقي': 60,
#  'بدل': 11,
#  'اغلط': 1,
#  'طبع': 13,
#  'بعا': 12,
#  'اغل': 3,
#  'غلط': 15,
#  'الخير': 18,
#  'علي': 185,
#  'اوسخ': 3,
#  'حكام': 5,
#  'العالم': 14,
#  'الخ': 81,
#  'لخي': 32,
#  'خير': 100,
#  'اوس': 6,
#  'وسخ': 30,
#  'حكا': 11,
#  'كام': 27,
#  'لعا': 51,
#  'عال': 55,
#  'الخي': 31,
#  'لخير': 27,
#  'العا': 43,
#  'لعال': 18,
#  'عالم': 22,
#  'والله': 52,
#  'اسمك': 5,
#  'جواهر': 2,
#  'ونتى': 2,
#  'وال': 301,
#  'لله': 404,
#  'سمك': 9,
#  'جوا': 24,
#  'واه': 19,
#  'اهر': 22,
#  'ونت': 11,
#  'والل': 67,
#  'الله': 357,
#  'جواه': 4,
#  'واهر': 2,
#  'الثقة': 4,
#  'بالله': 11,
#  'أزكى': 1,
#  'أمل': 13,
#  'والتوكل': 1,
#  'أوفى': 1,
#  'عمل': 87,
#  'الث': 27,
#  'لثق': 6,
#  'ثقة': 6,
#  'بال': 207,
#  'أزك': 1,
#  'زكى': 1,
#  'الت': 195,
#  'لتو': 37,
#  'توك': 8,
#  'وكل': 18,
#  'أوف': 1,
#  'وفى': 9,
#  'الثق': 6,
#  'لثقة': 4,
#  'بالل': 15,
#  'والت': 18,
#  'التو': 31,
#  'لتوك': 1,
#  'توكل': 5,
#  'الوطن': 23,
#  'دائرة': 1,
#  'انتخابية': 1,
#  'تتنافس': 2,
#  'مقعدا': 1,
#  'محافظة': 2,
#  'البحيرة': 1,
#  'الو': 142,
#  'لوط': 31,
#  'وطن': 34,
#  'دائ': 16,
#  'ائر': 7,
#  'ئرة': 1,
#  'نتخ': 8,
#  'تخا': 12,
#  'خاب': 6,
#  'ابي': 39,
#  'بية': 24,
#  'تتن': 4,
#  'ناف': 12,
#  'افس': 7,
#  'مقع': 2,
#  'قعد': 16,
#  'عدا': 15,
#  'محا': 17,
#  'حاف': 9,
#  'افظ': 11,
#  'فظة': 3,
#  'لبح': 7,
#  'بحي': 4,
#  'حير': 2,
#  'يرة': 23,
#  'الوط': 28,
#  'لوطن': 28,
#  'دائر': 1,
#  'ائرة': 1,
#  'انتخ': 4,
#  'نتخا': 4,
#  'تخاب': 5,
#  'خابي': 1,
#  'ابية': 3,
#  'تتنا': 3,
#  'تناف': 3,
#  'نافس': 5,
#  'مقعد': 2,
#  'قعدا': 1,
#  'محاف': 4,
#  'حافظ': 9,
#  'افظة': 3,
#  'البح': 7,
#  'لبحي': 1,
#  'بحير': 1,
#  'حيرة': 1,
#  'قمر': 10,
#  'منور': 8,
#  'منو': 15,
#  'نور': 29,
#  'المشكلة': 6,
#  'فيمن': 1,
#  'يخذلك': 1,
#  'يخونك': 2,
#  'يوجعك': 1,
#  'يسحقك': 1,
#  'أنك': 9,
#  'تتمكن': 1,
#  'تصديق': 1,
#  'شخص': 30,
#  'نال': 10,
#  'منك': 30,
#  'مرة': 15,
#  'لتمنحه': 1,
#  'فرصة': 1,
#  'النيل': 4,
#  'أخرى': 2,
#  'كلة': 13,
#  'فيم': 1,
#  'يمن': 10,
#  'يخذ': 1,
#  'خذل': 2,
#  'ذلك': 3,
#  'يخو': 4,
#  'خون': 4,
#  'ونك': 12,
#  'يوج': 5,
#  'وجع': 11,
#  'جعك': 3,
#  'يسح': 1,
#  'سحق': 1,
#  'حقك': 3,
#  'تتم': 8,
#  'تمك': 3,
#  'مكن': 60,
#  'تصد': 8,
#  'صدي': 12,
#  'ديق': 12,
#  'لتم': 10,
#  'تمن': 28,
#  'نحه': 2,
#  'فرص': 3,
#  'رصة': 1,
#  'لني': 9,
#  'نيل': 13,
#  'أخر': 7,
#  'خرى': 4,
#  'شكلة': 9,
#  'يخذل': 1,
#  'خذلك': 1,
#  'يخون': 3,
#  'خونك': 2,
#  'يوجع': 2,
#  'وجعك': 3,
#  'يسحق': 1,
#  'سحقك': 1,
#  'تتمك': 1,
#  'تمكن': 2,
#  'تصدي': 1,
#  'صديق': 11,
#  'لتمن': 2,
#  'تمنح': 2,
#  'منحه': 2,
#  'الني': 6,
#  'لنيل': 5,
#  'أقدار': 2,
#  'طيبه': 7,
#  'سواء': 2,
#  'طابت': 1,
#  'روحك': 3,
#  'تطب': 2,
#  'يعلم': 2,
#  'وأنتم': 2,
#  'تعلمون': 1,
#  'أقد': 2,
#  'قدا': 17,
#  'دار': 21,
#  'طيب': 42,
#  'يبه': 28,
#  'سوا': 23,
#  'واء': 9,
#  'طاب': 3,
#  'ابت': 32,
#  'روح': 48,
#  'وحك': 3,
#  'يعل': 5,
#  'وأن': 12,
#  'أنت': 10,
#  'نتم': 21,
#  'تعل': 17,
#  'لمو': 72,
#  'مون': 12,
#  'أقدا': 2,
#  'قدار': 4,
#  'وأنت': 6,
#  'أنتم': 2,
#  'تعلم': 8,
#  'علمو': 4,
#  'لمون': 4,
#  'إجتماع': 1,
#  'طارئ': 1,
#  'لمجلس': 1,
#  'إدارة': 1,
#  'نادي': 15,
#  'الزمالك': 25,
#  'إجت': 3,
#  'جتم': 12,
#  'تما': 26,
#  'ماع': 33,
#  'طار': 11,
#  'ارئ': 4,
#  'لمج': 8,
#  'مجل': 8,
#  'جلس': 9,
#  'إدا': 1,
#  'ارة': 29,
#  'ناد': 25,
#  'الز': 66,
#  'لزم': 45,
#  'زما': 52,
#  'مال': 103,
#  'إجتم': 2,
#  'جتما': 6,
#  'تماع': 6,
#  'لمجل': 1,
#  'مجلس': 5,
#  'إدار': 1,
#  'دارة': 3,
#  'الزم': 41,
#  'لزما': 33,
#  'زمال': 33,
#  'مالك': 34,
#  'بيحبك': 2,
#  'هيحب': 1,
#  'حياته': 4,
#  'غيرك': 11,
#  'واضحة': 1,
#  'بيح': 18,
#  'يحب': 22,
#  'حبك': 38,
#  'هيح': 4,
#  'يات': 93,
#  'اته': 44,
#  'غير': 55,
#  'يرك': 19,
#  'واض': 16,
#  'اضح': 13,
#  'ضحة': 1,
#  'بيحب': 10,
#  'يحبك': 4,
#  'حيات': 46,
#  'ياته': 10,
#  'واضح': 10,
#  'اضحة': 1,
#  'الحب': 20,
#  'الشوق': 5,
#  'الح': 275,
#  'لحب': 22,
#  'الش': 128,
#  'لشو': 9,
#  'شوق': 9,
#  'الشو': 9,
#  'لشوق': 6,
#  'كلام': 37,
#  'صريح': 4,
#  'كلا': 51,
#  'صري': 56,
#  'ريح': 12,
#  'الورد': 8,
#  'جميعا': 8,
#  'مدينة': 2,
#  'الشيخ': 3,
#  'زايد': 6,
#  'لور': 23,
#  'ورد': 17,
#  'جمي': 49,
#  'ميع': 19,
#  'يعا': 15,
#  'مدي': 14,
#  'ينة': 17,
#  'لشي': 12,
#  'شيخ': 11,
#  'زاي': 16,
#  'ايد': 22,
#  'الور': 12,
#  'لورد': 9,
#  'جميع': 16,
#  'ميعا': 9,
#  'مدين': 6,
#  'دينة': 5,
#  'الشي': 11,
#  'لشيخ': 3,
#  'انتهى': 1,
#  'مشوار': 2,
#  'الخواجة': 1,
#  'نته': 16,
#  'تهى': 3,
#  'مشو': 4,
#  'شوا': 15,
#  'وار': 31,
#  'لخو': 8,
#  'خوا': 23,
#  'واج': 15,
#  'اجة': 64,
#  'انته': 4,
#  'نتهى': 3,
#  'مشوا': 3,
#  'شوار': 8,
#  'الخو': 8,
#  'لخوا': 5,
#  'خواج': 1,
#  'واجة': 1,
#  'شافوا': 1,
#  'الهلع': 1,
#  'والرعب': 1,
#  'العيون': 5,
#  'وع': 4,
#  'الوجوه': 1,
#  'والجري': 1,
#  'والصرخات': 1,
#  'رجاله': 2,
#  'وشباب': 2,
#  'وستات': 1,
#  'قلب': 92,
#  'الجديدة': 3,
#  'ليلتها': 1,
#  'كانوا': 5,
#  'طالبوا': 1,
#  'باعدام': 1,
#  'المجرمين': 1,
#  'شاف': 7,
#  'افو': 6,
#  'فوا': 12,
#  'لهل': 2,
#  'هلع': 1,
#  'الر': 98,
#  'لرع': 2,
#  'رعب': 3,
#  'لعي': 25,
#  'عيو': 18,
#  'يون': 40,
#  'لوج': 9,
#  'وجو': 32,
#  'جوه': 8,
#  'لجر': 6,
#  'جري': 10,
#  'لصر': 11,
#  'صرخ': 2,
#  'رخا': 2,
#  'خات': 1,
#  'رجا': 14,
#  'جال': 12,
#  'وشب': 3,
#  'شبا': 24,
#  'وست': 8,
#  'ستا': 33,
#  'تات': 7,
#  'لجد': 18,
#  'جدي': 43,
#  'ديد': 49,
#  'يدة': 21,
#  'يلت': 3,
#  'لته': 21,
#  'تها': 75,
#  'كان': 71,
#  'انو': 37,
#  'نوا': 40,
#  'طال': 20,
#  'لبو': 12,
#  'بوا': 25,
#  'باع': 19,
#  'اعد': 26,
#  'دام': 22,
#  'مجر': 14,
#  'جرم': 5,
#  'رمي': 15,
#  'شافو': 1,
#  'افوا': 2,
#  'الهل': 2,
#  'لهلع': 1,
#  'والر': 5,
#  'الرع': 1,
#  'لرعب': 1,
#  'العي': 21,
#  'لعيو': 5,
#  'عيون': 16,
#  'الوج': 1,
#  'لوجو': 4,
#  'وجوه': 3,
#  'والج': 7,
#  'الجر': 6,
#  'لجري': 2,
#  'والص': 6,
#  'الصر': 11,
#  'لصرخ': 1,
#  'صرخا': 1,
#  'رخات': 1,
#  'رجال': 8,
#  'جاله': 4,
#  'وشبا': 3,
#  'شباب': 20,
#  'وستا': 2,
#  'ستات': 2,
#  'الجد': 17,
#  'لجدي': 15,
#  'جديد': 40,
#  'ديدة': 10,
#  'ليلت': 1,
#  'يلته': 2,
#  'لتها': 5,
#  'كانو': 11,
#  'انوا': 9,
#  'طالب': 10,
#  'البو': 9,
#  'لبوا': 3,
#  'باعد': 2,
#  'اعدا': 8,
#  'عدام': 2,
#  'المج': 5,
#  'لمجر': 4,
#  'مجرم': 1,
#  'جرمي': 1,
#  'رمين': 4,
#  'آخر': 8,
#  'ليآلى': 1,
#  'ليآ': 1,
#  'يآل': 1,
#  'آلى': 1,
#  'ليآل': 1,
#  'يآلى': 1,
#  'الاهلي': 15,
#  'يتغلب': 3,
#  'امبارح': 7,
#  'وناس': 9,
#  'تشمت': 4,
#  'والزمالك': 1,
#  'النهردة': 1,
#  'يبقي': 9,
#  'لسة': 6,
#  'مفيهاش': 2,
#  'رياضيه': 1,
#  'لاه': 42,
#  'اهل': 57,
#  'هلي': 29,
#  'يتغ': 4,
#  'تغل': 18,
#  'غلب': 14,
#  'امب': 9,
#  'مبا': 30,
#  'بار': 58,
#  'ارح': 24,
#  'ونا': 27,
#  'ناس': 132,
#  'تشم': 4,
#  'شمت': 4,
#  'لنه': 22,
#  'نهر': 6,
#  'هرد': 2,
#  'ردة': 9,
#  'يبق': 23,
#  'مفي': 36,
#  'فيه': 21,
#  'يها': 71,
#  'ريا': 37,
#  'ياض': 15,
#  'اضي': 24,
#  'ضيه': 1,
#  'الاه': 32,
#  'لاهل': 28,
#  'اهلي': 19,
#  'يتغل': 3,
#  'تغلب': 8,
#  'امبا': 9,
#  'مبار': 25,
#  'بارح': 11,
#  'والز': 3,
#  'النه': 21,
#  'لنهر': 2,
#  'نهرد': 1,
#  'هردة': 1,
#  'مفيه': 2,
#  'فيها': 5,
#  'يهاش': 2,
#  'رياض': 13,
#  'ياضي': 10,
#  'اضيه': 1,
#  'بحبك': 7,
#  'الانثي': 1,
#  'ترانيم': 1,
#  'وتناغم': 1,
#  'موسيقي': 2,
#  'الطبيعه': 1,
#  'بعضها': 2,
#  'البعض': 1,
#  'استطاعتك': 1,
#  'ياأدم': 1,
#  'قولها': 1,
#  'لاتتردد': 1,
#  'فهي': 5,
#  'تسمعها': 1,
#  'لومي': 2,
#  'بحب': 34,
#  'لان': 99,
#  'انث': 1,
#  'نثي': 2,
#  'ترا': 30,
#  'ران': 20,
#  'اني': 122,
#  'نيم': 2,
#  'وتن': 11,
#  'ناغ': 1,
#  'اغم': 1,
#  'موس': 11,
#  'وسي': 18,
#  'سيق': 3,
#  'يقي': 12,
#  'الط': 36,
#  'لطب': 6,
#  'طبي': 11,
#  'بيع': 25,
#  'يعه': 3,
#  'بعض': 13,
#  'عضه': 5,
#  'ضها': 4,
#  'لبع': 9,
#  'است': 72,
#  'ستط': 8,
#  'تطا': 2,
#  'طاع': 7,
#  'اعت': 23,
#  'عتك': 8,
#  'ياأ': 1,
#  'اأد': 1,
#  'أدم': 1,
#  'لات': 68,
#  'اتت': 5,
#  'تتر': 6,
#  'ترد': 6,
#  'ردد': 5,
#  'تسم': 10,
#  'سمع': 25,
#  'عها': 15,
#  'لوم': 19,
#  'ومي': 31,
#  'الان': 44,
#  'لانث': 1,
#  'انثي': 1,
#  'تران': 2,
#  'راني': 8,
#  'انيم': 1,
#  'وتنا': 2,
#  'تناغ': 1,
#  'ناغم': 1,
#  'موسي': 3,
#  'وسيق': 3,
#  'سيقي': 3,
#  ...}

# %% [markdown]
# # Sample Frequency

# %%
print('sample frequencies')
print(random.sample(list(all_features_count.items()), 30))
word = 'في'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
word = 'فى'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
word = 'من'
print('freq of word {} is {}'.format(word, all_features_count.get(word, 0)))
# Out:
# sample frequencies
# [('ازله', 3), ('آرف', 1), ('دروس', 1), ('إعل', 2), ('ذائ', 1), ('ابتد', 5), ('اشوفه', 1), ('اخرب', 1), ('وامشى', 1), ('بروو', 6), ('كاء', 1), ('بصنعك', 1), ('حاجتين', 1), ('سعو', 8), ('دريـ', 1), ('تبشر', 1), ('تخص', 5), ('يــلعــبش', 1), ('لاتج', 1), ('اعرة', 1), ('جمه', 13), ('اوزة', 3), ('ملكش', 1), ('تربيهاا', 1), ('اطف', 8), ('تمتع', 3), ('حط', 1), ('سيصن', 1), ('غله', 4), ('لوبه', 2)]
# freq of word في is 0
# freq of word فى is 135
# freq of word من is 0

# %% [markdown]
# # Compute Threshold

# %%
print('size of training data:',  len(train_data))
min_df = int(0.001 * len(train_data))
max_df = int(0.98 * len(train_data))
print('min document frequency:', min_df)
print('max document frequency:', max_df)
# Out:
# size of training data: 2191
# min document frequency: 2
# max document frequency: 2147

# %% [markdown]
# # Selecting Features

# %%
# remove features that have frequency below/above the threshold
my_features = set([word for word, freq in all_features_count.items() if  max_df > freq > min_df ])
print(len(my_features), 'are kept out of', len(all_features))
# Out:
# 8176 are kept out of 112650

# %%
# re.sub("[a-zA-Z]+", "","abv-")

# %% [markdown]
# # Sample of selected features

# %%
print('{} sample of selected features:'.format(sample_size))
print(random.sample(list(my_features), sample_size))
# Out:
# 100 sample of selected features:
# ['ممت', 'ريت', 'الاف', 'أتي', 'طــ', 'فهو', 'حبب', 'إبراهيم', 'قلوبنا', 'الشمال', 'اطف', 'لرجل', 'جرح', 'قهم', 'كادي', 'تسلم', 'لساع', 'للات', 'دام', 'داري', 'النف', 'آدم', 'جيني', 'واصا', 'لمق', 'أشر', 'لذاك', 'يحفظ', 'يصير', 'حيان', 'فاغ', 'خطاء', 'حمن', 'ومة', 'اغن', 'اسى', 'تتوقع', 'اصبح', 'تفرح', 'نيين', 'اكت', 'موقف', 'شمال', 'شلت', 'عدهم', 'خصص', 'عبي', 'واصل', 'شتغ', 'مدحت', 'ستق', 'بقو', 'هادي', 'البرد', 'سبه', 'تمنى', 'لأمل', 'عجر', 'ورت', 'حساب', 'هفض', 'بحو', 'محتا', 'الاثنين', 'روع', 'نما', 'ندنا', 'اسا', 'الكي', 'فيهم', 'فإنه', 'جوو', 'قبض', 'نفسه', 'تنف', 'لمسا', 'رمك', 'لحدي', 'نجوم', 'لموه', 'شاه', 'كلن', 'يغا', 'يجعل', 'لان', 'مميز', 'ده', 'عيم', 'نهاية', 'طاب', 'لبه', 'الدا', 'حلي', 'الماتشات', 'المولد', 'رادي', 'وحش', 'يشي', 'بطلت', 'تظهر']

# %% [markdown]
# # generating features for training documents ...

# %%
feature_sets = [(document_features(d, my_features), c) for (d, c) in train_data]

# %% [markdown]
# # training ...

# %%
classifier = nltk.NaiveBayesClassifier.train(feature_sets)
print('training is done')
# Out:
# training is done

# %% [markdown]
# # Most informative features

# %%
classifier.show_most_informative_features(40)
# Out:
# Most Informative Features
#                 has(لسي) = True              neu : pos    =     21.5 : 1.0
#                has(السي) = True              neu : pos    =     20.6 : 1.0
#                 has(لفي) = True              neu : pos    =     15.8 : 1.0
#                has(الفي) = True              neu : pos    =     15.8 : 1.0
#                 has(واق) = True              neg : pos    =     13.9 : 1.0
#                 has(لوط) = True              neu : pos    =     11.8 : 1.0
#                has(لوطن) = True              neu : pos    =     11.8 : 1.0
#                has(الوط) = True              neu : pos    =     11.8 : 1.0
#                 has(فاي) = True              neg : pos    =     11.7 : 1.0
#                 has(وطن) = True              neu : neg    =     11.6 : 1.0
#                has(اهين) = True              pos : neg    =     11.6 : 1.0
#                  has(رب) = True              pos : neg    =     11.6 : 1.0
#               has(الوطن) = True              neu : pos    =     11.2 : 1.0
#                 has(بيق) = True              neg : pos    =     11.0 : 1.0
#                 has(نور) = True              pos : neg    =     10.9 : 1.0
#                 has(يسع) = True              pos : neg    =     10.9 : 1.0
#                has(شاهي) = True              pos : neg    =     10.9 : 1.0
#                 has(خير) = True              pos : neg    =     10.1 : 1.0
#                has(لخير) = True              pos : neg    =      9.7 : 1.0
#                has(لعام) = True              neu : neg    =      9.4 : 1.0
#                 has(صدر) = True              neu : neg    =      9.4 : 1.0
#                 has(حلو) = True              pos : neu    =      9.3 : 1.0
#                 has(ارف) = True              neg : pos    =      9.3 : 1.0
#                 has(سعد) = True              pos : neg    =      9.2 : 1.0
#                 has(لنس) = True              neu : pos    =      9.1 : 1.0
#                has(ريبا) = True              neu : pos    =      9.1 : 1.0
#                has(النس) = True              neu : pos    =      9.1 : 1.0
#                 has(مصد) = True              neu : pos    =      9.1 : 1.0
#                has(مصدر) = True              neu : pos    =      9.1 : 1.0
#                 has(لور) = True              pos : neg    =      9.1 : 1.0
#                 has(ويه) = True              neg : pos    =      8.9 : 1.0
#                 has(كفا) = True              neg : pos    =      8.9 : 1.0
#                has(عارف) = True              neg : pos    =      8.7 : 1.0
#                 has(ائل) = True              neu : neg    =      8.5 : 1.0
#                 has(لقر) = True              neu : neg    =      8.5 : 1.0
#                 has(لأو) = True              neu : neg    =      8.5 : 1.0
#                 has(شاء) = True              pos : neg    =      8.4 : 1.0
#               has(شاهين) = True              pos : neg    =      8.4 : 1.0
#                 has(بتت) = True              neg : pos    =      8.2 : 1.0
#                has(الحم) = True              pos : neg    =      8.1 : 1.0

# %% [markdown]
# # generating features for test documents ...

# %%
test_features = [(document_features(d, my_features), c) for (d, c) in train_data]

# %% [markdown]
# # classify test instances

# %%
ref_sets = collections.defaultdict(set)
test_sets = collections.defaultdict(set)

for i, (feats, label) in enumerate(test_features):
    ref_sets[label].add(i)
    observed = classifier.classify(feats)
    test_sets[observed].add(i)

# %% [markdown]
# # Results

# %%
print('accuracy: ', nltk.classify.accuracy(classifier, test_features))
print('pos precision: ', precision(ref_sets['pos'], test_sets['pos']))
print('pos recall:', recall(ref_sets['pos'], test_sets['pos']))
print('neg precision: ', precision(ref_sets['neg'], test_sets['neg']))
print('neg recall:', recall(ref_sets['neg'], test_sets['neg']))
print('neu precision: ', precision(ref_sets['neu'], test_sets['neu']))
print('neu recall:', recall(ref_sets['neu'], test_sets['neu']))
print('positive f-score:', f_measure(ref_sets['pos'], test_sets['pos']))
print('negative f-score:', f_measure(ref_sets['neg'], test_sets['neg']))
print('neutral f-score:', f_measure(ref_sets['neu'], test_sets['neu']))
# Out:
# accuracy:  0.8452761296211776
# pos precision:  0.7933467741935484
# pos recall: 0.9459134615384616
# neg precision:  0.8697318007662835
# neg recall: 0.8730769230769231
# neu precision:  0.9230769230769231
# neu recall: 0.6632124352331606
# positive f-score: 0.8629385964912281
# negative f-score: 0.871401151631478
# neutral f-score: 0.7718592964824121

# %%
accuracy:  0.7659671532846716
pos precision:  0.7375381485249237
pos recall: 0.8682634730538922
neg precision:  0.7790849673202614
neg recall: 0.7650834403080873
neu precision:  0.8063063063063063
neu recall: 0.6193771626297578
positive f-score: 0.7975797579757976
negative f-score: 0.772020725388601
neutral f-score: 0.700587084148728
# Out:
#   File "<ipython-input-975-177ba45ce9d8>", line 2
#     pos precision:  0.7375381485249237
#                 ^
# SyntaxError: invalid syntax
